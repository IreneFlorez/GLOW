# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib import pylab
import pandas as pd

# %matplotlib inline

# %%
import seaborn as sns
sns.set_style("whitegrid")
import numpy as np

# %%
# %run ../.././data_wrangling/2b_data_handling.ipynb
# Out:
# Stored 'query_vars' (dict)
# Stored 'quality_vars' (dict)

# %%
import datetime
d = datetime.date(2019, 10, 10)
isinstance(d, datetime.date)
# Out:
# True

# %%
final_frame_updated_pv_topics_suggs = pd.read_csv("../../../data/processed/query_results/content_quality/b5_final_frame_updated_pv_topics_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
interim_frame_updated_pv_topics_suggs = pd.read_csv("../../../data/processed/query_results/content_quality/5_interim_frame_updated_w_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
feb_global_views_referrer = pd.read_csv("../../../data/processed/query_results/content_quality/feb_global_views_referrer.csv", sep=',', encoding = 'utf-8')

# %%
indonesia = pd.read_csv("../../../data/raw/articles/2019/query_results/content_quality/per_wiki_full/Indonesia/articles_w_july_incountry_pageviews_recs.csv", sep=',')

# %% [markdown]
# ## Handle Data

# %%
ifupvts_lim = interim_frame_updated_pv_topics_suggs[[
    'page_id',
    'database_code',
    'page_title',
    'page_len',
    'article_type',
    'g_suggestion',
]].copy()

# %%
feb_global_views_referrer = feb_global_views_referrer.rename(columns = {'wikicode':'database_code',
                                                                      'referer_class':'referrer_class'})

# %%
fgvr = feb_global_views_referrer.copy()
fgvr.replace({'referrer_class' : { 'none' : 'none_unknown', 
                                                       'unknown' : 'none_unknown',
                                                       'external (search engine)': 'external_comb',
                                                       'external': 'external_comb'
                                                      }}, inplace=True)

# %%
rdf = pd.merge(ifupvts_lim, feb_global_views_referrer, how='left', on=['page_id', 'page_title','database_code'])

# %%
interim_df = interim_frame_updated_pv_topics_suggs[[
    'database_code',
    'page_len',
    'relative_page_len',
    'first_edited',
    'article_type',
    'translation_tool',
    'views_1M',
    'views_1M_all',
    'predicted_label_1',
    'g_suggestion',
]].copy()

# %% [markdown]
# #### page_len

# %%
#Creating the page_len_bins
bins = [0, 1000, 5000, 10000, 20000, 30000, 40000, 50000, 100000, 200000]
interim_df['page_len_bins'] = pd.cut(interim_df['page_len'], bins)

# %%
b = pd.cut(interim_df['page_len'], bins=bins).value_counts()
b.plot()
plt.xticks(rotation=45);

# %% [markdown]
# #### page_len_relative

# %%
#Creating the page_len_bins
plr_bins = [0, .2, .5, .7, .9, 1]
names= ['1','2','3','4','5']

#create bin column
interim_df['rel_page_len_bins'] = pd.cut(interim_df['relative_page_len'], plr_bins)

#create renamed bin column for charting and change dtype to into
interim_df['rplb_charting'] = pd.cut(interim_df['relative_page_len'], plr_bins, labels=names)
interim_df.rplb_charting = pd.to_numeric(interim_df.rplb_charting, errors='coerce')

# %%
#attention: PA wiki had 1 featured article
#attention: tcywiki and satwiki had zero featured articles, so these use the median article length as their anchor
plr_att_list = ['tcywiki', 'satwiki', 'pawiki']
plr_limited_list = ['pawiki']
solid_plr_wikis_df = interim_df[~interim_df['database_code'].isin(plr_att_list)]
mid_plr_wikis_df = interim_df[~interim_df['database_code'].isin(plr_limited_list)]

# %% [markdown]
# #### stub_lifetime_M

# %%
#handling first_edited
#interim_df.first_edited = interim_df.first_edited.apply(np.datetime64) #creates datetime index column
interim_df['first_edited'] = pd.to_datetime(interim_df['first_edited']).dt.date

#create mask
expanded_articles = interim_df['article_type'] == 'expanded'
new_articles = interim_df['article_type'] == 'new'

# %%
#create a time delta column, negative if the article existed as a stub prior to the start of the contest
interim_df['stub_lifetime_M'] = (interim_df['first_edited']-d).astype('timedelta64[M]')
#interim_df['stub_lifetime'] = (interim_df['first_edited']-d)
#z = (d - interim_df['first_edited']).dt.seconds

# %%
#check dispersion in stub_lifetime_M
sns.stripplot(data = interim_df, y = 'stub_lifetime_M', jitter = True);
#sns.plt.ylim(0, 500)
#sns.plt.show()

# %%
# Review 'page_len' distribution 
plt.figure();
age_hist = interim_df['stub_lifetime_M'].plot.hist(bins=10)
age_hist.set_xlabel("stub_lifetime_M")
age_hist.set_ylabel("Articles")
age_hist.set_title('Distribution of stub_lifetime_M');

# %%
#Creating the stub_lifetime_bins
slb_bins = [-200, -150, -100, -50, 0, 5]
slb_names = ['4','3','2','1','0']

interim_df['stub_lifetime_bins'] = pd.cut(interim_df['stub_lifetime_M'], slb_bins)

interim_df['stub_stlb_charting'] = pd.cut(interim_df['stub_lifetime_M'], slb_bins, labels=slb_names)
interim_df.stub_stlb_charting = pd.to_numeric(interim_df.stub_stlb_charting, errors='coerce')

# %%
t = pd.cut(interim_df['stub_lifetime_M'], bins=slb_bins).value_counts()
t.plot();

# %% [markdown]
# #### Topics

# %%
#create mask
expanded_articles = interim_df['article_type'] == 'expanded'
new_articles = interim_df['article_type'] == 'new'

expanded_final_frame = final_frame_updated_pv_topics_suggs['article_type'] == 'expanded'
new_final_frame = final_frame_updated_pv_topics_suggs['article_type'] == 'new'

# %% [markdown]
# ### General Review

# %%
#unique value counts per column
for c in interim_df.columns:
    print ("---- %s ---" % c)
    print (interim_df[c].value_counts())
# Out:
# ---- database_code ---
# tawiki     2827
# pawiki     1726
# urwiki     1335
# bnwiki     1189
# satwiki     476
# hiwiki      251
# mlwiki      216
# knwiki      196
# aswiki      190
# guwiki      190
# orwiki      126
# mrwiki      121
# tewiki       24
# tcywiki      23
# sawiki       19
# Name: database_code, dtype: int64
# ---- page_len ---
# 9696.0     5
# 11421.0    5
# 10562.0    5
# 9965.0     5
# 4005.0     5
#           ..
# 10496.0    1
# 14720.0    1
# 14928.0    1
# 14201.0    1
# 11008.0    1
# Name: page_len, Length: 6896, dtype: int64
# ---- relative_page_len ---
# 1.000000    518
# 0.061849      5
# 0.256893      4
# 0.057694      4
# 0.131252      4
#            ...
# 0.070928      1
# 0.117290      1
# 0.278027      1
# 0.385100      1
# 0.269293      1
# Name: relative_page_len, Length: 7696, dtype: int64
# ---- first_edited ---
# 2020-01-11    260
# 2019-10-29    133
# 2019-11-17    121
# 2019-10-28    119
# 2019-11-20    114
#              ...
# 2006-08-18      1
# 2007-02-20      1
# 2015-03-17      1
# 2004-05-21      1
# 2009-03-02      1
# Name: first_edited, Length: 1154, dtype: int64
# ---- article_type ---
# new         7481
# expanded    1428
# Name: article_type, dtype: int64
# ---- translation_tool ---
# False    5183
# True     3726
# Name: translation_tool, dtype: int64
# ---- views_1M ---
# 0.0      2870
# 1.0      1283
# 2.0       863
# 3.0       528
# 4.0       383
#          ...
# 230.0       1
# 544.0       1
# 857.0       1
# 354.0       1
# 613.0       1
# Name: views_1M, Length: 411, dtype: int64
# ---- views_1M_all ---
# 2.0       681
# 1.0       640
# 3.0       547
# 4.0       516
# 5.0       454
#          ...
# 1558.0      1
# 341.0       1
# 550.0       1
# 1713.0      1
# 1031.0      1
# Name: views_1M_all, Length: 620, dtype: int64
# ---- predicted_label_1 ---
# Culture.Biography.Biography*                   2269
# Geography.Regions.Asia.South_Asia              1833
# 0                                               928
# Geography.Regions.Asia.Asia*                    877
# STEM.STEM*                                      661
# Culture.Sports                                  185
# History_and_Society.Politics_and_government     183
# Culture.Media.Films                             174
# Geography.Geographical                          153
# Culture.Philosophy_and_religion                 152
# History_and_Society.Society                     110
# Geography.Regions.Asia.Southeast_Asia           109
# Culture.Media.Media*                            100
# STEM.Biology                                     96
# Geography.Regions.Europe.Europe*                 78
# Geography.Regions.Asia.West_Asia                 78
# Culture.Food_and_drink                           78
# Culture.Literature                               71
# History_and_Society.History                      69
# STEM.Medicine_&_Health                           67
# History_and_Society.Transportation               63
# History_and_Society.Military_and_warfare         51
# History_and_Society.Business_and_economics       47
# Culture.Visual_arts.Visual_arts*                 42
# Geography.Regions.Asia.East_Asia                 37
# STEM.Chemistry                                   35
# Culture.Linguistics                              33
# STEM.Engineering                                 32
# Culture.Media.Television                         32
# History_and_Society.Education                    30
# Geography.Regions.Americas.North_America         24
# Geography.Regions.Oceania                        24
# Geography.Regions.Asia.Central_Asia              17
# Culture.Visual_arts.Architecture                 17
# Culture.Media.Music                              16
# Culture.Internet_culture                         15
# Geography.Regions.Americas.South_America         13
# STEM.Space                                       12
# Culture.Media.Video_games                        10
# Culture.Media.Entertainment                      10
# Culture.Visual_arts.Fashion                       9
# Geography.Regions.Europe.Northern_Europe          9
# Geography.Regions.Europe.Southern_Europe          8
# STEM.Technology                                   8
# STEM.Earth_and_environment                        6
# Culture.Media.Books                               6
# Geography.Regions.Europe.Western_Europe           6
# Culture.Biography.Women                           6
# Geography.Regions.Europe.Eastern_Europe           4
# Culture.Visual_arts.Comics_and_Anime              3
# Geography.Regions.Americas.Central_America        3
# Geography.Regions.Africa.Northern_Africa          3
# Culture.Performing_arts                           3
# STEM.Libraries_&_Information                      2
# Geography.Regions.Africa.Africa*                  2
# Name: predicted_label_1, dtype: int64
# ---- g_suggestion ---
# False    7373
# True     1536
# Name: g_suggestion, dtype: int64
# ---- page_len_bins ---
# (10000, 20000]      4637
# (5000, 10000]       2860
# (20000, 30000]       614
# (1000, 5000]         526
# (30000, 40000]       154
# (50000, 100000]       57
# (40000, 50000]        51
# (100000, 200000]       6
# (0, 1000]              2
# Name: page_len_bins, dtype: int64
# ---- rel_page_len_bins ---
# (0.0, 0.2]    5300
# (0.2, 0.5]    2744
# (0.9, 1.0]     561
# (0.5, 0.7]     232
# (0.7, 0.9]      72
# Name: rel_page_len_bins, dtype: int64
# ---- rplb_charting ---
# 1    5300
# 2    2744
# 5     561
# 3     232
# 4      72
# Name: rplb_charting, dtype: int64
# ---- stub_lifetime_M ---
#  1.0      2647
#  0.0      2592
#  2.0      1887
#  3.0       355
# -28.0       32
#           ...
# -119.0       1
# -185.0       1
# -178.0       1
# -118.0       1
# -175.0       1
# Name: stub_lifetime_M, Length: 188, dtype: int64
# ---- stub_lifetime_bins ---
# (0, 5]          4889
# (-50, 0]        2987
# (-100, -50]      391
# (-150, -100]     387
# (-200, -150]     255
# Name: stub_lifetime_bins, dtype: int64
# ---- stub_stlb_charting ---
# 0    4889
# 1    2987
# 2     391
# 3     387
# 4     255
# Name: stub_stlb_charting, dtype: int64

# %%
#all accepted and surviving articles, core metrics
plt.figure(figsize = (20,8))
sns.heatmap(indonesia.corr(), annot=True, cmap='coolwarm');

# %%
c = indonesia.corr().abs()

s = c.unstack()
so = s.sort_values(kind="quicksort")

# %%
so
# Out:
# relative_page_len         july_view_count_internal    0.000772
# july_view_count_internal  relative_page_len           0.000772
# iwsitelinks               talk_page_edits             0.002181
# talk_page_edits           iwsitelinks                 0.002181
# editors_nm                iwsitelinks                 0.002229
#                                                         ...
# watch_count               is_double_redirect               NaN
#                           revertrate                       NaN
# g_suggestion              is_double_redirect               NaN
#                           recs_given_order                 NaN
#                           revertrate                       NaN
# Length: 729, dtype: float64

# %%
plt.figure(figsize = (20,8))
sns.heatmap(indonesia[['july_view_count_internal', 'g_suggestion', 
                       'editors_nm', 'iwsitelinks', 'talk_page_edits',
                      'QID', 'micro_editors', 'recs_given_order', 'relative_page_len', 'page_len','editors_nm',
                      ]].corr(), annot=True, cmap='coolwarm');

# %%
#heatmap excluding PAwiki articles which only had 1 'featured article' (generally...not specific to GLOW)
sns.heatmap(mid_plr_wikis_df[['views_1M_all', 'g_suggestion', 'rplb_charting', 'page_len', 'relative_page_len']].corr(), annot=True, cmap='coolwarm');

# %%
#heatmap using only articles from wikis with 'featured articles' (generally...not specific to GLOW)
sns.heatmap(solid_plr_wikis_df[['views_1M_all', 'g_suggestion', 'rplb_charting', 'page_len', 'relative_page_len']].corr(), annot=True, cmap='coolwarm');

# %%
interim_df.describe()
# Out:
#             page_len  relative_page_len     views_1M  views_1M_all  \
# count    8909.000000        8909.000000  8909.000000   8909.000000
# mean    12774.340554           0.247017    29.769222     73.327646
# std      8669.469284           0.233040   163.064534    279.233210
# min       366.000000           0.009660     0.000000      0.000000
# 25%      8597.000000           0.108477     0.000000      4.000000
# 50%     11119.000000           0.158739     2.000000     10.000000
# 75%     14576.000000           0.285734     8.000000     37.000000
# max    218860.000000           1.000000  4890.000000   9389.000000
#
#        rplb_charting  stub_lifetime_M  stub_stlb_charting
# count    8909.000000      8909.000000         8909.000000
# mean        1.636211       -13.293187            0.667864
# std         1.042968        38.621574            0.955934
# min         1.000000      -191.000000            0.000000
# 25%         1.000000         0.000000            0.000000
# 50%         1.000000         1.000000            0.000000
# 75%         2.000000         2.000000            1.000000
# max         5.000000         3.000000            4.000000

# %%
def describe(df, stats):
    d = df.describe()
    return d.append(df.reindex(d.columns, axis=1).agg(stats))


#describe(interim_df, ['skew', 'mad', 'kurt'])

# %% [markdown]
# #### Select columns

# %%
list(interim_df)
# Out:
# ['database_code',
#  'page_len',
#  'relative_page_len',
#  'first_edited',
#  'article_type',
#  'translation_tool',
#  'views_1M',
#  'views_1M_all',
#  'predicted_label_1',
#  'g_suggestion',
#  'page_len_bins',
#  'rel_page_len_bins',
#  'rplb_charting',
#  'stub_lifetime_M',
#  'stub_lifetime_bins',
#  'stub_stlb_charting']

# %%
select_columns = [
 'g_suggestion',
 'article_type',
 'translation_tool',
 ]

columns = [
 'g_suggestion',
 'article_type',
 'stub_lifetime_bins',
 'translation_tool',
 'page_len_bins',
 'database_code',
 'predicted_label_1',
 ]

# %%
for r in select_columns :
    print(interim_df.groupby(r)['views_1M_all'].describe().sort_values(by=['count','mean'],ascending=False))
    print('*********************************')
# Out:
#                count        mean         std  min  25%   50%     75%     max
# g_suggestion
# False         7373.0   52.421809  221.094786  0.0  3.0   8.0   26.00  9389.0
# True          1536.0  173.678385  453.371171  0.0  9.0  34.0  161.25  6790.0
# *********************************
#                count        mean         std  min   25%   50%    75%     max
# article_type
# new           7481.0   37.464911   92.096313  0.0   3.0   8.0   24.0  1884.0
# expanded      1428.0  261.205182  632.619993  0.0  13.0  61.0  240.5  9389.0
# *********************************
#                    count       mean         std  min  25%   50%   75%     max
# translation_tool
# False             5183.0  98.776191  353.088117  0.0  5.0  14.0  57.0  9389.0
# True              3726.0  37.927805  104.264992  0.0  3.0   7.0  18.0  1884.0
# *********************************

# %%
#avg views for each unique value by columns
for r in columns :
    print(interim_df.groupby(r)['views_1M_all'].mean().sort_values(ascending=False))
    print('*********************************')
# Out:
# g_suggestion
# True     173.678385
# False     52.421809
# Name: views_1M_all, dtype: float64
# *********************************
# article_type
# expanded    261.205182
# new          37.464911
# Name: views_1M_all, dtype: float64
# *********************************
# stub_lifetime_bins
# (-200, -150]    650.443137
# (-150, -100]    299.956072
# (-100, -50]     135.365729
# (-50, 0]         53.656512
# (0, 5]           32.344038
# Name: views_1M_all, dtype: float64
# *********************************
# translation_tool
# False    98.776191
# True     37.927805
# Name: views_1M_all, dtype: float64
# *********************************
# page_len_bins
# (100000, 200000]    1150.000000
# (50000, 100000]      704.807018
# (40000, 50000]       485.921569
# (30000, 40000]       368.064935
# (20000, 30000]       191.599349
# (0, 1000]            106.500000
# (10000, 20000]        66.643520
# (5000, 10000]         29.296154
# (1000, 5000]          25.889734
# Name: views_1M_all, dtype: float64
# *********************************
# database_code
# hiwiki     351.721116
# guwiki     252.805263
# tewiki     250.250000
# mrwiki     199.727273
# bnwiki     117.312868
# tawiki      86.239123
# knwiki      74.454082
# aswiki      52.452632
# urwiki      39.763296
# tcywiki     24.913043
# mlwiki      19.629630
# orwiki      16.055556
# pawiki       9.848204
# sawiki       7.473684
# satwiki      3.962185
# Name: views_1M_all, dtype: float64
# *********************************
# predicted_label_1
# Geography.Regions.Africa.Africa*               322.000000
# STEM.Libraries_&_Information                   206.500000
# Geography.Geographical                         189.326797
# Culture.Linguistics                            174.181818
# Culture.Philosophy_and_religion                166.618421
# Culture.Food_and_drink                         166.166667
# History_and_Society.Transportation             154.698413
# Geography.Regions.Asia.Asia*                   118.824401
# STEM.Medicine_&_Health                         106.089552
# History_and_Society.Business_and_economics     104.638298
# Culture.Media.Films                            102.224138
# STEM.Earth_and_environment                      97.666667
# Geography.Regions.Europe.Europe*                97.051282
# STEM.STEM*                                      95.580938
# Culture.Media.Media*                            91.120000
# History_and_Society.Society                     80.854545
# Culture.Media.Video_games                       72.700000
# Geography.Regions.Asia.South_Asia               69.770322
# STEM.Biology                                    69.239583
# STEM.Technology                                 69.125000
# Culture.Media.Television                        66.218750
# Geography.Regions.Americas.South_America        64.461538
# History_and_Society.Military_and_warfare        59.411765
# Culture.Visual_arts.Fashion                     58.222222
# Culture.Visual_arts.Visual_arts*                55.952381
# Culture.Biography.Biography*                    54.472896
# STEM.Engineering                                48.281250
# STEM.Chemistry                                  48.228571
# 0                                               47.128233
# Geography.Regions.Asia.Southeast_Asia           47.045872
# Geography.Regions.Europe.Southern_Europe        46.125000
# History_and_Society.History                     45.985507
# Culture.Visual_arts.Architecture                41.470588
# STEM.Space                                      37.500000
# Culture.Literature                              37.211268
# Geography.Regions.Europe.Northern_Europe        37.111111
# History_and_Society.Politics_and_government     34.568306
# Geography.Regions.Americas.North_America        33.583333
# Culture.Media.Books                             33.000000
# Geography.Regions.Asia.West_Asia                32.038462
# History_and_Society.Education                   29.100000
# Culture.Sports                                  27.481081
# Culture.Biography.Women                         25.333333
# Geography.Regions.Asia.East_Asia                21.810811
# Culture.Internet_culture                        21.200000
# Geography.Regions.Africa.Northern_Africa        18.000000
# Culture.Media.Music                             16.000000
# Geography.Regions.Asia.Central_Asia             14.941176
# Geography.Regions.Europe.Eastern_Europe         13.000000
# Culture.Visual_arts.Comics_and_Anime            12.000000
# Geography.Regions.Europe.Western_Europe         11.333333
# Culture.Media.Entertainment                     11.200000
# Geography.Regions.Americas.Central_America       8.000000
# Geography.Regions.Oceania                        5.458333
# Culture.Performing_arts                          4.333333
# Name: views_1M_all, dtype: float64
# *********************************

# %%
#all pages average pageviews
interim_df["views_1M_all"].mean()
# Out:
# 73.32764620047143

# %%
#all pages average pageviews, from within India
interim_df["views_1M"].mean()
# Out:
# 29.769222134919744

# %%
#new pages average pageviews
final_frame_updated_pv_topics_suggs["views_1M_all"].mean()
# Out:
# 37.36135356519404

# %%
#new pages average pageviews, from within India
final_frame_updated_pv_topics_suggs["views_1M"].mean()
# Out:
# 10.728078420840607

# %% [markdown]
# ## Article type

# %%
interim_df.groupby('article_type', sort=True)['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False)
# Out:
#                     mean  count       sum
# article_type
# expanded      261.205182   1428  373001.0
# new            37.464911   7481  280275.0

# %%
interim_df.groupby('article_type')['views_1M_all'].agg(['mean'])
# Out:
#                     mean
# article_type
# expanded      261.205182
# new            37.464911

# %%
#calculate how many more views expanded articles received on average over new articles
e = interim_df.groupby('article_type')['views_1M_all'].mean()
e_impact = e[0]/e[1]
e_impact
# Out:
# 6.9719952442666475

# %%
interim_df.groupby('article_type').views_1M_all.mean().plot(kind='bar');

# %%
#Total Views by Wiki: Expanded vs New
indonesia.groupby(["database_code", "article_type"])["july_view_count_internal"].sum().unstack().plot(kind="bar", color=['b', 'g'],stacked=True);

# %%
#Total Views by Wiki: Expanded vs New
interim_df.groupby(["database_code", "article_type"])["views_1M_all"].sum().unstack().plot(kind="bar", color=['b', 'g'],stacked=True);

# %%
#Avg Views by Wiki: Expanded vs New
interim_df.groupby(["database_code", "article_type"])["views_1M_all"].mean().unstack().plot(kind="bar", color=['b', 'g'], stacked=True);

# %% [markdown]
# ## G_suggestions

# %%
interim_df.groupby('g_suggestion', sort=True)['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False)
# Out:
#                     mean  count       sum
# g_suggestion
# True          173.678385   1536  266770.0
# False          52.421809   7373  386506.0

# %%
#calculate how many more views g_suggested articles received on average over non g_suggested articles
g = interim_df.groupby('g_suggestion')['views_1M_all'].mean()
g_impact = g[1]/g[0]
g_impact
# Out:
# 3.313094067561909

# %%
interim_df.groupby('g_suggestion').views_1M_all.mean().plot(kind='bar')


plt.title('Average Pageviews, Google Suggestions',fontsize=16)
plt.xlabel('Google Suggestion',fontsize=13)
plt.ylabel('Average Views',fontsize=13)
plt.xticks(rotation=360)
plt.tick_params(labelsize=12)
#plt.savefig('../../results/figs/pageviews/g_suggestion.png');

# %%
interim_df.groupby('g_suggestion').views_1M_all.mean()
# Out:
# g_suggestion
# False     52.421809
# True     173.678385
# Name: views_1M_all, dtype: float64

# %%
interim_df.groupby('g_suggestion').views_1M.mean().plot(kind='bar', color=["#FF8C00", "#1f77b4"]);

# %%
subset.groupby('g_suggestion').july_view_count_internal.mean().plot(kind='bar', color=["#FF8C00", "#1f77b4"]);

# %% [markdown]
# ## G_suggestions & Article Type

# %%
interim_df.groupby(['g_suggestion', 'article_type'], sort=True)['views_1M_all'].describe()
# Out:
#                             count        mean         std  min   25%   50%  \
# g_suggestion article_type
# False        expanded       756.0  228.259259  621.124384  0.0  12.0  43.5
#              new           6617.0   32.332175   80.660036  0.0   3.0   8.0
# True         expanded       672.0  298.269345  643.756605  0.0  17.0  85.5
#              new            864.0   76.774306  147.948407  0.0   7.0  18.5
#
#                               75%     max
# g_suggestion article_type
# False        expanded      194.00  9389.0
#              new            21.00  1884.0
# True         expanded      297.25  6790.0
#              new            76.25  1735.0

# %%
g = sns.catplot(x="article_type", y="views_1M_all", hue="g_suggestion", data=interim_df,
                height=6, kind="bar", palette=["#FF8C00", "#1f77b4"],legend_out = False) #palette="muted", 
g.despine(left=True)

# check axes and find which have legend
leg = g.axes.flat[0].get_legend()
new_title = 'List Type'
leg.set_title(new_title)
new_labels = ['Non-Google List', 'Google List']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.title("Pageviews by Article Type & List Type",fontsize=16)
plt.xlabel('Article Type: new or expanded',fontsize=13)
plt.ylabel('Average Views',fontsize=13)

plt.savefig('../../../results/figs/pageviews/avg_pv_type_suggestion.svg')
plt.show(g)

# %%
f = sns.catplot(x="article_type", y="views_1M", hue="g_suggestion", data=interim_df,
                height=6, kind="bar", palette=["#FF8C00", "#1f77b4"],legend_out = False) #palette="muted", 
f.despine(left=True)

# check axes and find which have legend
leg = f.axes.flat[0].get_legend()
new_title = 'List Type'
leg.set_title(new_title)
new_labels = ['Non-Google List', 'Google List']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.title("Pageviews by Article Type & List Type",fontsize=16)
plt.xlabel('Article Type: new or expanded',fontsize=13)
plt.ylabel('Average Views',fontsize=13)

#plt.savefig('../../../results/figs/pageviews/avg_pv_type_suggestion.svg')
plt.show(f)

# %%
interim_df.groupby(['g_suggestion', 'article_type'], sort=True)['views_1M'].describe()
# Out:
#                             count        mean         std  min  25%   50%  \
# g_suggestion article_type
# False        expanded       756.0   97.272487  335.106586  0.0  2.0   9.5
#              new           6617.0    8.363156   39.583794  0.0  0.0   1.0
# True         expanded       672.0  165.818452  415.747415  0.0  4.0  25.5
#              new            864.0   28.827546   88.885577  0.0  1.0   4.0
#
#                               75%     max
# g_suggestion article_type
# False        expanded       57.25  4890.0
#              new             4.00  1207.0
# True         expanded      128.25  4732.0
#              new            18.00  1269.0

# %%
subset.groupby(['g_suggestion', 'article_type'], sort=True)['july_view_count_internal'].describe()
# Out:
#                             count       mean         std  min   25%   50%  \
# g_suggestion article_type
# False        0               73.0   0.000000    0.000000  0.0   0.0   0.0
#              expanded        16.0  73.625000   65.084432  3.0  18.0  71.5
#              new           1167.0  99.326478  347.415970  0.0   1.0   8.0
# True         0               62.0   0.000000    0.000000  0.0   0.0   0.0
#              expanded        31.0  73.645161  104.525451  1.0  11.0  31.0
#              new            444.0  75.797297  222.456386  0.0   6.0  20.0
#
#                              75%     max
# g_suggestion article_type
# False        0               0.0     0.0
#              expanded      106.0   228.0
#              new            51.0  4776.0
# True         0               0.0     0.0
#              expanded      114.5   526.0
#              new            68.0  3760.0

# %%
subset = indonesia.copy(deep=True)
subset['article_type'] = subset['article_type'].str.replace('post', 'new')

e = sns.catplot(x="article_type", y="july_view_count_internal", hue="g_suggestion", data=subset,
                height=6, kind="bar", palette=["#FF8C00", "#1f77b4"],legend_out = False) #palette="muted", 
e.despine(left=True)

# check axes and find which have legend
leg = e.axes.flat[0].get_legend()
new_title = 'List Type'
leg.set_title(new_title)
new_labels = ['Non-Google List', 'Google List']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.title("Pageviews by Article Type & List Type",fontsize=16)
plt.xlabel('Article Type: new or expanded',fontsize=13)
plt.ylabel('Average Views',fontsize=13)

#plt.savefig('../../../results/figs/pageviews/avg_pv_type_suggestion.svg')
plt.show(e)

# %%
interim_df.groupby(['database_code','g_suggestion'], sort=True)['views_1M_all'].describe()
# Out:
#                              count        mean         std    min     25%  \
# database_code g_suggestion
# aswiki        False          190.0   52.452632   54.420520    3.0   20.00
# bnwiki        False         1044.0   88.387931  408.885612    0.0    4.00
#               True           145.0  325.572414  682.246379    3.0   40.00
# guwiki        False          136.0  270.389706  612.512448    4.0   52.00
#               True            54.0  208.518519  217.801601   29.0   81.00
# hiwiki        False          137.0  257.510949  299.953602    0.0   48.00
#               True           114.0  464.938596  500.742109   11.0  136.25
# knwiki        False          137.0   58.583942  145.784573    2.0   10.00
#               True            59.0  111.305085  134.713266    3.0   35.50
# mlwiki        False          197.0   18.269036   36.451165    0.0    5.00
#               True            19.0   33.736842   42.525603    7.0   14.00
# mrwiki        False           86.0  159.941860  316.864950    1.0   24.00
#               True            35.0  297.485714  961.147059    2.0   23.50
# orwiki        False           25.0    8.520000    7.124605    1.0    4.00
#               True           101.0   17.920792   28.089387    0.0    5.00
# pawiki        False         1367.0    8.927579   39.400985    0.0    2.00
#               True           359.0   13.353760   30.299071    0.0    4.00
# satwiki       False          476.0    3.962185    7.991221    0.0    1.00
# sawiki        False           19.0    7.473684    6.003410    1.0    3.00
# tawiki        False         2236.0   54.597496  176.755441    0.0    4.00
#               True           591.0  205.952623  510.380411    1.0   14.00
# tcywiki       False           23.0   24.913043   41.559282    2.0    4.50
# tewiki        False           20.0  216.200000  221.352921   10.0   40.25
#               True             4.0  420.500000  338.670440  134.0  206.75
# urwiki        False         1280.0   35.475781  119.891785    1.0    6.00
#               True            55.0  139.545455  268.133730    3.0   15.00
#
#                               50%     75%     max
# database_code g_suggestion
# aswiki        False          34.5   66.50   367.0
# bnwiki        False          10.0   34.00  9389.0
#               True          112.0  330.00  5828.0
# guwiki        False         188.0  249.00  5756.0
#               True          145.0  243.75  1331.0
# hiwiki        False         184.0  329.00  1884.0
#               True          289.5  600.50  3338.0
# knwiki        False          22.0   52.00  1337.0
#               True           67.0  119.00   710.0
# mlwiki        False          11.0   20.00   399.0
#               True           18.0   34.50   198.0
# mrwiki        False          34.5  114.50  2162.0
#               True           47.0  191.50  5713.0
# orwiki        False           8.0   10.00    35.0
#               True           11.0   19.00   233.0
# pawiki        False           4.0    7.00  1200.0
#               True            7.0   13.00   394.0
# satwiki       False           2.0    3.00    75.0
# sawiki        False           6.0    9.00    25.0
# tawiki        False           9.0   31.25  5423.0
#               True           58.0  184.50  6790.0
# tcywiki       False          12.0   24.00   191.0
# tewiki        False         178.5  205.75   831.0
#               True          326.0  539.75   896.0
# urwiki        False          12.0   26.25  2694.0
#               True           45.0  147.00  1591.0

# %%
pd.pivot_table(interim_df, values = 'views_1M_all', index = 'database_code',
               columns = 'g_suggestion',aggfunc ='mean').plot.bar().set_title("Pageviews per Wiki by Suggestion");

# %%
interim_df.groupby(['database_code','g_suggestion', 'article_type'], sort=True)['views_1M_all'].describe()
# Out:
#                                           count        mean          std  \
# database_code g_suggestion article_type
# aswiki        False        expanded        16.0   88.875000    82.917529
#                            new            174.0   49.103448    50.053967
# bnwiki        False        expanded        70.0  812.514286  1372.167309
#                            new            974.0   36.345996    72.520716
#               True         expanded        58.0  596.551724  1002.778984
#                            new             87.0  144.919540   174.235888
# guwiki        False        expanded        27.0  659.555556  1287.159285
#                            new            109.0  173.990826   151.224538
#               True         expanded        19.0  331.684211   311.278020
#                            new             35.0  141.657143    97.830268
# hiwiki        False        expanded        18.0  314.833333   265.551646
#                            new            119.0  248.840336   304.894007
#               True         expanded        39.0  752.512821   648.938075
#                            new             75.0  315.400000   316.845601
# knwiki        False        expanded        26.0  163.038462   297.051037
#                            new            111.0   34.117117    55.129391
#               True         expanded        34.0  152.588235   163.882463
#                            new             25.0   55.160000    35.068599
# mlwiki        False        expanded        27.0   47.074074    84.918027
#                            new            170.0   13.694118    16.671929
#               True         new             19.0   33.736842    42.525603
# mrwiki        False        expanded        22.0  362.181818   476.819386
#                            new             64.0   90.421875   201.213052
#               True         expanded        13.0  662.538462  1540.370281
#                            new             22.0   81.772727    92.660636
# orwiki        False        new             25.0    8.520000     7.124605
#               True         new            101.0   17.920792    28.089387
# pawiki        False        expanded       115.0   31.521739   121.098506
#                            new           1252.0    6.852236    17.536935
#               True         expanded       105.0   22.009524    37.393566
#                            new            254.0    9.775591    26.082585
# satwiki       False        expanded         5.0   17.400000    21.290843
#                            new            471.0    3.819533     7.664183
# sawiki        False        expanded         3.0   16.333333     8.082904
#                            new             16.0    5.812500     3.986958
# tawiki        False        expanded       268.0  173.925373   456.690794
#                            new           1968.0   38.347561    70.598949
#               True         expanded       375.0  282.296000   625.101447
#                            new            216.0   73.412037    85.365053
# tcywiki       False        expanded         5.0   52.400000    77.889666
#                            new             18.0   17.277778    22.885406
# tewiki        False        expanded         5.0  443.000000   342.636834
#                            new             15.0  140.600000    91.971890
#               True         expanded         3.0  483.666667   384.845857
#                            new              1.0  231.000000          NaN
# urwiki        False        expanded       149.0  164.181208   314.164960
#                            new           1131.0   18.519894    29.501617
#               True         expanded        26.0  260.115385   354.744677
#                            new             29.0   31.448276    26.351452
#
#                                            min     25%    50%      75%     max
# database_code g_suggestion article_type
# aswiki        False        expanded       22.0   31.00   70.5    99.00   367.0
#                            new             3.0   19.00   34.0    61.50   352.0
# bnwiki        False        expanded       17.0  121.25  326.0   831.50  9389.0
#                            new             0.0    4.00    9.0    25.00   522.0
#               True         expanded        8.0   89.75  295.5   618.50  5828.0
#                            new             3.0   28.00   58.0   194.00   827.0
# guwiki        False        expanded       24.0  101.50  252.0   442.00  5756.0
#                            new             4.0   44.00  185.0   232.00   825.0
#               True         expanded       54.0  129.50  228.0   407.00  1331.0
#                            new            29.0   72.50  110.0   188.00   438.0
# hiwiki        False        expanded       35.0  105.00  261.0   457.75   966.0
#                            new             0.0   43.50  178.0   313.00  1884.0
#               True         expanded       36.0  282.50  572.0  1031.00  3338.0
#                            new            11.0   85.00  258.0   396.00  1735.0
# knwiki        False        expanded       13.0   34.75   67.0   112.00  1337.0
#                            new             2.0    9.00   17.0    40.00   479.0
#               True         expanded       12.0   43.00   89.0   177.50   710.0
#                            new             3.0   31.00   43.0    73.00   155.0
# mlwiki        False        expanded        4.0   14.00   21.0    37.00   399.0
#                            new             0.0    5.00    9.0    17.00   137.0
#               True         new             7.0   14.00   18.0    34.50   198.0
# mrwiki        False        expanded       17.0   67.25  181.0   590.75  2162.0
#                            new             1.0   13.50   28.5    51.00  1158.0
#               True         expanded       13.0   46.00  189.0   506.00  5713.0
#                            new             2.0   18.25   40.5   108.75   324.0
# orwiki        False        new             1.0    4.00    8.0    10.00    35.0
#               True         new             0.0    5.00   11.0    19.00   233.0
# pawiki        False        expanded        0.0    3.50    7.0    15.50  1200.0
#                            new             0.0    1.00    3.0     7.00   177.0
#               True         expanded        0.0    5.00   10.0    22.00   277.0
#                            new             0.0    3.00    6.0    10.00   394.0
# satwiki       False        expanded        1.0    3.00    4.0    30.00    49.0
#                            new             0.0    1.00    2.0     3.00    75.0
# sawiki        False        expanded        9.0   12.00   15.0    20.00    25.0
#                            new             1.0    3.00    5.5     8.00    16.0
# tawiki        False        expanded        0.0    6.00   28.0   162.00  5423.0
#                            new             0.0    4.00    8.0    25.00  1024.0
#               True         expanded        1.0   17.00   87.0   271.00  6790.0
#                            new             2.0   11.00   33.0   110.50   452.0
# tcywiki       False        expanded        7.0   15.00   20.0    29.00   191.0
#                            new             2.0    4.00    9.0    23.75    99.0
# tewiki        False        expanded       35.0  139.00  543.0   667.00   831.0
#                            new            10.0   37.00  176.0   199.50   293.0
#               True         expanded      134.0  277.50  421.0   658.50   896.0
#                            new           231.0  231.00  231.0   231.00   231.0
# urwiki        False        expanded        5.0   28.00   61.0   136.00  2694.0
#                            new             1.0    5.00   10.0    20.00   378.0
#               True         expanded       12.0   46.50  152.5   291.25  1591.0
#                            new             3.0   12.00   26.0    45.00   122.0

# %%
#Avg Views by Wiki: g_suggestions vs. internal lists
interim_df.groupby(["database_code", "g_suggestion", "article_type"], sort=False)["views_1M_all"].mean().unstack().plot(kind="bar", figsize=(15,9), color=['g', 'b'],stacked=True);

# %%
#Avg Views by Wiki: Expanded vs New
n = interim_df.groupby(["database_code", "g_suggestion", "article_type"], sort=False)["views_1M_all"].mean().unstack().sort_values(['expanded'],ascending=False).plot(kind="bar", figsize=(15,9), color=['g', 'b'], stacked=True);

# %%
#Avg Views by Wiki: Expanded vs New
interim_df.groupby(["database_code", "article_type", "g_suggestion"], sort=False)["views_1M_all"].mean().unstack().plot(kind="bar", figsize=(15,9),stacked=True);

# %%
#Avg Views by Wiki: Expanded vs New - ordered
interim_df.groupby(["database_code", "article_type", "g_suggestion"], sort=False)["views_1M_all"].mean().unstack().sort_values([True],ascending=False).plot(kind="bar", figsize=(15,9), stacked=True);

# %% [markdown]
# ### Stub lifetime

# %%
interim_df.groupby('stub_lifetime_bins')['views_1M_all'].describe()
# Out:
#                      count        mean          std  min   25%    50%    75%  \
# stub_lifetime_bins
# (-200, -150]         255.0  650.443137  1089.192012  5.0  77.0  274.0  767.5
# (-150, -100]         387.0  299.956072   655.276310  0.0  18.5   85.0  319.0
# (-100, -50]          391.0  135.365729   296.003173  0.0   9.0   28.0  143.5
# (-50, 0]            2987.0   53.656512   125.657533  0.0   5.0   13.0   40.0
# (0, 5]              4889.0   32.344038    78.985097  0.0   3.0    7.0   18.0
#
#                        max
# stub_lifetime_bins
# (-200, -150]        9389.0
# (-150, -100]        6790.0
# (-100, -50]         3399.0
# (-50, 0]            2162.0
# (0, 5]              1884.0

# %%
interim_df.groupby('stub_lifetime_bins')['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['sum'], ascending=False)
# Out:
#                           mean  count       sum
# stub_lifetime_bins
# (-200, -150]        650.443137    255  165863.0
# (-50, 0]             53.656512   2987  160272.0
# (0, 5]               32.344038   4889  158130.0
# (-150, -100]        299.956072    387  116083.0
# (-100, -50]         135.365729    391   52928.0

# %%
interim_df.groupby(['database_code','g_suggestion', 'stub_lifetime_bins'], sort=True)['views_1M_all'].describe()[['count','mean']]
# Out:
#                                                count         mean
# database_code g_suggestion stub_lifetime_bins
# aswiki        False        (-100, -50]           2.0    86.500000
#                            (-50, 0]            109.0    60.045872
#                            (0, 5]               79.0    41.113924
# bnwiki        False        (-200, -150]         32.0  1343.187500
#                            (-150, -100]          6.0   363.500000
# ...                                              ...          ...
# urwiki        True         (-200, -150]          6.0   296.000000
#                            (-150, -100]          8.0   394.750000
#                            (-100, -50]           7.0   158.714286
#                            (-50, 0]             23.0    57.782609
#                            (0, 5]               11.0    27.363636
#
# [108 rows x 2 columns]

# %%
sns.lmplot(data = interim_df, x = 'stub_lifetime_M', y = 'views_1M_all', col='g_suggestion', fit_reg = True);

# %%
f = sns.lmplot(x = 'stub_lifetime_M', y = 'views_1M_all', hue='g_suggestion', col='database_code',
               data=interim_df, height=6, col_wrap=5, aspect=.4, x_jitter=.5)

f = (f.set_axis_labels("Stub Lifetime", "Pageviews")
      .set(xlim=(5, -200), ylim=(0, 3000),)
           #xticks=[---], yticks=[---])
      .fig.subplots_adjust(wspace=.1))

# %% [markdown]
# ## Page_length & Relative page length

# %% [raw]
# sns.lmplot(data = interim_df[new_articles], x = 'stub_stlb_charting', y = 'views_1M_all', fit_reg = True);

# %% [raw]
# #copied from above as a reminder
# plr_att_list = ['tcywiki', 'satwiki', 'pawiki']
# plr_limited_list = ['pawiki']
# solid_plr_wikis_df = interim_df[~interim_df['database_code'].isin(plr_att_list)]
# mid_plr_wikis_df = interim_df[~interim_df['database_code'].isin(plr_limited_list)]

# %%
interim_df.groupby('page_len_bins')['views_1M_all'].describe()
# Out:
#                    count         mean          std   min    25%    50%  \
# page_len_bins
# (0, 1000]            2.0   106.500000   147.785317   2.0  54.25  106.5
# (1000, 5000]       526.0    25.889734   122.039538   1.0   5.00   10.0
# (5000, 10000]     2860.0    29.296154    97.558108   0.0   2.00    6.0
# (10000, 20000]    4637.0    66.643520   173.968068   0.0   4.00   12.0
# (20000, 30000]     614.0   191.599349   510.162475   0.0  11.00   32.0
# (30000, 40000]     154.0   368.064935   792.647476   1.0  22.00   94.5
# (40000, 50000]      51.0   485.921569  1199.490756   3.0  25.00   63.0
# (50000, 100000]     57.0   704.807018  1406.790971   1.0  49.00  196.0
# (100000, 200000]     6.0  1150.000000  1636.529010  18.0  19.50  422.0
#
#                       75%     max
# page_len_bins
# (0, 1000]          158.75   211.0
# (1000, 5000]        21.00  2694.0
# (5000, 10000]       15.00  2065.0
# (10000, 20000]      50.00  4269.0
# (20000, 30000]     174.75  6790.0
# (30000, 40000]     379.00  5828.0
# (40000, 50000]     196.50  5756.0
# (50000, 100000]    812.00  9389.0
# (100000, 200000]  1618.75  4135.0

# %%
sns.lmplot(data = interim_df, x = 'page_len', y = 'views_1M_all', fit_reg = True);

# %%
#Higher values here denote proximity to the median relative length of a wiki's featured article, 
#for example a '5' here is equal to a 1.0 score noting a full matches to the length of the median length of a featured article in that wiki  
solid_plr_wikis_df.groupby('rplb_charting').views_1M_all.mean().plot(kind='bar');

# %%
#pageviews by rel_page_len_bins per wiki
#attention: PA wiki had 1 featured article
#attention: tcywiki and satwiki had zero featured articles, so these use the median article length as their anchor
pv_given_rplb_by_wiki = interim_df.groupby(['database_code', 'rel_page_len_bins'], sort=True)['views_1M_all'].describe()

# %%
pv_given_rplb_by_wiki
# Out:
#                                   count         mean          std     min  \
# database_code rel_page_len_bins
# aswiki        (0.0, 0.2]          161.0    48.142857    49.761413     3.0
#               (0.2, 0.5]           26.0    73.538462    74.610043     7.0
#               (0.5, 0.7]            1.0   105.000000          NaN   105.0
#               (0.9, 1.0]            2.0    99.000000    52.325902    62.0
# bnwiki        (0.0, 0.2]         1138.0    80.565905   243.454820     0.0
#               (0.2, 0.5]           50.0   873.320000  1659.352362    12.0
#               (0.7, 0.9]            1.0  4135.000000          NaN  4135.0
# guwiki        (0.0, 0.2]           24.0   147.458333   107.727910    15.0
#               (0.2, 0.5]          146.0   213.246575   332.315919     4.0
#               (0.5, 0.7]           15.0   370.133333   583.552895    34.0
#               (0.7, 0.9]            3.0   240.333333   238.286242    14.0
#               (0.9, 1.0]            2.0  3543.500000  3128.947507  1331.0
# hiwiki        (0.0, 0.2]          217.0   330.004608   397.473532     0.0
#               (0.2, 0.5]           32.0   447.468750   453.141506    36.0
#               (0.5, 0.7]            1.0   468.000000          NaN   468.0
#               (0.9, 1.0]            1.0  1884.000000          NaN  1884.0
# knwiki        (0.2, 0.5]          129.0    59.201550    97.422435     2.0
#               (0.5, 0.7]           33.0    60.333333    88.859322     2.0
#               (0.7, 0.9]           19.0    79.052632    96.676708     7.0
#               (0.9, 1.0]           15.0   230.866667   379.650378     8.0
# mlwiki        (0.0, 0.2]          186.0    17.849462    36.395707     0.0
#               (0.2, 0.5]           30.0    30.666667    40.606041     1.0
# mrwiki        (0.0, 0.2]           88.0   113.681818   210.380910     1.0
#               (0.2, 0.5]           31.0   427.709677  1065.229590    13.0
#               (0.5, 0.7]            2.0   452.000000   363.452886   195.0
# orwiki        (0.2, 0.5]           83.0    16.228916    26.997888     0.0
#               (0.5, 0.7]           34.0    18.823529    24.913755     1.0
#               (0.7, 0.9]            6.0     3.833333     3.544949     0.0
#               (0.9, 1.0]            3.0     4.333333     1.527525     3.0
# pawiki        (0.0, 0.2]            1.0     2.000000          NaN     2.0
# orwiki        (0.2, 0.5]            6.00    11.0    17.00   233.0
#               (0.5, 0.7]            4.00     9.5    19.00   110.0
#               (0.7, 0.9]            1.25     3.0     6.25     9.0
#               (0.9, 1.0]            3.50     4.0     5.00     6.0
# pawiki        (0.0, 0.2]            2.00     2.0     2.00     2.0
#               (0.2, 0.5]            2.00     4.0     8.00  1200.0
#               (0.5, 0.7]            3.00     6.0    11.25   168.0
#               (0.7, 0.9]            6.00    14.0    27.00   277.0
#               (0.9, 1.0]            3.00     8.0    58.25   287.0
# satwiki       (0.9, 1.0]            1.00     2.0     3.00    75.0
# sawiki        (0.2, 0.5]            3.00     6.0     9.00    16.0
#               (0.5, 0.7]            4.00     6.5     8.00     8.0
#               (0.9, 1.0]            8.50    14.0    19.50    25.0
# tawiki        (0.0, 0.2]            4.00    10.0    43.75  2360.0
#               (0.2, 0.5]            9.00    29.0   174.25  6790.0
#               (0.5, 0.7]           52.25   598.5  1209.00  5423.0
#               (0.7, 0.9]          408.25  1295.5  2539.75  3916.0
#               (0.9, 1.0]          199.00  1176.0  1509.00  1558.0
# tcywiki       (0.9, 1.0]            4.50    12.0    24.00   191.0
# tewiki        (0.2, 0.5]          111.00   187.0   202.50   293.0
#               (0.5, 0.7]           27.25   103.5   298.00   667.0
#               (0.7, 0.9]          179.50   316.0   728.50   896.0
#               (0.9, 1.0]          143.25   276.5   409.75   543.0
# urwiki        (0.0, 0.2]            6.00    11.0    24.00  2694.0
#               (0.2, 0.5]           12.00    24.5    57.25  1591.0
#               (0.5, 0.7]           11.25    27.5    98.75  1031.0
#               (0.7, 0.9]           15.25    51.5    96.25   207.0
#               (0.9, 1.0]           27.00    49.5   222.75   823.0

# %%
interim_df.groupby(['database_code','g_suggestion', 'rel_page_len_bins'], sort=False)['views_1M_all'].describe()[['count','mean']]
# Out:
#                                                count         mean
# database_code g_suggestion rel_page_len_bins
# hiwiki        True         (0.0, 0.2]          101.0   442.613861
#                            (0.2, 0.5]           13.0   638.384615
#               False        (0.0, 0.2]          116.0   231.956897
#                            (0.2, 0.5]           19.0   316.842105
#                            (0.5, 0.7]            1.0   468.000000
# ...                                              ...          ...
# bnwiki        True         (0.0, 0.2]          129.0   268.426357
#                            (0.2, 0.5]           16.0   786.312500
#               False        (0.0, 0.2]         1009.0    56.548067
#                            (0.2, 0.5]           34.0   914.264706
#                            (0.7, 0.9]            1.0  4135.000000
#
# [86 rows x 2 columns]

# %%
interim_df.groupby(['database_code','g_suggestion', 'rel_page_len_bins'], sort=False)['views_1M_all'].describe()[['count','mean']].sort_values(by=['count', 'mean'], ascending=False)
# Out:
#                                                count        mean
# database_code g_suggestion rel_page_len_bins
# tawiki        False        (0.0, 0.2]         1888.0   39.895127
# pawiki        False        (0.2, 0.5]         1278.0    8.244131
# urwiki        False        (0.0, 0.2]         1097.0   25.527803
# bnwiki        False        (0.0, 0.2]         1009.0   56.548067
# satwiki       False        (0.9, 1.0]          476.0    3.962185
# ...                                              ...         ...
# hiwiki        False        (0.5, 0.7]            1.0  468.000000
# guwiki        True         (0.7, 0.9]            1.0  218.000000
# knwiki        True         (0.9, 1.0]            1.0  155.000000
# aswiki        False        (0.5, 0.7]            1.0  105.000000
# pawiki        False        (0.0, 0.2]            1.0    2.000000
#
# [86 rows x 2 columns]

# %%
interim_df.groupby(['database_code','g_suggestion', 'rel_page_len_bins'], sort=False)['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False)
# Out:
#                                                 mean  count     sum
# database_code g_suggestion rel_page_len_bins
# guwiki        False        (0.9, 1.0]         5756.0    1.0  5756.0
# bnwiki        False        (0.7, 0.9]         4135.0    1.0  4135.0
# tawiki        True         (0.7, 0.9]         2213.0    2.0  4426.0
# hiwiki        False        (0.9, 1.0]         1884.0    1.0  1884.0
# tawiki        True         (0.9, 1.0]         1558.0    1.0  1558.0
# ...                                              ...    ...     ...
# tewiki        True         (0.5, 0.7]            NaN    NaN     NaN
#                            (0.9, 1.0]            NaN    NaN     NaN
# urwiki        True         (0.5, 0.7]            NaN    NaN     NaN
#                            (0.7, 0.9]            NaN    NaN     NaN
#                            (0.9, 1.0]            NaN    NaN     NaN
#
# [150 rows x 3 columns]

# %%
interim_df['rel_page_len_bins'].unique()
# Out:
# [(0.2, 0.5], (0.0, 0.2], (0.9, 1.0], (0.5, 0.7], (0.7, 0.9]]
# Categories (5, interval[float64]): [(0.0, 0.2] < (0.2, 0.5] < (0.5, 0.7] < (0.7, 0.9] < (0.9, 1.0]]

# %% [raw]
# 1 = 0.0 - 0.2
# 2 = 0.2 - 0.5
# 3 = 0.5 - 0.7
# 4 = 0.7 - 0.9
# 5 = 0.9 - 1.0

# %%
sns.lmplot(data = interim_df, x = 'rplb_charting', y = 'views_1M_all', fit_reg = True);
#sns.plt.xlim(0, 6)
#sns.plt.title('---')
#sns.plt.show()

# %%
#Expanded articles, article length and views
sns.lmplot(data = interim_df[expanded_articles], x = 'rplb_charting', y = 'views_1M_all', fit_reg = True);

# %%
#New articles, article length and views
sns.lmplot(data = interim_df[new_articles], x = 'rplb_charting', y = 'views_1M_all', fit_reg = True);

# %% [markdown]
# ## Topics

# %%
indonesia.groupby('predicted_label_1')['july_view_count_internal'].describe().sort_values(by=['count', 'mean'], ascending=False)
# Out:
#                                              count        mean          std  \
# predicted_label_1
# Culture.Biography.Biography*                 259.0   46.135135   114.542505
# STEM.STEM*                                   236.0   78.576271   171.626582
# STEM.Medicine_&_Health                        99.0   74.898990   164.368271
# STEM.Biology                                  84.0   21.583333    47.715828
# Geography.Regions.Asia.Asia*                  54.0   45.796296   123.342196
# Geography.Regions.Asia.Southeast_Asia         41.0   69.292683   136.404590
# Geography.Regions.Americas.North_America      39.0  153.871795   644.351334
# Culture.Media.Media*                          38.0  193.473684   569.548457
# History_and_Society.Transportation            34.0   46.029412    90.265764
# Culture.Literature                            33.0   16.000000    19.915446
# Culture.Sports                                32.0   89.968750   431.622631
# Geography.Geographical                        23.0   16.478261    53.337578
# History_and_Society.Politics_and_government   18.0  104.388889   204.136672
# Culture.Philosophy_and_religion               16.0  105.062500   189.246037
# STEM.Engineering                              15.0   18.133333    30.677741
# Geography.Regions.Europe.Eastern_Europe        35.0
# Geography.Regions.Africa.Northern_Africa       31.0
# Culture.Visual_arts.Comics_and_Anime           15.0
# Geography.Regions.Americas.Central_America     17.0
# Culture.Performing_arts                         6.0
# Geography.Regions.Africa.Africa*              572.0
# STEM.Libraries_&_Information                  235.0

# %%
#get only topics with more than 25 associated articles
topics_grouped = interim_df.groupby('predicted_label_1')
topics_over_25 = interim_df[interim_df.groupby('predicted_label_1')['views_1M_all'].transform('count') > 25]

# %%
#top topics by number of associated articles
topics_over_25.groupby('predicted_label_1').size().sort_values( ascending=False)
# Out:
# predicted_label_1
# Culture.Biography.Biography*                   2269
# Geography.Regions.Asia.South_Asia              1833
# 0                                               928
# Geography.Regions.Asia.Asia*                    877
# STEM.STEM*                                      661
# Culture.Sports                                  185
# History_and_Society.Politics_and_government     183
# Culture.Media.Films                             174
# Geography.Geographical                          153
# Culture.Philosophy_and_religion                 152
# History_and_Society.Society                     110
# Geography.Regions.Asia.Southeast_Asia           109
# Culture.Media.Media*                            100
# STEM.Biology                                     96
# Geography.Regions.Europe.Europe*                 78
# Culture.Food_and_drink                           78
# Geography.Regions.Asia.West_Asia                 78
# Culture.Literature                               71
# History_and_Society.History                      69
# STEM.Medicine_&_Health                           67
# History_and_Society.Transportation               63
# History_and_Society.Military_and_warfare         51
# History_and_Society.Business_and_economics       47
# Culture.Visual_arts.Visual_arts*                 42
# Geography.Regions.Asia.East_Asia                 37
# STEM.Chemistry                                   35
# Culture.Linguistics                              33
# Culture.Media.Television                         32
# STEM.Engineering                                 32
# History_and_Society.Education                    30
# dtype: int64

# %%
topics_over_25.groupby('predicted_label_1')['views_1M_all'].describe().sort_values(by=['mean'], ascending=False)
# Out:
#                                               count        mean         std  \
# predicted_label_1
# Geography.Geographical                        153.0  189.326797  856.421255
# Culture.Linguistics                            33.0  174.181818  260.609197
# Culture.Philosophy_and_religion               152.0  166.618421  494.879194
# Culture.Food_and_drink                         78.0  166.166667  303.488095
# History_and_Society.Transportation             63.0  154.698413  206.226906
# Geography.Regions.Asia.Asia*                  877.0  118.824401  376.468111
# STEM.Medicine_&_Health                         67.0  106.089552  214.690668
# History_and_Society.Business_and_economics     47.0  104.638298  206.015663
# Culture.Media.Films                           174.0  102.224138  150.574089
# Geography.Regions.Europe.Europe*               78.0   97.051282  659.651205
# STEM.STEM*                                    661.0   95.580938  273.989982
# Culture.Media.Media*                          100.0   91.120000  293.145301
# History_and_Society.Society                   110.0   80.854545  231.869223
# Geography.Regions.Asia.South_Asia            1833.0   69.770322  225.198094
# STEM.Biology                                   96.0   69.239583  114.377836
# Culture.Media.Television                       32.0   66.218750   90.417931
# History_and_Society.Military_and_warfare       51.0   59.411765  145.392596
# Culture.Visual_arts.Visual_arts*               42.0   55.952381   68.410865
# Culture.Biography.Biography*                 2269.0   54.472896  268.573496
# STEM.Engineering                               32.0   48.281250  145.751940
# STEM.Chemistry                                 35.0   48.228571  114.402048
# 0                                             928.0   47.128233  166.652031
# Geography.Regions.Asia.Southeast_Asia         109.0   47.045872   82.180401
# History_and_Society.Business_and_economics   104.638298     47    4918.0
# Culture.Media.Films                          102.224138    174   17787.0
# Geography.Regions.Europe.Europe*              97.051282     78    7570.0
# STEM.STEM*                                    95.580938    661   63179.0
# Culture.Media.Media*                          91.120000    100    9112.0
# History_and_Society.Society                   80.854545    110    8894.0
# Geography.Regions.Asia.South_Asia             69.770322   1833  127889.0
# STEM.Biology                                  69.239583     96    6647.0
# Culture.Media.Television                      66.218750     32    2119.0
# History_and_Society.Military_and_warfare      59.411765     51    3030.0
# Culture.Visual_arts.Visual_arts*              55.952381     42    2350.0
# Culture.Biography.Biography*                  54.472896   2269  123599.0
# STEM.Engineering                              48.281250     32    1545.0
# STEM.Chemistry                                48.228571     35    1688.0
# 0                                             47.128233    928   43735.0
# Geography.Regions.Asia.Southeast_Asia         47.045872    109    5128.0
# History_and_Society.History                   45.985507     69    3173.0
# Culture.Literature                            37.211268     71    2642.0
# History_and_Society.Politics_and_government   34.568306    183    6326.0
# Geography.Regions.Asia.West_Asia              32.038462     78    2499.0
# History_and_Society.Education                 29.100000     30     873.0
# Culture.Sports                                27.481081    185    5084.0
# Geography.Regions.Asia.East_Asia              21.810811     37     807.0

# %%
topics_over_25.groupby('predicted_label_1')['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['sum'], ascending=False)
# Out:
#                                                    mean  count       sum
# predicted_label_1
# Geography.Regions.Asia.South_Asia             69.770322   1833  127889.0
# Culture.Biography.Biography*                  54.472896   2269  123599.0
# Geography.Regions.Asia.Asia*                 118.824401    877  104209.0
# STEM.STEM*                                    95.580938    661   63179.0
# 0                                             47.128233    928   43735.0
# Geography.Geographical                       189.326797    153   28967.0
# Culture.Philosophy_and_religion              166.618421    152   25326.0
# Culture.Media.Films                          102.224138    174   17787.0
# Culture.Food_and_drink                       166.166667     78   12961.0
# History_and_Society.Transportation           154.698413     63    9746.0
# Culture.Media.Media*                          91.120000    100    9112.0
# History_and_Society.Society                   80.854545    110    8894.0
# Geography.Regions.Europe.Europe*              97.051282     78    7570.0
# STEM.Medicine_&_Health                       106.089552     67    7108.0
# STEM.Biology                                  69.239583     96    6647.0
# History_and_Society.Politics_and_government   34.568306    183    6326.0
# Culture.Linguistics                          174.181818     33    5748.0
# Geography.Regions.Asia.Southeast_Asia         47.045872    109    5128.0
# Culture.Sports                                27.481081    185    5084.0
# History_and_Society.Business_and_economics   104.638298     47    4918.0
# History_and_Society.History                   45.985507     69    3173.0
# History_and_Society.Military_and_warfare      59.411765     51    3030.0
# Culture.Literature                            37.211268     71    2642.0
# Geography.Regions.Asia.West_Asia              32.038462     78    2499.0
# Culture.Visual_arts.Visual_arts*              55.952381     42    2350.0
# Culture.Media.Television                      66.218750     32    2119.0
# STEM.Chemistry                                48.228571     35    1688.0
# STEM.Engineering                              48.281250     32    1545.0
# History_and_Society.Education                 29.100000     30     873.0
# Geography.Regions.Asia.East_Asia              21.810811     37     807.0

# %%
#get top ~10 topics

top_topics_df = interim_df[interim_df.groupby('predicted_label_1')['views_1M_all'].transform('count') > 100]

#topics_grouped = interim_df.groupby('predicted_label_1')
#df1 = interim_df[interim_df.groupby('predicted_label_1')['views_1M_all'].transform('count') > 25]

# %%
top_topics_df.groupby(["article_type", 'predicted_label_1'])['views_1M_all'].describe().sort_values(by=['predicted_label_1'], ascending=False)
# Out:
#                                                            count        mean  \
# article_type predicted_label_1
# new          STEM.STEM*                                    523.0   41.604207
# expanded     STEM.STEM*                                    138.0  300.144928
#              History_and_Society.Society                    21.0  166.285714
# new          History_and_Society.Society                    89.0   60.696629
#              History_and_Society.Politics_and_government   176.0   19.806818
# expanded     History_and_Society.Politics_and_government     7.0  405.714286
#              Geography.Regions.Asia.Southeast_Asia           2.0  171.500000
# new          Geography.Regions.Asia.Southeast_Asia         107.0   44.719626
# expanded     Geography.Regions.Asia.South_Asia             226.0  300.924779
# new          Geography.Regions.Asia.South_Asia            1607.0   37.261979
#              Geography.Regions.Asia.Asia*                  718.0   46.101671
# expanded     Geography.Regions.Asia.Asia*                  159.0  447.220126
#              Geography.Geographical                         42.0  577.833333
# new          Geography.Geographical                        111.0   42.324324
# expanded     Culture.Sports                                 40.0   44.825000
# new          Culture.Sports                                145.0   22.696552
# expanded     Culture.Philosophy_and_religion                54.0  382.777778
# new          Culture.Philosophy_and_religion                98.0   47.510204
# expanded     Culture.Media.Films                            21.0  176.000000
# new          Culture.Media.Films                           153.0   92.098039
#              Culture.Biography.Biography*                 1813.0   25.381136
# expanded     Culture.Biography.Biography*                  456.0  170.138158
#              0                                              61.0  235.754098
# new          0                                             867.0   33.856978
#
#                                                                   std   min  \
# article_type predicted_label_1
# new          STEM.STEM*                                     72.935035   0.0
# expanded     STEM.STEM*                                    536.759587   2.0
#              History_and_Society.Society                   295.043072   4.0
# new          History_and_Society.Society                   211.320599   1.0
#              History_and_Society.Politics_and_government    29.964878   0.0
# expanded     History_and_Society.Politics_and_government   383.650759  12.0
#              Geography.Regions.Asia.Southeast_Asia         221.324423  15.0
# new          Geography.Regions.Asia.Southeast_Asia          78.238242   0.0
# expanded     Geography.Regions.Asia.South_Asia             541.836629   0.0
# new          Geography.Regions.Asia.South_Asia              90.237464   0.0
#              Geography.Regions.Asia.Asia*                  116.587949   0.0
# expanded     Geography.Regions.Asia.Asia*                  769.117394   1.0
#              Geography.Geographical                       1575.909028   6.0
# new          Geography.Geographical                         91.671961   0.0
# expanded     Culture.Sports                                 81.419738   0.0
# new          Culture.Sports                                 73.564345   0.0
# expanded     Culture.Philosophy_and_religion               784.177172   5.0
# new          Culture.Philosophy_and_religion                70.035226   1.0
# expanded     Culture.Media.Films                           238.010504   2.0
# new          Culture.Media.Films                           132.272235   1.0
#              Culture.Biography.Biography*                   76.608771   0.0
# expanded     Culture.Biography.Biography*                  565.151584   0.0
#              0                                             542.693212   3.0
# new          0                                              81.494827   0.0
#
#                                                             25%    50%  \
# article_type predicted_label_1
# new          STEM.STEM*                                    6.00   15.0
# expanded     STEM.STEM*                                   53.00  114.0
#              History_and_Society.Society                  25.00   76.0
# new          History_and_Society.Society                   7.00   13.0
#              History_and_Society.Politics_and_government   3.00    6.0
# expanded     History_and_Society.Politics_and_government  81.00  324.0
#              Geography.Regions.Asia.Southeast_Asia        93.25  171.5
# new          Geography.Regions.Asia.Southeast_Asia         3.00    6.0
# expanded     Geography.Regions.Asia.South_Asia            10.25   69.0
# new          Geography.Regions.Asia.South_Asia             2.00    6.0
#              Geography.Regions.Asia.Asia*                  3.00    8.0
# expanded     Geography.Regions.Asia.Asia*                 26.50  172.0
#              Geography.Geographical                       48.25  128.5
# new          Geography.Geographical                        5.00    9.0
# expanded     Culture.Sports                                4.00    6.5
# new          Culture.Sports                                2.00    4.0
# expanded     Culture.Philosophy_and_religion              45.75  154.0
# new          Culture.Philosophy_and_religion               9.25   18.0
# expanded     Culture.Media.Films                          38.00  100.0
# new          Culture.Media.Films                          16.00   39.0
#              Culture.Biography.Biography*                  3.00    7.0
# expanded     Culture.Biography.Biography*                  7.00   21.0
#              0                                            28.00   71.0
# new          0                                             3.00    9.0
#
#                                                              75%     max
# article_type predicted_label_1
# new          STEM.STEM*                                    35.50   600.0
# expanded     STEM.STEM*                                   308.50  4236.0
#              History_and_Society.Society                  175.00  1369.0
# new          History_and_Society.Society                   26.00  1884.0
#              History_and_Society.Politics_and_government   22.50   179.0
# expanded     History_and_Society.Politics_and_government  662.50  1017.0
#              Geography.Regions.Asia.Southeast_Asia        249.75   328.0
# new          Geography.Regions.Asia.Southeast_Asia         13.50   348.0
# expanded     Geography.Regions.Asia.South_Asia            371.50  4100.0
# new          Geography.Regions.Asia.South_Asia             22.00  1158.0
#              Geography.Regions.Asia.Asia*                  27.00  1515.0
# expanded     Geography.Regions.Asia.Asia*                 567.00  5713.0
#              Geography.Geographical                       320.25  9389.0
# new          Geography.Geographical                        23.50   687.0
# expanded     Culture.Sports                                50.50   346.0
# new          Culture.Sports                                10.00   522.0
# expanded     Culture.Philosophy_and_religion              370.50  5423.0
# new          Culture.Philosophy_and_religion               52.25   390.0
# expanded     Culture.Media.Films                          298.00  1083.0
# new          Culture.Media.Films                          108.00   950.0
#              Culture.Biography.Biography*                  14.00  1735.0
# expanded     Culture.Biography.Biography*                 101.00  6790.0
#              0                                            215.00  3456.0
# new          0                                             25.00  1024.0

# %%
top_topics_df.groupby(['predicted_label_1',"g_suggestion", ])['views_1M_all'].describe().sort_values(by=['predicted_label_1'], ascending=False)
# Out:
#                                                            count        mean  \
# predicted_label_1                           g_suggestion
# STEM.STEM*                                  True           147.0  178.870748
#                                             False          514.0   71.760700
# History_and_Society.Society                 True            14.0  181.714286
#                                             False           96.0   66.145833
# History_and_Society.Politics_and_government True            10.0  201.200000
#                                             False          173.0   24.936416
# Geography.Regions.Asia.Southeast_Asia       True             4.0    7.000000
#                                             False          105.0   48.571429
# Geography.Regions.Asia.South_Asia           True           281.0  221.765125
#                                             False         1552.0   42.250644
# Geography.Regions.Asia.Asia*                True           174.0  326.695402
#                                             False          703.0   67.374111
# Geography.Geographical                      True            29.0  302.068966
#                                             False          124.0  162.959677
# Culture.Sports                              True            44.0   57.977273
#                                             False          141.0   17.964539
# Culture.Philosophy_and_religion             True            29.0  307.103448
#                                             False          123.0  133.495935
# Culture.Media.Films                         True            92.0  106.847826
#                                             False           82.0   97.036585
# Culture.Biography.Biography*                True           320.0  137.700000
#                                             False         1949.0   40.808107
# 0                                           True            43.0  138.720930
#                                             False          885.0   42.677966
#
#                                                                  std  min  \
# predicted_label_1                           g_suggestion
# STEM.STEM*                                  True          445.239220  2.0
#                                             False         193.925196  0.0
# History_and_Society.Society                 True          360.207083  4.0
#                                             False         205.459125  1.0
# History_and_Society.Politics_and_government True          348.963163  6.0
#                                             False          61.623685  0.0
# Geography.Regions.Asia.Southeast_Asia       True            1.825742  5.0
#                                             False          83.362145  0.0
# Geography.Regions.Asia.South_Asia           True          440.083703  0.0
#                                             False         141.404472  0.0
# Geography.Regions.Asia.Asia*                True          612.624294  0.0
#                                             False         266.469015  0.0
# Geography.Geographical                      True          807.576486  2.0
#                                             False         868.461235  0.0
# Culture.Sports                              True           87.380613  1.0
#                                             False          69.238966  0.0
# Culture.Philosophy_and_religion             True          437.647228  5.0
#                                             False         503.353074  1.0
# Culture.Media.Films                         True          145.133961  1.0
#                                             False         157.188528  1.0
# Culture.Biography.Biography*                True          510.879809  0.0
#                                             False         199.789209  0.0
# 0                                           True          161.708339  2.0
#                                             False         165.691104  0.0
#
#                                                             25%    50%  \
# predicted_label_1                           g_suggestion
# STEM.STEM*                                  True          14.00   37.0
#                                             False          7.00   18.0
# History_and_Society.Society                 True          19.50   33.0
#                                             False          8.00   15.0
# History_and_Society.Politics_and_government True          12.50   45.0
#                                             False          3.00    6.0
# Geography.Regions.Asia.Southeast_Asia       True           5.75    7.0
#                                             False          3.00    6.0
# Geography.Regions.Asia.South_Asia           True          11.00   57.0
#                                             False          2.00    5.0
# Geography.Regions.Asia.Asia*                True          19.00  124.0
#                                             False          3.00    8.0
# Geography.Geographical                      True          14.00   52.0
#                                             False          5.00   11.0
# Culture.Sports                              True           5.00   17.0
#                                             False          2.00    4.0
# Culture.Philosophy_and_religion             True          16.00   86.0
#                                             False         11.50   24.0
# Culture.Media.Films                         True          17.50   45.5
#                                             False         16.25   43.0
# Culture.Biography.Biography*                True           6.00   17.0
#                                             False          3.00    7.0
# 0                                           True          16.00   56.0
#                                             False          4.00   10.0
#
#                                                              75%     max
# predicted_label_1                           g_suggestion
# STEM.STEM*                                  True          148.50  4236.0
#                                             False          60.00  2622.0
# History_and_Society.Society                 True          166.50  1369.0
#                                             False          35.50  1884.0
# History_and_Society.Politics_and_government True          104.25  1017.0
#                                             False          24.00   660.0
# Geography.Regions.Asia.Southeast_Asia       True            8.25     9.0
#                                             False          15.00   348.0
# Geography.Regions.Asia.South_Asia           True          227.00  4100.0
#                                             False          21.00  3399.0
# Geography.Regions.Asia.Asia*                True          408.75  5713.0
#                                             False          26.50  4135.0
# Geography.Geographical                      True          192.00  4269.0
#                                             False          75.00  9389.0
# Culture.Sports                              True           71.75   346.0
#                                             False           7.00   522.0
# Culture.Philosophy_and_religion             True          324.00  1591.0
#                                             False          91.50  5423.0
# Culture.Media.Films                         True          125.50   950.0
#                                             False         101.75  1083.0
# Culture.Biography.Biography*                True          102.00  6790.0
#                                             False          17.00  5756.0
# 0                                           True          220.50   665.0
#                                             False          27.00  3456.0

# %%
top_topics_df.groupby(["article_type", 'predicted_label_1', "g_suggestion"])['views_1M_all'].describe().sort_values(by=['predicted_label_1', "g_suggestion"], ascending=False)
# Out:
#                                                                         count  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True            62.0
# new          STEM.STEM*                                  True            85.0
# expanded     STEM.STEM*                                  False           76.0
# new          STEM.STEM*                                  False          438.0
# expanded     History_and_Society.Society                 True             8.0
# new          History_and_Society.Society                 True             6.0
# expanded     History_and_Society.Society                 False           13.0
# new          History_and_Society.Society                 False           83.0
# expanded     History_and_Society.Politics_and_government True             2.0
# new          History_and_Society.Politics_and_government True             8.0
# expanded     History_and_Society.Politics_and_government False            5.0
# new          History_and_Society.Politics_and_government False          168.0
#              Geography.Regions.Asia.Southeast_Asia       True             4.0
# expanded     Geography.Regions.Asia.Southeast_Asia       False            2.0
# new          Geography.Regions.Asia.Southeast_Asia       False          103.0
# expanded     Geography.Regions.Asia.South_Asia           True           151.0
# new          Geography.Regions.Asia.South_Asia           True           130.0
# expanded     Geography.Regions.Asia.South_Asia           False           75.0
# new          Geography.Regions.Asia.South_Asia           False         1477.0
# expanded     Geography.Regions.Asia.Asia*                True           120.0
# new          Geography.Regions.Asia.Asia*                True            54.0
# expanded     Geography.Regions.Asia.Asia*                False           39.0
# new          Geography.Regions.Asia.Asia*                False          664.0
# expanded     Geography.Geographical                      True            19.0
# new          Geography.Geographical                      True            10.0
# expanded     Geography.Geographical                      False           23.0
# new          Geography.Geographical                      False          101.0
# expanded     Culture.Sports                              True            17.0
# new          Culture.Sports                              True            27.0
# expanded     Culture.Sports                              False           23.0
# new          Culture.Sports                              False          118.0
# expanded     Culture.Philosophy_and_religion             True            18.0
# new          Culture.Philosophy_and_religion             True            11.0
# expanded     Culture.Philosophy_and_religion             False           36.0
# new          Culture.Philosophy_and_religion             False           87.0
# expanded     Culture.Media.Films                         True            17.0
# new          Culture.Media.Films                         True            75.0
# expanded     Culture.Media.Films                         False            4.0
# new          Culture.Media.Films                         False           78.0
# expanded     Culture.Biography.Biography*                True           130.0
# new          Culture.Biography.Biography*                True           190.0
# expanded     Culture.Biography.Biography*                False          326.0
# new          Culture.Biography.Biography*                False         1623.0
# expanded     0                                           True            18.0
# new          0                                           True            25.0
# expanded     0                                           False           43.0
# new          0                                           False          842.0
#
#                                                                              mean  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True          339.645161
# new          STEM.STEM*                                  True           61.600000
# expanded     STEM.STEM*                                  False         267.921053
# new          STEM.STEM*                                  False          37.723744
# expanded     History_and_Society.Society                 True          303.625000
# new          History_and_Society.Society                 True           19.166667
# expanded     History_and_Society.Society                 False          81.769231
# new          History_and_Society.Society                 False          63.698795
# expanded     History_and_Society.Politics_and_government True          841.000000
# new          History_and_Society.Politics_and_government True           41.250000
# expanded     History_and_Society.Politics_and_government False         231.600000
# new          History_and_Society.Politics_and_government False          18.785714
#              Geography.Regions.Asia.Southeast_Asia       True            7.000000
# expanded     Geography.Regions.Asia.Southeast_Asia       False         171.500000
# new          Geography.Regions.Asia.Southeast_Asia       False          46.184466
# expanded     Geography.Regions.Asia.South_Asia           True          312.814570
# new          Geography.Regions.Asia.South_Asia           True          116.007692
# expanded     Geography.Regions.Asia.South_Asia           False         276.986667
# new          Geography.Regions.Asia.South_Asia           False          30.331077
# expanded     Geography.Regions.Asia.Asia*                True          417.291667
# new          Geography.Regions.Asia.Asia*                True          125.370370
# expanded     Geography.Regions.Asia.Asia*                False         539.307692
# new          Geography.Regions.Asia.Asia*                False          39.655120
# expanded     Geography.Geographical                      True          446.315789
# new          Geography.Geographical                      True           28.000000
# expanded     Geography.Geographical                      False         686.478261
# new          Geography.Geographical                      False          43.742574
# expanded     Culture.Sports                              True           84.411765
# new          Culture.Sports                              True           41.333333
# expanded     Culture.Sports                              False          15.565217
# new          Culture.Sports                              False          18.432203
# expanded     Culture.Philosophy_and_religion             True          476.055556
# new          Culture.Philosophy_and_religion             True           30.636364
# expanded     Culture.Philosophy_and_religion             False         336.138889
# new          Culture.Philosophy_and_religion             False          49.643678
# expanded     Culture.Media.Films                         True          141.882353
# new          Culture.Media.Films                         True           98.906667
# expanded     Culture.Media.Films                         False         321.000000
# new          Culture.Media.Films                         False          85.551282
# expanded     Culture.Biography.Biography*                True          234.200000
# new          Culture.Biography.Biography*                True           71.673684
# expanded     Culture.Biography.Biography*                False         144.592025
# new          Culture.Biography.Biography*                False          19.961799
# expanded     0                                           True          150.166667
# new          0                                           True          130.480000
# expanded     0                                           False         271.581395
# new          0                                           False          30.988124
#
#                                                                                std  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True           642.633187
# new          STEM.STEM*                                  True           107.988227
# expanded     STEM.STEM*                                  False          433.649805
# new          STEM.STEM*                                  False           63.401766
# expanded     History_and_Society.Society                 True           448.548751
# new          History_and_Society.Society                 True            13.702798
# expanded     History_and_Society.Society                 False           86.062142
# new          History_and_Society.Society                 False          218.579881
# expanded     History_and_Society.Politics_and_government True           248.901587
# new          History_and_Society.Politics_and_government True            39.033868
# expanded     History_and_Society.Politics_and_government False          269.559455
# new          History_and_Society.Politics_and_government False           29.222693
#              Geography.Regions.Asia.Southeast_Asia       True             1.825742
# expanded     Geography.Regions.Asia.Southeast_Asia       False          221.324423
# new          Geography.Regions.Asia.Southeast_Asia       False           79.392762
# expanded     Geography.Regions.Asia.South_Asia           True           564.877596
# new          Geography.Regions.Asia.South_Asia           True           168.436241
# expanded     Geography.Regions.Asia.South_Asia           False          494.971075
# new          Geography.Regions.Asia.South_Asia           False           76.067120
# expanded     Geography.Regions.Asia.Asia*                True           705.989828
# new          Geography.Regions.Asia.Asia*                True           214.676703
# expanded     Geography.Regions.Asia.Asia*                False          941.907112
# new          Geography.Regions.Asia.Asia*                False          102.285600
# expanded     Geography.Geographical                      True           974.328946
# new          Geography.Geographical                      True            54.626001
# expanded     Geography.Geographical                      False         1955.589074
# new          Geography.Geographical                      False           94.620363
# expanded     Culture.Sports                              True           107.991932
# new          Culture.Sports                              True            68.603095
# expanded     Culture.Sports                              False           34.118545
# new          Culture.Sports                              False           74.271215
# expanded     Culture.Philosophy_and_religion             True           485.035653
# new          Culture.Philosophy_and_religion             True            29.980903
# expanded     Culture.Philosophy_and_religion             False          900.113648
# new          Culture.Philosophy_and_religion             False           73.394597
# expanded     Culture.Media.Films                         True           124.650452
# new          Culture.Media.Films                         True           148.988134
# expanded     Culture.Media.Films                         False          510.061434
# new          Culture.Media.Films                         False          114.526200
# expanded     Culture.Biography.Biography*                True           766.576052
# new          Culture.Biography.Biography*                True           169.251633
# expanded     Culture.Biography.Biography*                False          460.012216
# new          Culture.Biography.Biography*                False           54.203694
# expanded     0                                           True           156.129000
# new          0                                           True           168.304070
# expanded     0                                           False          637.508365
# new          0                                           False           75.793840
#
#                                                                          min  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True            2.0
# new          STEM.STEM*                                  True            2.0
# expanded     STEM.STEM*                                  False           6.0
# new          STEM.STEM*                                  False           0.0
# expanded     History_and_Society.Society                 True           18.0
# new          History_and_Society.Society                 True            4.0
# expanded     History_and_Society.Society                 False           4.0
# new          History_and_Society.Society                 False           1.0
# expanded     History_and_Society.Politics_and_government True          665.0
# new          History_and_Society.Politics_and_government True            6.0
# expanded     History_and_Society.Politics_and_government False          12.0
# new          History_and_Society.Politics_and_government False           0.0
#              Geography.Regions.Asia.Southeast_Asia       True            5.0
# expanded     Geography.Regions.Asia.Southeast_Asia       False          15.0
# new          Geography.Regions.Asia.Southeast_Asia       False           0.0
# expanded     Geography.Regions.Asia.South_Asia           True            1.0
# new          Geography.Regions.Asia.South_Asia           True            0.0
# expanded     Geography.Regions.Asia.South_Asia           False           0.0
# new          Geography.Regions.Asia.South_Asia           False           0.0
# expanded     Geography.Regions.Asia.Asia*                True            2.0
# new          Geography.Regions.Asia.Asia*                True            0.0
# expanded     Geography.Regions.Asia.Asia*                False           1.0
# new          Geography.Regions.Asia.Asia*                False           0.0
# expanded     Geography.Geographical                      True           11.0
# new          Geography.Geographical                      True            2.0
# expanded     Geography.Geographical                      False           6.0
# new          Geography.Geographical                      False           0.0
# expanded     Culture.Sports                              True            5.0
# new          Culture.Sports                              True            1.0
# expanded     Culture.Sports                              False           0.0
# new          Culture.Sports                              False           0.0
# expanded     Culture.Philosophy_and_religion             True            6.0
# new          Culture.Philosophy_and_religion             True            5.0
# expanded     Culture.Philosophy_and_religion             False           5.0
# new          Culture.Philosophy_and_religion             False           1.0
# expanded     Culture.Media.Films                         True            2.0
# new          Culture.Media.Films                         True            1.0
# expanded     Culture.Media.Films                         False          13.0
# new          Culture.Media.Films                         False           1.0
# expanded     Culture.Biography.Biography*                True            0.0
# new          Culture.Biography.Biography*                True            0.0
# expanded     Culture.Biography.Biography*                False           0.0
# new          Culture.Biography.Biography*                False           0.0
# expanded     0                                           True            4.0
# new          0                                           True            2.0
# expanded     0                                           False           3.0
# new          0                                           False           0.0
#
#                                                                           25%  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True           45.25
# new          STEM.STEM*                                  True           10.00
# expanded     STEM.STEM*                                  False          58.75
# new          STEM.STEM*                                  False           5.00
# expanded     History_and_Society.Society                 True           82.00
# new          History_and_Society.Society                 True            8.75
# expanded     History_and_Society.Society                 False          15.00
# new          History_and_Society.Society                 False           7.00
# expanded     History_and_Society.Politics_and_government True          753.00
# new          History_and_Society.Politics_and_government True           10.50
# expanded     History_and_Society.Politics_and_government False          31.00
# new          History_and_Society.Politics_and_government False           3.00
#              Geography.Regions.Asia.Southeast_Asia       True            5.75
# expanded     Geography.Regions.Asia.Southeast_Asia       False          93.25
# new          Geography.Regions.Asia.Southeast_Asia       False           2.50
# expanded     Geography.Regions.Asia.South_Asia           True           11.00
# new          Geography.Regions.Asia.South_Asia           True           11.25
# expanded     Geography.Regions.Asia.South_Asia           False           8.50
# new          Geography.Regions.Asia.South_Asia           False           2.00
# expanded     Geography.Regions.Asia.Asia*                True           36.75
# new          Geography.Regions.Asia.Asia*                True           11.50
# expanded     Geography.Regions.Asia.Asia*                False          16.50
# new          Geography.Regions.Asia.Asia*                False           2.00
# expanded     Geography.Geographical                      True           49.50
# new          Geography.Geographical                      True            6.75
# expanded     Geography.Geographical                      False          59.00
# new          Geography.Geographical                      False           5.00
# expanded     Culture.Sports                              True            9.00
# new          Culture.Sports                              True            3.50
# expanded     Culture.Sports                              False           2.50
# new          Culture.Sports                              False           1.00
# expanded     Culture.Philosophy_and_religion             True          123.75
# new          Culture.Philosophy_and_religion             True            8.00
# expanded     Culture.Philosophy_and_religion             False          38.50
# new          Culture.Philosophy_and_religion             False          10.00
# expanded     Culture.Media.Films                         True           38.00
# new          Culture.Media.Films                         True           15.00
# expanded     Culture.Media.Films                         False          50.50
# new          Culture.Media.Films                         False          16.25
# expanded     Culture.Biography.Biography*                True            8.00
# new          Culture.Biography.Biography*                True            5.00
# expanded     Culture.Biography.Biography*                False           6.00
# new          Culture.Biography.Biography*                False           3.00
# expanded     0                                           True           13.00
# new          0                                           True           21.00
# expanded     0                                           False          29.00
# new          0                                           False           3.00
#
#                                                                          50%  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True          102.0
# new          STEM.STEM*                                  True           15.0
# expanded     STEM.STEM*                                  False         120.0
# new          STEM.STEM*                                  False          15.0
# expanded     History_and_Society.Society                 True          159.0
# new          History_and_Society.Society                 True           19.0
# expanded     History_and_Society.Society                 False          55.0
# new          History_and_Society.Society                 False          12.0
# expanded     History_and_Society.Politics_and_government True          841.0
# new          History_and_Society.Politics_and_government True           29.0
# expanded     History_and_Society.Politics_and_government False         131.0
# new          History_and_Society.Politics_and_government False           6.0
#              Geography.Regions.Asia.Southeast_Asia       True            7.0
# expanded     Geography.Regions.Asia.Southeast_Asia       False         171.5
# new          Geography.Regions.Asia.Southeast_Asia       False           6.0
# expanded     Geography.Regions.Asia.South_Asia           True           74.0
# new          Geography.Regions.Asia.South_Asia           True           47.5
# expanded     Geography.Regions.Asia.South_Asia           False          67.0
# new          Geography.Regions.Asia.South_Asia           False           5.0
# expanded     Geography.Regions.Asia.Asia*                True          179.5
# new          Geography.Regions.Asia.Asia*                True           41.0
# expanded     Geography.Regions.Asia.Asia*                False          40.0
# new          Geography.Regions.Asia.Asia*                False           7.0
# expanded     Geography.Geographical                      True           99.0
# new          Geography.Geographical                      True           11.0
# expanded     Geography.Geographical                      False         136.0
# new          Geography.Geographical                      False           9.0
# expanded     Culture.Sports                              True           33.0
# new          Culture.Sports                              True           13.0
# expanded     Culture.Sports                              False           4.0
# new          Culture.Sports                              False           3.5
# expanded     Culture.Philosophy_and_religion             True          290.5
# new          Culture.Philosophy_and_religion             True           16.0
# expanded     Culture.Philosophy_and_religion             False          97.0
# new          Culture.Philosophy_and_religion             False          18.0
# expanded     Culture.Media.Films                         True          100.0
# new          Culture.Media.Films                         True           39.0
# expanded     Culture.Media.Films                         False          94.0
# new          Culture.Media.Films                         False          40.5
# expanded     Culture.Biography.Biography*                True           32.0
# new          Culture.Biography.Biography*                True           11.0
# expanded     Culture.Biography.Biography*                False          18.5
# new          Culture.Biography.Biography*                False           6.0
# expanded     0                                           True          115.0
# new          0                                           True           56.0
# expanded     0                                           False          61.0
# new          0                                           False           9.0
#
#                                                                           75%  \
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True          412.75
# new          STEM.STEM*                                  True           41.00
# expanded     STEM.STEM*                                  False         277.75
# new          STEM.STEM*                                  False          34.00
# expanded     History_and_Society.Society                 True          237.00
# new          History_and_Society.Society                 True           24.75
# expanded     History_and_Society.Society                 False          77.00
# new          History_and_Society.Society                 False          26.00
# expanded     History_and_Society.Politics_and_government True          929.00
# new          History_and_Society.Politics_and_government True           58.50
# expanded     History_and_Society.Politics_and_government False         324.00
# new          History_and_Society.Politics_and_government False          21.00
#              Geography.Regions.Asia.Southeast_Asia       True            8.25
# expanded     Geography.Regions.Asia.Southeast_Asia       False         249.75
# new          Geography.Regions.Asia.Southeast_Asia       False          14.50
# expanded     Geography.Regions.Asia.South_Asia           True          363.50
# new          Geography.Regions.Asia.South_Asia           True          162.25
# expanded     Geography.Regions.Asia.South_Asia           False         370.00
# new          Geography.Regions.Asia.South_Asia           False          17.00
# expanded     Geography.Regions.Asia.Asia*                True          553.50
# new          Geography.Regions.Asia.Asia*                True          180.00
# expanded     Geography.Regions.Asia.Asia*                False         572.50
# new          Geography.Regions.Asia.Asia*                False          23.00
# expanded     Geography.Geographical                      True          297.50
# new          Geography.Geographical                      True           14.75
# expanded     Geography.Geographical                      False         355.50
# new          Geography.Geographical                      False          25.00
# expanded     Culture.Sports                              True          103.00
# new          Culture.Sports                              True           26.00
# expanded     Culture.Sports                              False           6.50
# new          Culture.Sports                              False           7.75
# expanded     Culture.Philosophy_and_religion             True          664.50
# new          Culture.Philosophy_and_religion             True           45.50
# expanded     Culture.Philosophy_and_religion             False         284.00
# new          Culture.Philosophy_and_religion             False          51.50
# expanded     Culture.Media.Films                         True          298.00
# new          Culture.Media.Films                         True          115.00
# expanded     Culture.Media.Films                         False         364.50
# new          Culture.Media.Films                         False          99.50
# expanded     Culture.Biography.Biography*                True          169.50
# new          Culture.Biography.Biography*                True           58.50
# expanded     Culture.Biography.Biography*                False          85.00
# new          Culture.Biography.Biography*                False          13.00
# expanded     0                                           True          246.50
# new          0                                           True          188.00
# expanded     0                                           False         192.00
# new          0                                           False          23.75
#
#                                                                           max
# article_type predicted_label_1                           g_suggestion
# expanded     STEM.STEM*                                  True          4236.0
# new          STEM.STEM*                                  True           539.0
# expanded     STEM.STEM*                                  False         2622.0
# new          STEM.STEM*                                  False          600.0
# expanded     History_and_Society.Society                 True          1369.0
# new          History_and_Society.Society                 True            41.0
# expanded     History_and_Society.Society                 False          240.0
# new          History_and_Society.Society                 False         1884.0
# expanded     History_and_Society.Politics_and_government True          1017.0
# new          History_and_Society.Politics_and_government True           110.0
# expanded     History_and_Society.Politics_and_government False          660.0
# new          History_and_Society.Politics_and_government False          179.0
#              Geography.Regions.Asia.Southeast_Asia       True             9.0
# expanded     Geography.Regions.Asia.Southeast_Asia       False          328.0
# new          Geography.Regions.Asia.Southeast_Asia       False          348.0
# expanded     Geography.Regions.Asia.South_Asia           True          4100.0
# new          Geography.Regions.Asia.South_Asia           True          1088.0
# expanded     Geography.Regions.Asia.South_Asia           False         3399.0
# new          Geography.Regions.Asia.South_Asia           False         1158.0
# expanded     Geography.Regions.Asia.Asia*                True          5713.0
# new          Geography.Regions.Asia.Asia*                True          1353.0
# expanded     Geography.Regions.Asia.Asia*                False         4135.0
# new          Geography.Regions.Asia.Asia*                False         1515.0
# expanded     Geography.Geographical                      True          4269.0
# new          Geography.Geographical                      True           182.0
# expanded     Geography.Geographical                      False         9389.0
# new          Geography.Geographical                      False          687.0
# expanded     Culture.Sports                              True           346.0
# new          Culture.Sports                              True           230.0
# expanded     Culture.Sports                              False          156.0
# new          Culture.Sports                              False          522.0
# expanded     Culture.Philosophy_and_religion             True          1591.0
# new          Culture.Philosophy_and_religion             True            86.0
# expanded     Culture.Philosophy_and_religion             False         5423.0
# new          Culture.Philosophy_and_religion             False          390.0
# expanded     Culture.Media.Films                         True           355.0
# new          Culture.Media.Films                         True           950.0
# expanded     Culture.Media.Films                         False         1083.0
# new          Culture.Media.Films                         False          483.0
# expanded     Culture.Biography.Biography*                True          6790.0
# new          Culture.Biography.Biography*                True          1735.0
# expanded     Culture.Biography.Biography*                False         5756.0
# new          Culture.Biography.Biography*                False          825.0
# expanded     0                                           True           570.0
# new          0                                           True           665.0
# expanded     0                                           False         3456.0
# new          0                                           False         1024.0

# %% [raw]
# interim_df[new_articles].groupby(['g_suggestion', 'predicted_label_1'])['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['sum'], ascending=False)

# %% [raw]
# final_frame_updated_pv_topics_suggs[new_final_frame].groupby('g_category')['views_1M_all'].agg(['mean','count','sum']).sort_values(by=['sum'], ascending=False).head(5)

# %% [markdown]
# ## Referral Source

# %%
feb_global_views_referrer.groupby('referrer_class')['feb_view_count_global'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False)
# Out:
#                                mean  count     sum
# referrer_class
# external (search engine)  54.912170   4281  235079
# none                      34.720480   8418  292277
# internal                  17.778332   6415  114048
# unknown                    3.084337    249     768
# external                   2.010067    894    1797

# %%
rdf.groupby('referrer_class')['feb_view_count_global'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False)
# Out:
#                                mean  count       sum
# referrer_class
# external (search engine)  55.919185   4170  233183.0
# none                      33.801371   8171  276191.0
# internal                  18.166160   6253  113593.0
# unknown                    3.211765    255     819.0
# external                   2.006749    889    1784.0

# %%
t = feb_global_views_referrer.groupby('referrer_class')['feb_view_count_global'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False).reset_index()
entries = t['count'].sum()
_pvsum = t['sum'].sum()
print('raw entries', entries)
print('raw pgview sum', _pvsum)
# Out:
# raw entries 20257
# raw pgview sum 643969

# %%
n = rdf.groupby('referrer_class')['feb_view_count_global'].agg(['mean','count','sum']).sort_values(by=['mean'], ascending=False).reset_index()
entries = n['count'].sum()
_pvsum = n['sum'].sum()
print('merged entries', entries)
print('merged pgview sum', _pvsum)
# Out:
# merged entries 19738
# merged pgview sum 625570.0

# %%
rdf.groupby(['referrer_class', 'g_suggestion'], sort=False)["feb_view_count_global"].mean().unstack().sort_values([True],ascending=False).plot(kind="bar", figsize=(15,9), stacked=True);

# %%
pd.pivot_table(rdf.sort_values('feb_view_count_global'), values = 'feb_view_count_global', index = 'referrer_class',
               columns = 'g_suggestion',aggfunc ='mean').plot.bar().set_title("Avg pageviews by referrer and suggestion");

# %%
#define rows
mask = rdf['referrer_class'].isin(['unknown', 'external'])
rdf_select = rdf[~mask]

#define order
referral_types = ['external (search engine)', 'none', 'internal']
mapping = {referral_type: i for i, referral_type in enumerate(referral_types)}
key = rdf_select['article_type'].map(mapping)

#rdf_select.iloc[key.argsort()]
df_grouped = rdf_select.iloc[key.argsort()]

gapv = pd.pivot_table(df_grouped.sort_values('article_type', ascending=True), 
                      values = 'feb_view_count_global', 
                      index = 'referrer_class',
                      columns = ['g_suggestion', 'article_type'],
                      aggfunc ='mean'
                     )

gapv.plot(kind = 'bar', figsize=(20,10))

plt.title('Avg pageviews by referrer, type, suggestion',fontsize=24)
plt.xlabel('Referral Source Category',fontsize=28)
plt.ylabel('Average Views',fontsize=28)
plt.xticks(rotation=360)
plt.tick_params(labelsize=22)
#plt.savefig('../../results/figs/pageviews/Avg_pv_referrer_suggestion_type.png')
plt.show();

#color scheme by sugg type
#label bars

# %%
gapv
# Out:
# g_suggestion                   False                  True
# article_type                expanded        new    expanded        new
# referrer_class
# external                    2.732877   1.439922    3.652778   1.397590
# external (search engine)  135.707192  14.529504  181.264325  37.638171
# internal                   52.181818   8.559691   54.544093  13.618056
# none                       77.542974  20.425861   93.886329  43.985577
# unknown                     5.206897   1.763889    2.472973   2.545455

# %%
fgvr.groupby('referrer_class')["feb_view_count_global"].mean().sort_values(ascending=False).plot(kind="bar", 
                                                                                                 figsize=(15,9), 
                                                                                                 stacked=True);
