# %% [raw]
# remove dates before Oct 10, 2019
# remove dates after Feb 11, 2019
#
# same for editors
#
# also review added editor item

# %% [markdown]
# # process/get baselines - contest

# %% [markdown]
# #### Editors<a class="anchor" id="editors"></a>
# [Back to Table of Contents](#toc)

# %%
mae
# Out:
#   database_code  indic_editors_on_big_wikis_m
# 0        enwiki                          92.2
# 1  wikidatawiki                         169.8
# 2   commonswiki                          82.4

# %% [raw]
# mae.to_csv("../../data/processed/query_results/regional_counts/baseline/mae_contest.csv", sep=',', encoding = 'utf-8', index=False)

# %% [markdown]
# #### Readers<a class="anchor" id="readers"></a>
# [Back to Table of Contents](#toc)

# %% [raw]
# #save to process
# pv_rc.to_csv("../../data/processed/query_results/pv/pv_to_process/pv_rc.csv", sep=',', encoding = 'utf-8', index=False)
#
# pv_all.to_csv("../../data/processed/query_results/pv/pv_to_process/pv_all.csv", sep=',', encoding = 'utf-8', index=False)

# %%
wikis
# Out:
#    database_code project_code language_code    language_name  \
# 0         aswiki    wikipedia            as         Assamese
# 1         bnwiki    wikipedia            bn           Bangla
# 2         guwiki    wikipedia            gu         Gujarati
# 3         hiwiki    wikipedia            hi            Hindi
# 4         knwiki    wikipedia            kn          Kannada
# 5         mlwiki    wikipedia            ml        Malayalam
# 6         mrwiki    wikipedia            mr          Marathi
# 7         orwiki    wikipedia            or             Odia
# 8         pawiki    wikipedia            pa          Punjabi
# 9        pnbwiki    wikipedia           pnb  Western Punjabi
# 10       satwiki    wikipedia           sat          Santali
# 11        sawiki    wikipedia            sa         Sanskrit
# 12        tawiki    wikipedia            ta            Tamil
# 13       tcywiki    wikipedia           tcy             Tulu
# 14        tewiki    wikipedia            te           Telugu
# 15        urwiki    wikipedia            ur             Urdu
#
#                     wiki_name                domain_name  \
# 0          Assamese Wikipedia   https://as.wikipedia.org
# 1           Bengali Wikipedia   https://bn.wikipedia.org
# 2          Gujarati Wikipedia   https://gu.wikipedia.org
# 3             Hindi Wikipedia   https://hi.wikipedia.org
# 4           Kannada Wikipedia   https://kn.wikipedia.org
# 5         Malayalam Wikipedia   https://ml.wikipedia.org
# 6           Marathi Wikipedia   https://mr.wikipedia.org
# 7             Oriya Wikipedia   https://or.wikipedia.org
# 8           Punjabi Wikipedia   https://pa.wikipedia.org
# 9   Western Punjabi Wikipedia  https://pnb.wikipedia.org
# 10          Santali Wikipedia  https://sat.wikipedia.org
# 11         Sanskrit Wikipedia   https://sa.wikipedia.org
# 12            Tamil Wikipedia   https://ta.wikipedia.org
# 13             Tulu Wikipedia  https://tcy.wikipedia.org
# 14           Telugu Wikipedia   https://te.wikipedia.org
# 15             Urdu Wikipedia   https://ur.wikipedia.org
#
#     monthly_unique_devices  monthly_editors  monthly_new_editors  \
# 0                   3664.4             14.8                  0.6
# 1                  41209.2             41.4                  2.4
# 2                  24449.0              8.4                  0.2
# 3                 760583.2             37.8                  1.0
# 4                  58041.8             16.2                  0.0
# 5                  73146.8              9.6                  0.2
# 6                 182675.0             17.8                  0.6
# 7                   3669.2              6.6                  0.2
# 8                   5108.6             26.6                  0.6
# 9                    570.4              4.8                  0.0
# 10                   402.0             13.4                  0.8
# 11                  2889.2              5.2                  0.6
# 12                244168.0             47.6                  2.2
# 13                  1233.2              7.4                  0.0
# 14                118132.0             19.0                  5.0
# 15                  7528.4             23.6                  0.4
#
#     monthly_active_editors  monthly_new_active_editors  mon_new_articles  \
# 0                     11.0                         0.6            1677.2
# 1                     33.6                         1.4           52330.6
# 2                      5.8                         0.2            2297.8
# 3                     21.4                         0.0           31990.2
# 4                      9.2                         0.0            5439.2
# 5                      6.4                         0.0           10067.0
# 6                     13.8                         0.4            5215.2
# 7                      5.2                         0.2            1446.0
# 8                     17.8                         0.4            3562.8
# 9                      2.0                         0.0            2587.0
# 10                    10.8                         0.4            2201.0
# 11                     2.2                         0.6             622.2
# 12                    35.2                         1.4           15318.8
# 13                     5.2                         0.0             882.0
# 14                    10.6                         3.2           15440.6
# 15                    20.0                         0.0           20449.0
#
#     mon_new_articles_edited  avg_n_existing_articles_edited    nonbot_revs
# 0                     562.2                          1675.2    8281.166667
# 1                    8839.2                         52310.0  253725.000000
# 2                     775.6                          2289.8   11419.833333
# 3                    9106.2                         31939.4  159379.583333
# 4                     931.2                          5434.8   27169.666667
# 5                    2298.8                         10053.4   49849.333333
# 6                     841.4                          5212.0   26008.666667
# 7                     255.6                          1439.8    7166.500000
# 8                     886.2                          3548.8   17739.333333
# 9                    1566.4                          2585.4   12926.250000
# 10                    425.0                          2201.0   11001.416667
# 11                    322.0                           617.8    3086.583333
# 12                   3468.2                         15307.8   75271.583333
# 13                    152.0                           880.8    4398.000000
# 14                   1442.6                         15433.6   74287.833333
# 15                   3187.6                         20432.2   97252.500000

# %% [raw]
# wikis.to_csv("../../data/processed/query_results/regional_counts/baseline/baseline_contest.csv", sep=',', encoding = 'utf-8', index=False)

# %% [markdown]
# # process/get baselines - monthly

# %%
mae
# Out:
#   database_code  indic_editors_on_big_wikis_m
# 0        enwiki                 146712.833333
# 1  wikidatawiki                  22553.500000
# 2   commonswiki                  38676.333333

# %% [raw]
# mae.to_csv("../../data/processed/query_results/regional_counts/baseline/mae_12m.csv", sep=',', encoding = 'utf-8', index=False)

# %% [markdown]
# #### Readers<a class="anchor" id="readers"></a>
# [Back to Table of Contents](#toc)

# %% [raw]
# #save to process
# pv_rc.to_csv("../../data/processed/query_results/pv/pv_to_process/pv_rc_12M.csv", sep=',', encoding = 'utf-8', index=False)
#
# pv_all.to_csv("../../data/processed/query_results/pv/pv_to_process/pv_all_12M.csv", sep=',', encoding = 'utf-8', index=False)

# %% [raw]
# wikis.to_csv("../../data/processed/query_results/regional_counts/baseline/baseline_monthly.csv", sep=',', encoding = 'utf-8', index=False)
