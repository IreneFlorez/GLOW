# %% [markdown]
# # Quick Exploration

# %% [raw]
# TODO
# 1. add note: see relative length for PA wikis
# 2. fix charts

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np

# %load_ext sql_magic
# %matplotlib inline

# %%
#fyi, file names updated
#new_articles = pd.read_csv("../../data/processed/query_results/content_quality/b4_final_frame_updated_pv_topcs.csv", sep=',', encoding = 'utf-8', parse_dates=True)

# %%
new_articles = pd.read_csv("../../data/processed/query_results/content_quality/final_frame_updated_pv_topcs.csv", sep=',', encoding = 'utf-8', parse_dates=True) 
interim = pd.read_csv("../../data/processed/query_results/content_quality/interim_frame_updated.csv", sep=',', encoding = 'utf-8', parse_dates=True)

# %%
final_frame_updated_pv_topics_suggs = pd.read_csv("../../data/processed/query_results/content_quality/b5_final_frame_updated_pv_topics_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
interim_frame_updated_pv_topics_suggs = pd.read_csv("../../data/processed/query_results/content_quality/5_interim_frame_updated_w_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
new_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7447 entries, 0 to 7446
# Data columns (total 36 columns):
# wikicode             7447 non-null object
# page_title           7447 non-null object
# url                  7447 non-null object
# url_article_info     7447 non-null object
# page_id              7447 non-null float64
# at_edits             7447 non-null object
# translation_tool     7447 non-null bool
# QID                  7447 non-null object
# iwsitelinks          7447 non-null float64
# iwsites              7447 non-null object
# article_type         7447 non-null object
# page_len             7447 non-null float64
# relative_page_len    7447 non-null float64
# total_edits          7447 non-null float64
# editors              7447 non-null float64
# views_1M             7447 non-null float64
# views_1M_all         7447 non-null float64
# editors_1stM         7447 non-null float64
# edits_1M             7447 non-null float64
# minor_edits          7447 non-null float64
# major_editors        7447 non-null float64
# IP_editors           7447 non-null float64
# micro_editors        7447 non-null float64
# revertrate           7447 non-null int64
# first_edited         7447 non-null object
# last_edited          7447 non-null object
# talk_page_edits      7447 non-null float64
# watch_count          7447 non-null float64
# o_internal_links     7447 non-null float64
# o_external_links     7447 non-null float64
# incoming_links       7447 non-null float64
# predicted_labels     7447 non-null object
# predicted_label_1    7447 non-null object
# pl1_score            7447 non-null float64
# predicted_label_2    7447 non-null object
# pl2_score            7447 non-null float64
# dtypes: bool(1), float64(21), int64(1), object(13)
# memory usage: 2.0+ MB

# %%
interim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8863 entries, 0 to 8862
# Data columns (total 14 columns):
# wikicode             8863 non-null object
# page_id              8863 non-null float64
# page_title           8863 non-null object
# page_len             8863 non-null float64
# relative_page_len    8863 non-null float64
# at_edits             8863 non-null object
# QID                  8863 non-null float64
# first_edited         8863 non-null object
# article_type         8863 non-null object
# translation_tool     8863 non-null bool
# url                  8863 non-null object
# url_article_info     8863 non-null object
# views_1M             8863 non-null float64
# views_1M_all         8863 non-null float64
# dtypes: bool(1), float64(6), object(7)
# memory usage: 908.9+ KB

# %%
#check for outliers in page_len
sns.stripplot(data = interim, y = 'page_len', jitter = True);
#sns.plt.ylim(0, 500)
#sns.plt.show()

# %%
#check for outliers in page_len
sns.stripplot(data = interim, y = 'page_len', jitter = True);
sns.plt.ylim(0, 100000)
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-531da8bec2d2> in <module>
#       1 #check for outliers in page_len
#       2 sns.stripplot(data = interim_df, y = 'page_len', jitter = True);
# ----> 3 sns.plt.ylim(0, 100000)
#       4 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
# Review 'page_len' distribution 
plt.figure();
age_hist = interim['page_len'].plot.hist(bins=10)
age_hist.set_xlabel("page_len")
age_hist.set_ylabel("Articles")
age_hist.set_title('Distribution of page_len');

# %%
## exploratory analysis

# %%
new_articles.describe()
# Out:
#             page_id  iwsitelinks       page_len  relative_page_len  \
# count  7.447000e+03  7447.000000    7447.000000        7447.000000
# mean   4.611372e+05    23.386062   11837.564791           0.244831
# std    3.204643e+05    34.561769    7277.651458           0.240546
# min    3.632000e+03     0.000000     366.000000           0.009660
# 25%    1.234155e+05     3.000000    8209.500000           0.103495
# 50%    4.634890e+05     8.000000   10645.000000           0.151828
# 75%    8.060390e+05    32.000000   13717.500000           0.280630
# max    1.124778e+06  1057.000000  211451.000000           1.000000
#
#        total_edits      editors     views_1M  views_1M_all  editors_1stM  \
# count  7447.000000  7447.000000  7447.000000   7447.000000   7447.000000
# mean      7.841144     2.071841    10.728078     37.361354      1.337720
# std       7.197075     1.192158    48.433681     91.884482      0.622313
# min       1.000000     1.000000     0.000000      0.000000      1.000000
# 25%       4.000000     1.000000     0.000000      3.000000      1.000000
# 50%       6.000000     2.000000     1.000000      8.000000      1.000000
# 75%      10.000000     3.000000     5.000000     24.000000      2.000000
# max     202.000000    16.000000  1269.000000   1884.000000      8.000000
#
#           edits_1M  ...   IP_editors  micro_editors  revertrate  \
# count  7447.000000  ...  7447.000000    7447.000000      7447.0
# mean      7.878475  ...     0.013965       0.963207         0.0
# std       7.103670  ...     0.164115       0.906294         0.0
# min       1.000000  ...     0.000000       0.000000         0.0
# 25%       3.000000  ...     0.000000       0.000000         0.0
# 50%       6.000000  ...     0.000000       1.000000         0.0
# 75%      10.000000  ...     0.000000       1.000000         0.0
# max     121.000000  ...     9.000000       6.000000         0.0
#
#        talk_page_edits  watch_count  o_internal_links  o_external_links  \
# count      7447.000000  7447.000000       7447.000000       7447.000000
# mean          0.943870     1.130657         18.839130          8.752652
# std           0.830403     0.535833         30.608028          9.461206
# min           0.000000     0.000000          0.000000          0.000000
# 25%           1.000000     1.000000          6.000000          3.000000
# 50%           1.000000     1.000000         11.000000          7.000000
# 75%           1.000000     1.000000         20.000000         11.000000
# max          32.000000     9.000000        589.000000        185.000000
#
#        incoming_links    pl1_score    pl2_score
# count     7447.000000  7447.000000  7447.000000
# mean         7.862361     0.838174     0.721720
# std         23.344913     0.323906     0.382791
# min          0.000000     0.000000     0.000000
# 25%          0.000000     0.907322     0.637041
# 50%          1.000000     0.987578     0.928419
# 75%          4.000000     0.998255     0.991694
# max        906.000000     1.000010     1.000010
#
# [8 rows x 22 columns]

# %%
interim.describe()
# Out:
#             page_id       page_len  relative_page_len           QID  \
# count  8.863000e+03    8863.000000        8863.000000  8.863000e+03
# mean   4.127637e+05   12758.483922           0.247730  8.430302e+06
# std    3.237508e+05    8671.881363           0.233403  1.654171e+07
# min    5.820000e+02     366.000000           0.009660  0.000000e+00
# 25%    1.215890e+05    8585.500000           0.109016  2.314015e+05
# 50%    4.595530e+05   11109.000000           0.159322  2.418927e+06
# 75%    7.993185e+05   14549.000000           0.287146  6.974085e+06
# max    1.124778e+06  218860.000000           1.000000  8.600728e+07
#
#           views_1M  views_1M_all
# count  8863.000000   8863.000000
# mean     29.618526     72.658129
# std     162.708724    277.769040
# min       0.000000      0.000000
# 25%       0.000000      4.000000
# 50%       2.000000     10.000000
# 75%       8.000000     37.000000
# max    4890.000000   9389.000000

# %%
na_agg = new_articles[[ #for aggregating
'wikicode',
'iwsitelinks',
'article_type',
'page_len',
'relative_page_len',
'total_edits',
'editors',
'views_1M',
'views_1M_all',
'editors_1stM',
'edits_1M',
'minor_edits',
'major_editors',
'IP_editors',
'micro_editors',
'revertrate',
'first_edited',
'last_edited',
'talk_page_edits',
'watch_count',
'o_internal_links',
'o_external_links',
'incoming_links']]

#select only numeric columns for hist plotting
numerics = ['int', 'float64']
na_numeric = new_articles.select_dtypes(include=numerics)

# %%
na_agg.groupby(['wikicode']).agg(['nunique'])

# %%
na_agg.groupby(['wikicode']).agg(['median', 'max'])
# Out:
#          iwsitelinks         page_len           relative_page_len            \
#               median     max   median       max            median       max
# wikicode
# aswiki          30.0   277.0  11782.0   54259.0          0.122673  0.564939
# bnwiki           5.0  1057.0  11642.5   57514.0          0.076433  0.377579
# guwiki          11.5   223.0  12937.5   34624.0          0.287076  0.768287
# hiwiki           5.0   147.0  10544.0  146014.0          0.116047  1.000000
# knwiki           0.0   120.0  16463.0  211451.0          0.435437  1.000000
# mlwiki          44.0   258.0  15577.0   55640.0          0.133744  0.477726
# mrwiki          10.0   147.0   9929.5   44149.0          0.147495  0.655798
# orwiki          62.0   270.0   9801.5   24546.0          0.438948  1.000000
# pawiki          10.0   191.0   8563.5   41302.0          0.293321  1.000000
# satwiki         28.0   544.0   8880.0   55277.0          1.000000  1.000000
# sawiki           8.0    20.0  11811.0   40530.0          0.423911  1.000000
# tawiki           9.0   149.0  12275.5   86020.0          0.137720  0.965064
# tcywiki          0.0   229.0  10521.0   20445.0          1.000000  1.000000
# tewiki          11.5    79.0  17648.5   42605.0          0.463179  1.000000
# urwiki           6.0   133.0   5404.0  179564.0          0.083453  1.000000
#
#          total_edits        editors        ... talk_page_edits        \
#               median    max  median   max  ...          median   max
# wikicode                                   ...
# aswiki           8.0   54.0     2.0   4.0  ...             1.0   4.0
# bnwiki           8.0  107.0     3.0  16.0  ...             1.0  14.0
# guwiki           7.0   39.0     2.0   5.0  ...             1.0   8.0
# hiwiki           5.0   38.0     2.0   5.0  ...             1.0   1.0
# knwiki           5.0  202.0     1.0   5.0  ...             0.0   2.0
# mlwiki          14.0   32.0     2.0   5.0  ...             1.0   3.0
# mrwiki           5.0   69.0     2.0   5.0  ...             0.0   1.0
# orwiki           8.0   28.0     2.0   5.0  ...             1.0   4.0
# pawiki           4.0   30.0     1.0   4.0  ...             0.0   5.0
# satwiki          8.0   54.0     1.0   4.0  ...             1.0   2.0
# sawiki           6.5   35.0     1.0   4.0  ...             0.0   0.0
# tawiki           6.0   79.0     2.0   7.0  ...             1.0  32.0
# tcywiki         20.0   50.0     3.0   8.0  ...             0.0   1.0
# tewiki          17.5   44.0     2.0   4.0  ...             0.0   4.0
# urwiki           5.0  127.0     2.0  10.0  ...             1.0   5.0
#
#          watch_count      o_internal_links        o_external_links         \
#               median  max           median    max           median    max
# wikicode
# aswiki           1.0  2.0             11.0  201.0              5.0   84.0
# bnwiki           2.0  8.0             29.0  201.0              9.0  111.0
# guwiki           2.0  4.0             10.5   83.0              9.0   70.0
# hiwiki           1.0  4.0             15.0  303.0              8.0   75.0
# knwiki           1.0  3.0              4.0   68.0              6.0   79.0
# mlwiki           1.0  2.0             21.0  160.0             17.0  185.0
# mrwiki           1.0  3.0              7.0  291.0              7.0   44.0
# orwiki           1.0  2.0              4.0   55.0              8.0   82.0
# pawiki           1.0  2.0              7.0   54.0              6.0   69.0
# satwiki          1.0  2.0              3.0   51.0              7.0   64.0
# sawiki           1.0  1.0             12.5   25.0              4.5   17.0
# tawiki           1.0  6.0             12.0  193.0              7.0  119.0
# tcywiki          1.0  2.0              1.5   10.0              2.0    4.0
# tewiki           1.0  2.0              2.5   22.0              9.5   24.0
# urwiki           1.0  9.0             13.0  589.0              2.0  112.0
#
#          incoming_links
#                  median    max
# wikicode
# aswiki             10.0  280.0
# bnwiki             12.0  499.0
# guwiki              2.0   81.0
# hiwiki              2.0  178.0
# knwiki              1.0   29.0
# mlwiki              1.0   15.0
# mrwiki              1.0  114.0
# orwiki              1.0   48.0
# pawiki              0.0  906.0
# satwiki             1.0   30.0
# sawiki              3.0   13.0
# tawiki              1.0  145.0
# tcywiki             1.0    8.0
# tewiki              1.0   25.0
# urwiki              3.0  521.0
#
# [15 rows x 38 columns]

# %%
na_numeric.hist(figsize=(15,15));

# %%
new_articles.corr()
# Out:
#                     page_id  translation_tool  iwsitelinks  page_len  \
# page_id            1.000000         -0.261001    -0.209006  0.008665
# translation_tool  -0.261001          1.000000    -0.018813 -0.007219
# iwsitelinks       -0.209006         -0.018813     1.000000  0.019431
# page_len           0.008665         -0.007219     0.019431  1.000000
# relative_page_len -0.615344         -0.076493     0.080778  0.216926
# total_edits        0.051295         -0.233692     0.039729  0.226569
# editors            0.504902         -0.235503    -0.057874  0.122038
# views_1M           0.117334         -0.030796    -0.007271  0.143374
# views_1M_all       0.173974         -0.028838    -0.004716  0.182979
# editors_1stM       0.069809         -0.101247     0.037865  0.131575
# edits_1M          -0.208813         -0.034018     0.065921  0.155215
# minor_edits        0.144606         -0.214502     0.054483  0.096722
# major_editors      0.167781         -0.135115    -0.006246  0.140012
# IP_editors         0.011073         -0.033245     0.000233  0.033744
# micro_editors      0.486171         -0.265220     0.003828  0.018840
# revertrate              NaN               NaN          NaN       NaN
# talk_page_edits    0.413988         -0.256563    -0.012675  0.060626
# watch_count        0.151869         -0.069020    -0.005371  0.083739
# o_internal_links   0.298573         -0.155781    -0.067106  0.144816
# o_external_links  -0.011895         -0.015197     0.103933  0.506931
# incoming_links     0.206378         -0.183351    -0.011080  0.023972
# pl1_score         -0.026821          0.162348     0.110276  0.001620
# pl2_score         -0.040323          0.127112    -0.015599  0.028642
#
#                    relative_page_len  total_edits   editors  views_1M  \
# page_id                    -0.615344     0.051295  0.504902  0.117334
# translation_tool           -0.076493    -0.233692 -0.235503 -0.030796
# iwsitelinks                 0.080778     0.039729 -0.057874 -0.007271
# page_len                    0.216926     0.226569  0.122038  0.143374
# relative_page_len           1.000000     0.066503 -0.315843 -0.034098
# total_edits                 0.066503     1.000000  0.314195  0.078779
# editors                    -0.315843     0.314195  1.000000  0.057614
# views_1M                   -0.034098     0.078779  0.057614  1.000000
# views_1M_all               -0.083492     0.111973  0.129618  0.808109
# editors_1stM               -0.101381     0.248926  0.620244  0.071545
# edits_1M                    0.175138     0.845061  0.043532  0.043198
# minor_edits                -0.025549     0.457911  0.329857  0.067490
# major_editors              -0.137375     0.269073  0.708398  0.051601
# IP_editors                  0.016704     0.128544  0.199427  0.120507
# micro_editors              -0.278829     0.296626  0.684236  0.042120
# revertrate                       NaN          NaN       NaN       NaN
# talk_page_edits            -0.192346     0.133135  0.313380  0.022808
# watch_count                -0.100105     0.139494  0.335142  0.077036
# o_internal_links           -0.164216     0.107231  0.206760  0.058106
# o_external_links            0.143352     0.191165  0.078637  0.060982
# incoming_links             -0.144832     0.052145  0.205665  0.014928
# pl1_score                  -0.064562    -0.016263  0.090360 -0.016153
# pl2_score                  -0.010726    -0.017363  0.075033 -0.028864
#
#                    views_1M_all  editors_1stM  ...  IP_editors  micro_editors  \
# page_id                0.173974      0.069809  ...    0.011073       0.486171
# translation_tool      -0.028838     -0.101247  ...   -0.033245      -0.265220
# iwsitelinks           -0.004716      0.037865  ...    0.000233       0.003828
# page_len               0.182979      0.131575  ...    0.033744       0.018840
# relative_page_len     -0.083492     -0.101381  ...    0.016704      -0.278829
# total_edits            0.111973      0.248926  ...    0.128544       0.296626
# editors                0.129618      0.620244  ...    0.199427       0.684236
# views_1M               0.808109      0.071545  ...    0.120507       0.042120
# views_1M_all           1.000000      0.105396  ...    0.113539       0.086124
# editors_1stM           0.105396      1.000000  ...    0.040603       0.275396
# edits_1M               0.036585      0.176587  ...    0.061474       0.080223
# minor_edits            0.087430      0.194414  ...    0.064126       0.543327
# major_editors          0.104064      0.797784  ...    0.060475       0.206869
# IP_editors             0.113539      0.040603  ...    1.000000       0.044991
# micro_editors          0.086124      0.275396  ...    0.044991       1.000000
# revertrate                  NaN           NaN  ...         NaN            NaN
# talk_page_edits        0.083293      0.136742  ...    0.005753       0.295625
# watch_count            0.162292      0.277255  ...    0.025064       0.120522
# o_internal_links       0.066386      0.053195  ...    0.002346       0.170553
# o_external_links       0.071350      0.069435  ...    0.010615       0.037672
# incoming_links         0.023482      0.065673  ...   -0.010260       0.150086
# pl1_score              0.003660      0.036327  ...   -0.011250       0.004285
# pl2_score             -0.013336      0.030164  ...   -0.007321      -0.046588
#
#                    revertrate  talk_page_edits  watch_count  o_internal_links  \
# page_id                   NaN         0.413988     0.151869          0.298573
# translation_tool          NaN        -0.256563    -0.069020         -0.155781
# iwsitelinks               NaN        -0.012675    -0.005371         -0.067106
# page_len                  NaN         0.060626     0.083739          0.144816
# relative_page_len         NaN        -0.192346    -0.100105         -0.164216
# total_edits               NaN         0.133135     0.139494          0.107231
# editors                   NaN         0.313380     0.335142          0.206760
# views_1M                  NaN         0.022808     0.077036          0.058106
# views_1M_all              NaN         0.083293     0.162292          0.066386
# editors_1stM              NaN         0.136742     0.277255          0.053195
# edits_1M                  NaN        -0.075035     0.053039          0.009300
# minor_edits               NaN         0.193964     0.070026          0.094378
# major_editors             NaN         0.184317     0.364995          0.097617
# IP_editors                NaN         0.005753     0.025064          0.002346
# micro_editors             NaN         0.295625     0.120522          0.170553
# revertrate                NaN              NaN          NaN               NaN
# talk_page_edits           NaN         1.000000     0.222330          0.123663
# watch_count               NaN         0.222330     1.000000          0.064359
# o_internal_links          NaN         0.123663     0.064359          1.000000
# o_external_links          NaN         0.074608     0.059649          0.104062
# incoming_links            NaN         0.121704     0.108028          0.430710
# pl1_score                 NaN        -0.057034     0.040540          0.021117
# pl2_score                 NaN        -0.052310     0.041244          0.040419
#
#                    o_external_links  incoming_links  pl1_score  pl2_score
# page_id                   -0.011895        0.206378  -0.026821  -0.040323
# translation_tool          -0.015197       -0.183351   0.162348   0.127112
# iwsitelinks                0.103933       -0.011080   0.110276  -0.015599
# page_len                   0.506931        0.023972   0.001620   0.028642
# relative_page_len          0.143352       -0.144832  -0.064562  -0.010726
# total_edits                0.191165        0.052145  -0.016263  -0.017363
# editors                    0.078637        0.205665   0.090360   0.075033
# views_1M                   0.060982        0.014928  -0.016153  -0.028864
# views_1M_all               0.071350        0.023482   0.003660  -0.013336
# editors_1stM               0.069435        0.065673   0.036327   0.030164
# edits_1M                   0.171271       -0.032705   0.005173  -0.003088
# minor_edits                0.065598        0.060788  -0.049858  -0.069839
# major_editors              0.082052        0.096674   0.069684   0.069079
# IP_editors                 0.010615       -0.010260  -0.011250  -0.007321
# micro_editors              0.037672        0.150086   0.004285  -0.046588
# revertrate                      NaN             NaN        NaN        NaN
# talk_page_edits            0.074608        0.121704  -0.057034  -0.052310
# watch_count                0.059649        0.108028   0.040540   0.041244
# o_internal_links           0.104062        0.430710   0.021117   0.040419
# o_external_links           1.000000        0.023700   0.112878   0.107154
# incoming_links             0.023700        1.000000   0.054879   0.077647
# pl1_score                  0.112878        0.054879   1.000000   0.792289
# pl2_score                  0.107154        0.077647   0.792289   1.000000
#
# [23 rows x 23 columns]

# %%
corr = new_articles.corr()
corr = (corr)
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="coolwarm", center=0);

# %%
plt.figure(figsize = (20,8))
sns.heatmap(new_articles.corr(), annot=True, cmap='coolwarm');

# %%
#new articles - full frame
plt.figure(figsize = (21,19))
sns.heatmap(final_frame_updated_pv_topics_suggs.corr(), annot=True, cmap='coolwarm');

# %% [markdown]
# ## Isolated/Underdeveloped articles

# %%
#o_internal_links	o_external_links
zero_oel = new_articles[new_articles['o_internal_links']==0]
zero_oil = new_articles[new_articles['o_external_links']==0]
zero_in_links =  new_articles[new_articles['incoming_links']==0]

# %%
len(new_articles[new_articles['o_internal_links']==0])
# Out:
# 228

# %%
len(new_articles[new_articles['o_external_links']==0])
# Out:
# 540

# %%
z = len(new_articles[new_articles['incoming_links']==0])
z
# Out:
# 2561

# %%
z/len(new_articles)
# Out:
# 0.3438968712233114

# %%
zero_out_links_mask = (new_articles['o_internal_links']== 0) & (new_articles['o_external_links'] == 0)
zero_out_links = new_articles.loc[zero_out_links_mask]

# %%
len(zero_out_links)
# Out:
# 75

# %%
zero_out_links.wikicode.unique()
# Out:
# array(['pawiki', 'tawiki', 'tcywiki', 'knwiki', 'urwiki', 'satwiki'],
#       dtype=object)

# %%
zero_out_links.describe()
# Out:
#              page_id  iwsitelinks       page_len  relative_page_len  \
# count      75.000000    75.000000      75.000000          75.000000
# mean   676604.480000    13.506667   10958.013333           0.312989
# std    360916.914552    33.405119   24642.372186           0.374795
# min      6631.000000     0.000000     366.000000           0.012536
# 25%    872110.000000     0.000000    4504.500000           0.069562
# 50%    874411.000000     2.000000    6366.000000           0.110478
# 75%    878390.500000     5.500000    9182.500000           0.289267
# max    881402.000000   171.000000  211451.000000           1.000000
#
#        total_edits    editors   views_1M  views_1M_all  editors_1stM  \
# count    75.000000  75.000000  75.000000     75.000000     75.000000
# mean      4.813333   2.173333   1.866667     16.746667      1.386667
# std       6.343103   1.266761   3.330179     26.894234      0.695416
# min       1.000000   1.000000   0.000000      1.000000      1.000000
# 25%       2.000000   1.000000   0.000000      3.000000      1.000000
# 50%       3.000000   2.000000   0.000000      7.000000      1.000000
# 75%       6.500000   3.000000   2.000000     22.500000      2.000000
# max      50.000000   6.000000  16.000000    207.000000      4.000000
#
#         edits_1M  ...  IP_editors  micro_editors  revertrate  talk_page_edits  \
# count  75.000000  ...   75.000000      75.000000        75.0        75.000000
# mean    3.866667  ...    0.053333       0.973333         0.0         1.386667
# std     5.909985  ...    0.226210       0.972227         0.0         0.590312
# min     1.000000  ...    0.000000       0.000000         0.0         0.000000
# 25%     1.000000  ...    0.000000       0.000000         0.0         1.000000
# 50%     2.000000  ...    0.000000       1.000000         0.0         1.000000
# 75%     5.000000  ...    0.000000       2.000000         0.0         2.000000
# max    46.000000  ...    1.000000       4.000000         0.0         2.000000
#
#        watch_count  o_internal_links  o_external_links  incoming_links  \
# count    75.000000              75.0              75.0       75.000000
# mean      1.000000               0.0               0.0        2.986667
# std       0.328798               0.0               0.0        6.556394
# min       0.000000               0.0               0.0        0.000000
# 25%       1.000000               0.0               0.0        1.000000
# 50%       1.000000               0.0               0.0        1.000000
# 75%       1.000000               0.0               0.0        3.000000
# max       2.000000               0.0               0.0       51.000000
#
#        pl1_score  pl2_score
# count  75.000000  75.000000
# mean    0.249957   0.188610
# std     0.409999   0.369031
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     0.000000   0.000000
# 75%     0.640575   0.000000
# max     1.000010   1.000010
#
# [8 rows x 22 columns]

# %%
zero_oel.describe()
# Out:
#             page_id  iwsitelinks       page_len  relative_page_len  \
# count  2.280000e+02   228.000000     228.000000         228.000000
# mean   4.051370e+05    23.451754   10725.846491           0.430080
# std    3.804724e+05    49.965824   14820.435361           0.393889
# min    6.145000e+03     0.000000     366.000000           0.012536
# 25%    7.879500e+03     0.000000    6354.500000           0.097488
# 50%    2.503450e+05     4.000000    8408.000000           0.221282
# 75%    8.743758e+05    29.250000   11499.250000           1.000000
# max    1.107858e+06   544.000000  211451.000000           1.000000
#
#        total_edits     editors    views_1M  views_1M_all  editors_1stM  \
# count   228.000000  228.000000  228.000000    228.000000    228.000000
# mean      6.885965    1.929825    8.201754     22.842105      1.377193
# std       6.840871    1.166487   49.334635     67.169400      0.662266
# min       1.000000    1.000000    0.000000      0.000000      1.000000
# 25%       3.000000    1.000000    0.000000      2.000000      1.000000
# 50%       5.000000    2.000000    1.000000      6.000000      1.000000
# 75%       9.000000    3.000000    3.250000     19.000000      2.000000
# max      50.000000    6.000000  703.000000    838.000000      4.000000
#
#          edits_1M  ...  IP_editors  micro_editors  revertrate  \
# count  228.000000  ...  228.000000     228.000000       228.0
# mean     6.504386  ...    0.030702       0.833333         0.0
# std      7.292805  ...    0.172888       0.904386         0.0
# min      1.000000  ...    0.000000       0.000000         0.0
# 25%      2.000000  ...    0.000000       0.000000         0.0
# 50%      4.000000  ...    0.000000       1.000000         0.0
# 75%      8.000000  ...    0.000000       1.000000         0.0
# max     46.000000  ...    1.000000       4.000000         0.0
#
#        talk_page_edits  watch_count  o_internal_links  o_external_links  \
# count       228.000000   228.000000             228.0        228.000000
# mean          0.986842     1.035088               0.0          4.245614
# std           0.699152     0.361831               0.0          4.865706
# min           0.000000     0.000000               0.0          0.000000
# 25%           0.750000     1.000000               0.0          0.000000
# 50%           1.000000     1.000000               0.0          3.000000
# 75%           1.000000     1.000000               0.0          7.000000
# max           2.000000     3.000000               0.0         38.000000
#
#        incoming_links   pl1_score   pl2_score
# count      228.000000  228.000000  228.000000
# mean         1.837719    0.580270    0.474920
# std          4.533282    0.469098    0.473213
# min          0.000000    0.000000    0.000000
# 25%          0.000000    0.000000    0.000000
# 50%          1.000000    0.899096    0.611386
# 75%          2.000000    0.995940    0.982160
# max         51.000000    1.000010    1.000010
#
# [8 rows x 22 columns]

# %%
zero_oil.describe()
# Out:
#              page_id  iwsitelinks       page_len  relative_page_len  \
# count     540.000000   540.000000     540.000000         540.000000
# mean   565268.648148    18.794444    8787.922222           0.239050
# std    365719.757145    29.517901   10392.387284           0.266192
# min      6219.000000     0.000000     366.000000           0.009660
# 25%    123508.750000     2.000000    5609.250000           0.084835
# 50%    872728.500000     4.000000    7206.500000           0.130422
# 75%    876385.250000    29.250000    9330.500000           0.251340
# max    881412.000000   171.000000  211451.000000           1.000000
#
#        total_edits     editors    views_1M  views_1M_all  editors_1stM  \
# count   540.000000  540.000000  540.000000    540.000000    540.000000
# mean      5.861111    2.005556    3.538889     18.729630      1.266667
# std       5.339075    1.114072   12.080757     42.630016      0.550931
# min       1.000000    1.000000    0.000000      0.000000      1.000000
# 25%       3.000000    1.000000    0.000000      4.000000      1.000000
# 50%       5.000000    2.000000    1.000000      8.000000      1.000000
# 75%       7.000000    3.000000    3.000000     17.000000      1.000000
# max      50.000000    7.000000  154.000000    600.000000      4.000000
#
#          edits_1M  ...  IP_editors  micro_editors  revertrate  \
# count  540.000000  ...  540.000000     540.000000       540.0
# mean     5.766667  ...    0.022222       0.983333         0.0
# std      5.494237  ...    0.170850       0.928671         0.0
# min      1.000000  ...    0.000000       0.000000         0.0
# 25%      2.000000  ...    0.000000       0.000000         0.0
# 50%      4.000000  ...    0.000000       1.000000         0.0
# 75%      7.250000  ...    0.000000       2.000000         0.0
# max     46.000000  ...    2.000000       4.000000         0.0
#
#        talk_page_edits  watch_count  o_internal_links  o_external_links  \
# count       540.000000   540.000000        540.000000             540.0
# mean          1.127778     1.079630         22.644444               0.0
# std           0.765905     0.389033         72.513139               0.0
# min           0.000000     0.000000          0.000000               0.0
# 25%           1.000000     1.000000          3.000000               0.0
# 50%           1.000000     1.000000          6.000000               0.0
# 75%           2.000000     1.000000         14.000000               0.0
# max           4.000000     6.000000        488.000000               0.0
#
#        incoming_links   pl1_score   pl2_score
# count      540.000000  540.000000  540.000000
# mean         5.874074    0.596960    0.461811
# std         26.375181    0.457842    0.448671
# min          0.000000    0.000000    0.000000
# 25%          0.000000    0.000000    0.000000
# 50%          1.000000    0.903296    0.573684
# 75%          4.250000    0.993106    0.938581
# max        521.000000    1.000010    1.000010
#
# [8 rows x 22 columns]
