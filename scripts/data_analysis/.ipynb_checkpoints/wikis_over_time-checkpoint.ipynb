# %%
import datetime as dt 
from datetime import datetime, timedelta, date
import dateutil

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np

# %load_ext sql_magic
# %matplotlib inline

# %%
# %run .././data_wrangling/2b_data_handling.ipynb
# Out:
# Stored 'query_vars' (dict)
# Stored 'quality_vars' (dict)

# %%
c_w_editors = pd.read_csv("../../data/raw/editors/2019/tiger2_participants_report/wiki_editor_art_counts.csv", sep=',', encoding = 'utf-8', parse_dates=True)
c_w_editors.columns = ['language_name', 'article_total', 'total_editor_count', 'contest_link']
c_w_editors['language_name'] = c_w_editors['language_name'].replace({'Bengali':'Bangla'})

# %%
glow_wikis = pd.read_csv("../../data/raw/glow_wikis.csv", sep=',', encoding = 'utf-8', parse_dates=True)

# %% [markdown]
# #### Unique Devices - country <a class="anchor" id="devices"></a>
# [Back to Table of Contents](#toc)

# %%
co_uds.to_csv("../../data/processed/query_results/regional_counts/co_uds_2020_april.csv", sep=',', encoding = 'utf-8', parse_dates=True)

# %%
def yellow_focus(row):
    color = 'white'
    if row.values['-1'] == 'India':
        color = 'yellow'
    return ['background-color: %s' % color]*len(row.values)

# %%
co_uds.style.apply(yellow_focus, axis=1)

# %%
yellow_highlight = (co_uds.index == 'India').map({True:'background-color:yellow', False:''})
co_uds.style.apply(lambda s:yellow_highlight)

# %%
co_uds_pct_ch = co_uds[['2016', '2017', '2018']].copy()

# %%
co_uds_pct_ch.pct_change(axis = 1)

# %% [markdown]
# #### Unique Devices - domain <a class="anchor" id="devices"></a>
# [Back to Table of Contents](#toc)

# %%
devices = pd.read_csv("../../data/processed/query_results/regional_counts/devices.csv", sep=',', encoding = 'utf-8', parse_dates=True)

# %% [markdown]
# ## Articles<a class="anchor" id="editors"></a>
# [Back to Table of Contents](#toc)

# %% [markdown]
# ## Historical Article Counts

# %%
wiki_counts = pd.read_csv("../../data/processed/query_results/regional_counts/wiki_counts_India_2016_2020.csv", thousands=',', encoding = 'utf-8', parse_dates=True) #parse_dates=['date']

# %%
wiki_counts['date']= pd.to_datetime(wiki_counts['date'])

# %%
wiki_counts_arabic = pd.read_csv("../../data/processed/query_results/regional_counts/arabic/wiki_counts_mena_2016_2020.csv", thousands=',', encoding = 'utf-8', parse_dates=True)

# %%
fig, ax = plt.subplots(figsize=(15,11))
wiki_counts.groupby(['month_year', 'lang']).sum()['count'].unstack().plot(ax=ax)
plt.title('GLOW India Article Counts 2016-2020')
ax.set_xlabel('date')
ax.set_ylabel('count')
plt.title('GLOW India Article Counts 2016-2020')
plt.savefig('../../results/figs/regional_counts/india/wiki_counts_India_GLOW_2016_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('wiki counts India GLOW')
sns.lineplot(x="month_year", y="count", hue="lang", 
            data=wiki_counts)

plt.xticks(rotation=45)
plt.title('GLOW India Wiki Counts 2016-2020')

plt.tight_layout()
plt.savefig('../../results/figs/regional_counts/india/wiki_counts_India_GLOW_2016_2020_b.png')
plt.show();

# %%
pd.pivot_table(wiki_counts.reset_index(),
               index='month_year', columns='lang', values='count'
              ).plot(subplots=True, figsize=(15,21))

plt.savefig('../../results/figs/regional_counts/india/wiki_counts_India_GLOW_wiki_subplots_pivot.png');

# %%
wiki_counts_India_agg = wiki_counts.groupby('month_year').sum().plot(kind='bar', figsize=(15,11), grid=True)
plt.tight_layout()
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('GLOW India Article Counts Aggregated 2016-2020')
plt.xticks(rotation=45)
plt.savefig('../../results/figs/regional_counts/india/wiki_counts_India_GLOW_aggregated.png')
plt.show();

# %% [markdown]
# ## Articles added

# %%
new_per_wp = pd.read_csv("../../data/processed/query_results/regional_counts/edited_pages_new_19_20.csv",sep=',', encoding = 'utf-8', parse_dates=True)

# %%
new_per_wp_16_20 = pd.read_csv("../../data/processed/query_results/regional_counts/edited_pages_new_16_20.csv",sep=',', encoding = 'utf-8', parse_dates=True)

# %%
new_per_wp_20 = pd.read_csv("../../data/processed/query_results/regional_counts/edited_pages_new_india_indonesia_2020.csv",sep=',', encoding = 'utf-8', parse_dates=True)

# %%
new_per_wp_16_20['month'] = pd.to_datetime(new_per_wp_16_20['month'])
new_per_wp_16_20['month_year']= new_per_wp_16_20['month'].dt.to_period('M')
new_per_wp_16_20['date'] = new_per_wp_16_20['month'].apply(pd.to_datetime)
                                               
new_per_wp['month'] = pd.to_datetime(new_per_wp['month'])
new_per_wp['month_year']= new_per_wp['month'].dt.to_period('M')
new_per_wp['date'] = new_per_wp['month'].apply(pd.to_datetime)
del new_per_wp['index']
                                                           
new_per_wp_20['month'] = pd.to_datetime(new_per_wp_20['month'])
new_per_wp_20['year']= new_per_wp_20['month'].dt.to_period('Y')

# India_new_per_wp['date'] = pd.to_datetime(India_new_per_wp['month'], format = '%Y-%m-%d')
# Out:
# /home/iflorez/venv/lib/python3.5/site-packages/pandas/core/arrays/datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %%
new_per_wp_20.columns.to_list()
# Out:
# ['month', 'new_pages', 'project', 'date', 'month_year', 'countries', 'year']

# %%
columnsTitles = ['month', 'new_pages', 'project', 'year', 'countries','month_year', 'date']
new_per_wp_20 = new_per_wp_20.reindex(columns=columnsTitles)

# %%
new_articles_df = pd.concat([new_per_wp,new_per_wp_16_20, new_per_wp_20]).drop_duplicates().reset_index(drop=True)

new_articles_df['date'] = new_articles_df['date'].apply(pd.to_datetime)
new_articles_df['date'] =  pd.to_datetime(new_articles_df['date'],utc=True)
new_articles_df['date'] = new_articles_df['date'].dt.date

# %%
#df = new_articles_df[(new_articles_df['date'] >= '2018-01-01') & (new_articles_df['date'] < '2020-06-01')]
df = new_articles_df[(new_articles_df['date']>=datetime.date(2018,1,1)) & (new_articles_df['date']<datetime.date(2020,6,1))] \

india_new_per_wp = new_per_wp_16_20[(new_per_wp_16_20['countries']=='India')]
india_2019_new_per_wp = new_per_wp_16_20[(new_per_wp_16_20['countries']=='India') & (new_per_wp_16_20['year'] == 2019)]

india_glow_start = query_vars['contest_start_dt_first_day_of_m']
india_glow_end = query_vars['contest_end_dt_first_day_next_m']
india_glow_2019_12M_pre_mask = (new_per_wp['date']>= query_vars['contest_start_dt_first_day_12m_pre']) & (new_per_wp['date'] < india_glow_start) & (new_per_wp['countries']=='India')
india_glow_2019_5M_pre_mask = (new_per_wp['date']>= query_vars['contest_start_dt_first_day_5m_pre']) & (new_per_wp['date'] < india_glow_start) & (new_per_wp['countries']=='India')
india_glow_mask = (new_per_wp['date']>= india_glow_start) & (new_per_wp['date'] <= india_glow_end) & (new_per_wp['countries']=='India')

india_glow = new_per_wp.loc[india_glow_mask]
india_glow_2019_12M_pre = new_per_wp.loc[india_glow_2019_12M_pre_mask]
india_glow_2019_5M_pre = new_per_wp.loc[india_glow_2019_5M_pre_mask]

# %% [markdown]
# #### 2016-2020

# %%
India_new_per_wp.groupby('project')['new_pages'].describe()
# Out:
#                    count    mean          std    min     25%    50%     75%  \
# project
# as.wikipedia.org    50.0   50.18    39.283735    4.0   21.00   42.5   67.25
# bn.wikipedia.org    50.0  847.44   413.817625  338.0  566.25  699.0  947.25
# gu.wikipedia.org    50.0   56.06    33.754462    6.0   32.00   43.0   74.75
# hi.wikipedia.org    50.0  633.08   404.562694  294.0  443.25  537.0  662.00
# kn.wikipedia.org    50.0  154.04    94.780727   56.0  103.75  130.5  171.25
# ml.wikipedia.org    50.0  533.44   217.108659  183.0  380.75  486.5  646.25
# mr.wikipedia.org    50.0  246.24   124.081862   89.0  175.00  222.5  283.75
# or.wikipedia.org    50.0  110.66    75.561736   33.0   76.50   95.0  113.25
# pa.wikipedia.org    50.0  279.72   168.334463   76.0  152.25  252.0  353.75
# pnb.wikipedia.org   50.0  288.58   394.167844    2.0   63.00  157.0  288.25
# sa.wikipedia.org    50.0    9.54    11.201694    0.0    3.00    6.0   12.00
# sat.wikipedia.org   50.0   54.34    80.532820    0.0    0.00   22.0   60.75
# ta.wikipedia.org    50.0  730.48  1031.671840  172.0  349.75  463.5  730.25
# tcy.wikipedia.org   50.0   13.04    11.023093    1.0    5.00    9.0   18.75
# te.wikipedia.org    50.0  219.48   138.354210   84.0  150.25  189.5  231.75
# ur.wikipedia.org    50.0  554.10   206.932233  302.0  406.00  486.5  642.50
#
#                       max
# project
# as.wikipedia.org    163.0
# bn.wikipedia.org   2003.0
# gu.wikipedia.org    164.0
# hi.wikipedia.org   2599.0
# kn.wikipedia.org    551.0
# ml.wikipedia.org   1168.0
# mr.wikipedia.org    740.0
# or.wikipedia.org    488.0
# pa.wikipedia.org    890.0
# pnb.wikipedia.org  1746.0
# sa.wikipedia.org     68.0
# sat.wikipedia.org   293.0
# ta.wikipedia.org   7202.0
# tcy.wikipedia.org    49.0
# te.wikipedia.org    875.0
# ur.wikipedia.org   1380.0

# %% [raw]
# india_new_per_wp.groupby(['project', 'date'])['new_pages'].mean()

# %%
india_new_per_wp.groupby('project')['new_pages'].mean().plot(kind='bar')#.sort_values(by='new_pages')

# %% [markdown]
# #### 2019

# %%
india_glow_2019_12M_pre.describe()
# Out:
#             index    new_pages    year
# count  144.000000   144.000000   144.0
# mean     4.000000   262.868056  2019.0
# std      2.591001   331.732141     0.0
# min      0.000000     1.000000  2019.0
# 25%      2.000000    48.500000  2019.0
# 50%      4.000000   132.500000  2019.0
# 75%      6.000000   378.000000  2019.0
# max      8.000000  1879.000000  2019.0

# %%
india_glow_2019_5M_pre.describe()
# Out:
#            index    new_pages    year
# count  80.000000    80.000000    80.0
# mean    6.000000   261.862500  2019.0
# std     1.423136   374.144957     0.0
# min     4.000000     2.000000  2019.0
# 25%     5.000000    46.000000  2019.0
# 50%     6.000000   125.500000  2019.0
# 75%     7.000000   363.000000  2019.0
# max     8.000000  1879.000000  2019.0

# %%
india_glow.describe()
# Out:
#            index    new_pages         year
# count  80.000000    80.000000    80.000000
# mean   11.000000   412.962500  2019.400000
# std     1.423136   449.398739     0.492989
# min     9.000000     2.000000  2019.000000
# 25%    10.000000    99.000000  2019.000000
# 50%    11.000000   267.500000  2019.000000
# 75%    12.000000   591.500000  2020.000000
# max    13.000000  2003.000000  2020.000000

# %%
india_glow_2019_12M_pre.groupby('project')['new_pages'].describe()
# Out:
#                    count         mean         std    min    25%     50%  \
# project
# as.wikipedia.org     9.0    88.666667   38.285115   43.0   62.0    86.0
# bn.wikipedia.org     9.0  1218.000000  428.732726  593.0  899.0  1193.0
# gu.wikipedia.org     9.0    29.666667    6.442049   23.0   25.0    30.0
# hi.wikipedia.org     9.0   474.444444   91.564337  377.0  421.0   441.0
# kn.wikipedia.org     9.0   142.111111   50.686400   66.0  116.0   132.0
# ml.wikipedia.org     9.0   490.333333  148.741386  292.0  366.0   520.0
# mr.wikipedia.org     9.0   165.555556   55.655438   91.0  136.0   146.0
# or.wikipedia.org     9.0    67.666667   20.682118   41.0   49.0    68.0
# pa.wikipedia.org     9.0   109.777778   27.526250   76.0   84.0   109.0
# pnb.wikipedia.org    9.0   134.000000  114.567666    2.0   47.0    67.0
# sa.wikipedia.org     9.0     6.777778    4.465920    1.0    4.0     7.0
# sat.wikipedia.org    9.0    98.777778   63.377397   30.0   50.0    84.0
# ta.wikipedia.org     9.0   485.444444  253.872070  172.0  322.0   428.0
# tcy.wikipedia.org    9.0    16.000000   13.228757    2.0    5.0    15.0
# te.wikipedia.org     9.0   221.333333  191.287088  113.0  117.0   168.0
# ur.wikipedia.org     9.0   457.333333   89.404977  366.0  396.0   420.0
#
#                       75%     max
# project
# as.wikipedia.org    103.0   163.0
# bn.wikipedia.org   1587.0  1879.0
# gu.wikipedia.org     31.0    42.0
# hi.wikipedia.org    494.0   629.0
# kn.wikipedia.org    183.0   225.0
# ml.wikipedia.org    560.0   738.0
# mr.wikipedia.org    184.0   274.0
# or.wikipedia.org     85.0   100.0
# pa.wikipedia.org    133.0   151.0
# pnb.wikipedia.org   249.0   318.0
# sa.wikipedia.org      8.0    14.0
# sat.wikipedia.org   155.0   216.0
# ta.wikipedia.org    725.0   847.0
# tcy.wikipedia.org    23.0    42.0
# te.wikipedia.org    194.0   720.0
# ur.wikipedia.org    542.0   618.0

# %%
india_glow_2019_5M_pre.groupby('project')['new_pages'].describe()
# Out:
#                    count    mean         std     min     25%     50%     75%  \
# project
# as.wikipedia.org     5.0    94.6   47.626673    43.0    62.0    86.0   119.0
# bn.wikipedia.org     5.0  1533.6  263.995833  1193.0  1365.0  1587.0  1644.0
# gu.wikipedia.org     5.0    31.8    7.791020    23.0    26.0    31.0    37.0
# hi.wikipedia.org     5.0   492.4   71.570245   434.0   441.0   481.0   494.0
# kn.wikipedia.org     5.0   107.6   24.925890    66.0   107.0   116.0   117.0
# ml.wikipedia.org     5.0   453.0  138.964024   292.0   366.0   433.0   526.0
# mr.wikipedia.org     5.0   183.2   62.058037   136.0   138.0   146.0   222.0
# or.wikipedia.org     5.0    53.2   12.988456    41.0    42.0    49.0    66.0
# pa.wikipedia.org     5.0   123.2   21.614810   101.0   109.0   114.0   141.0
# pnb.wikipedia.org    5.0    83.0   99.877425     2.0    46.0    47.0    63.0
# sa.wikipedia.org     5.0     6.4    4.615192     2.0     4.0     5.0     7.0
# sat.wikipedia.org    5.0   127.6   71.612150    46.0    62.0   155.0   159.0
# ta.wikipedia.org     5.0   306.0   99.789779   172.0   246.0   322.0   362.0
# tcy.wikipedia.org    5.0    23.2   13.442470     4.0    23.0    23.0    24.0
# te.wikipedia.org     5.0   135.6   30.005000   113.0   116.0   117.0   150.0
# ur.wikipedia.org     5.0   435.4  104.114360   366.0   377.0   396.0   420.0
#
#                       max
# project
# as.wikipedia.org    163.0
# bn.wikipedia.org   1879.0
# gu.wikipedia.org     42.0
# hi.wikipedia.org    612.0
# kn.wikipedia.org    132.0
# ml.wikipedia.org    648.0
# mr.wikipedia.org    274.0
# or.wikipedia.org     68.0
# pa.wikipedia.org    151.0
# pnb.wikipedia.org   257.0
# sa.wikipedia.org     14.0
# sat.wikipedia.org   216.0
# ta.wikipedia.org    428.0
# tcy.wikipedia.org    42.0
# te.wikipedia.org    182.0
# ur.wikipedia.org    618.0

# %%
india_glow.groupby('project')['new_pages'].describe()
# Out:
#                    count    mean         std     min     25%     50%     75%  \
# project
# as.wikipedia.org     5.0    97.6   43.113803    46.0    68.0   104.0   112.0
# bn.wikipedia.org     5.0  1591.0  297.916935  1215.0  1423.0  1598.0  1716.0
# gu.wikipedia.org     5.0    51.8   25.351529    31.0    33.0    50.0    51.0
# hi.wikipedia.org     5.0   676.0  162.983128   509.0   544.0   656.0   766.0
# kn.wikipedia.org     5.0   163.8  104.327369   103.0   108.0   114.0   146.0
# ml.wikipedia.org     5.0   439.8  149.808878   266.0   326.0   423.0   591.0
# mr.wikipedia.org     5.0   274.0   40.205721   225.0   243.0   286.0   290.0
# or.wikipedia.org     5.0    95.4   13.992855    76.0    90.0    96.0   101.0
# pa.wikipedia.org     5.0   423.6  222.872834   100.0   300.0   497.0   569.0
# pnb.wikipedia.org    5.0   888.6  602.384678   203.0   313.0  1057.0  1324.0
# sa.wikipedia.org     5.0     9.8   10.917875     2.0     3.0     4.0    12.0
# sat.wikipedia.org    5.0   245.6   46.591845   194.0   197.0   269.0   275.0
# ta.wikipedia.org     5.0   769.4  240.785797   478.0   594.0   763.0   960.0
# tcy.wikipedia.org    5.0    26.0   16.688319    10.0    15.0    18.0    38.0
# te.wikipedia.org     5.0   209.2   81.152326   148.0   153.0   188.0   210.0
# ur.wikipedia.org     5.0   645.8  178.974020   466.0   517.0   635.0   687.0
#
#                       max
# project
# as.wikipedia.org    158.0
# bn.wikipedia.org   2003.0
# gu.wikipedia.org     94.0
# hi.wikipedia.org    905.0
# kn.wikipedia.org    348.0
# ml.wikipedia.org    593.0
# mr.wikipedia.org    326.0
# or.wikipedia.org    114.0
# pa.wikipedia.org    652.0
# pnb.wikipedia.org  1546.0
# sa.wikipedia.org     28.0
# sat.wikipedia.org   293.0
# ta.wikipedia.org   1052.0
# tcy.wikipedia.org    49.0
# te.wikipedia.org    347.0
# ur.wikipedia.org    924.0

# %%
india_2019_new_per_wp.groupby('project')['new_pages'].describe()
# Out:
#                    count         mean         std    min     25%     50%  \
# project
# as.wikipedia.org    12.0    92.166667   40.945270   43.0   58.00    94.0
# bn.wikipedia.org    12.0  1332.166667  438.669027  593.0  910.25  1394.0
# gu.wikipedia.org    12.0    38.500000   20.006817   23.0   25.75    30.5
# hi.wikipedia.org    12.0   498.250000   94.995813  377.0  430.75   487.5
# kn.wikipedia.org    12.0   136.833333   45.280607   66.0  112.25   124.5
# ml.wikipedia.org    12.0   501.666667  135.061826  292.0  408.75   523.0
# mr.wikipedia.org    12.0   195.750000   74.508236   91.0  137.50   180.0
# or.wikipedia.org    12.0    74.666667   21.839636   41.0   61.75    78.5
# pa.wikipedia.org    12.0   225.500000  213.241860   76.0   96.75   123.5
# pnb.wikipedia.org   12.0   427.750000  550.314807    2.0   59.00   203.0
# sa.wikipedia.org    12.0     8.666667    7.438638    1.0    3.75     7.0
# sat.wikipedia.org   12.0   143.833333   97.945099   30.0   59.00   121.0
# ta.wikipedia.org    12.0   581.250000  295.947822  172.0  352.00   512.0
# tcy.wikipedia.org   12.0    20.750000   15.685112    2.0    5.75    20.5
# te.wikipedia.org    12.0   223.333333  169.021426  113.0  141.75   175.0
# ur.wikipedia.org    12.0   530.166667  165.798253  366.0  402.00   494.0
#
#                        75%     max
# project
# as.wikipedia.org    107.75   163.0
# bn.wikipedia.org   1609.50  2003.0
# gu.wikipedia.org     44.00    94.0
# hi.wikipedia.org    561.00   656.0
# kn.wikipedia.org    155.25   225.0
# ml.wikipedia.org    591.50   738.0
# mr.wikipedia.org    250.75   326.0
# or.wikipedia.org     91.50   101.0
# pa.wikipedia.org    237.50   652.0
# pnb.wikipedia.org   502.75  1546.0
# sa.wikipedia.org     12.25    28.0
# sat.wikipedia.org   229.25   293.0
# ta.wikipedia.org    839.50  1052.0
# tcy.wikipedia.org    27.50    49.0
# te.wikipedia.org    203.50   720.0
# ur.wikipedia.org    622.25   924.0

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('India pages added per month 2016-2019')
sns.lineplot(x="month", y="new_pages", hue="countries", 
            data=new_per_wp_16_20[new_per_wp_16_20.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.title('Indic Wikis: number pages added per month 2016-2020')

plt.tight_layout()
#plt.savefig('figs/p_GLOW_avg_pages_added_per_month_2016_2020');
plt.savefig('../../results/figs/regional_counts/india/pages_added_per_month_GLOW_India_2016_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('India pages added per month 2019-2020')
sns.lineplot(x="month", y="new_pages", hue="countries", 
            data=new_per_wp[new_per_wp.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.title('Indic Wikis: number of pages added per month Jan_2019-Feb_2019')

plt.tight_layout()

plt.savefig('../../results/figs/regional_counts/india/pages_added_per_month_GLOW_India_2019_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('India pages added per month 2018-2020')
sns.lineplot(x="date", y="new_pages", 
            data=new_articles_df[new_articles_df.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.title('Indic Wikis: number of pages added per month 2018-2020')

plt.tight_layout()



fig.autofmt_xdate()
#ax.set_xlim([datetime.date(2018, 1, 1), datetime.date(2020, 6, 1)])
ax.set_xlim(z, new_articles_df['date'].max())
ax.set_ylim([0, 900])

plt.savefig('../../results/figs/regional_counts/india/pages_added_per_month_GLOW_India_2018_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('Indic Wikis: number of pages added per month 2016-2020')
sns.lineplot(x="date", y="new_pages", hue="countries", 
            data=new_articles_df[new_articles_df.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.title('Indic Wikis: number of pages added per month 2016-2020')

plt.tight_layout()

plt.savefig('../../results/figs/regional_counts/india/pages_added_per_month_GLOW_India_2016_May_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('India wikis pages added per month 2016-2020')
sns.lineplot(x="date", y="new_pages", hue="project", 
            data=new_articles_df[new_articles_df.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('Indic wikis: number of pages added per month 2016-2020')
ax.set_xlim(z, new_articles_df['date'].max())
#ax.set_ylim([0, 3000])
plt.tight_layout()
plt.show();

# %%
new_articles_df['pct_ch'] = (new_articles_df.groupby('project')['new_pages'].apply(pd.Series.pct_change) + 1)
new_articles_df['percentile_rank'] = new_articles_df.groupby(['date', 'project'])['new_pages'].rank(pct=True)

new_articles_df = new_articles_df.sort_values(['new_pages']).reset_index(drop=True)
d= new_articles_df[new_articles_df.countries.isin(['India'])]
d = d.copy()

# %%
import datetime
z = datetime.date(2018,1,1)
y = datetime.date(2019,1,1)
ptp = datetime.date(2018,5,1)
c = datetime.date(2019,10,10)
e = datetime.date(2020,1,11)

# %%
#df.query('during > pre')
#(df["B"] > 50) & (df["C"] == 900)
# df['col'] = df['col'].dt.to_period("Q") #avg by quarter

# %%
#create before, during, after columns
#https://stackoverflow.com/questions/47218138/python-pandas-if-datetime-values-fall-under-certain-date-duration-create-a-col
#https://stackoverflow.com/questions/19913659/pandas-conditional-creation-of-a-series-dataframe-column?noredirect=1&lq=1

d = d.copy()
### id periods                                                                                                                 
period_conditions = [
    (d['date'] < ptp), #hist
    (d['date'] >= ptp) & (d['date'] < c),#pre
    (d['date'] >= c) & (d['date'] < e),#during
    (d['date'] >e)#post
              ]
mchoices = ['hist_max', 'pre_max', 'during_max', 'post_max']
d['period'] = np.select(period_conditions, mchoices, default='m')
#get each group's pre, during, & post contest max 
df_max = d.groupby(['project', 'period']).agg({'new_pages':'max'}).unstack('period').reset_index()

#get each group's pre & during & post contest avg
achoices = ['hist_avg', 'pre_avg', 'during_avg', 'post_avg']
d['period'] = np.select(period_conditions, achoices, default='a')
df_avg = d.groupby(['project', 'period']).agg({'new_pages':'mean'}).unstack('period').reset_index()

#merge
df_avg_max= df_max.merge(df_avg, how='left', on='project').drop_duplicates().reset_index()
#flatten multiindex and rename columns, then delete index column
df_avg_max.columns = df_avg_max.columns.get_level_values(0)
df_avg_max.columns =['index','project','during_max','hist_max','post_max','pre_max','during_avg','hist_avg','post_avg','pre_avg']
del df_avg_max['index']

# %%
### categorize max and averages
ma_labels = ['sustained', 'post','contained','hist', 'pre']
#identify rows where wikis reached new highs during the contest, compared to pre contest etc.

max_cond = [
    (df_avg_max['during_max'] > df_avg_max['pre_max']) & (df_avg_max['post_max'] >df_avg_max['during_max']), #sustained
    
    
    (df_avg_max['post_max'] > df_avg_max['during_max']) & (df_avg_max['post_max'] > df_avg_max['pre_max']), #post-op
    
    
    (df_avg_max['during_max'] > df_avg_max['post_max']) & (df_avg_max['during_max']>df_avg_max['pre_max'] ), #contest-only
    
    (df_avg_max['hist_max'] > df_avg_max['pre_max']),#hist
    (df_avg_max['pre_max'] > df_avg_max['during_max']) & (df_avg_max['pre_max'] > df_avg_max['post_max']),#pre
    
    
]
 
avg_cond = [
    (df_avg_max['pre_avg']  < df_avg_max['during_avg']) & (df_avg_max['during_avg'] > df_avg_max['post_avg']), #sustained
    
    (df_avg_max['post_avg'] > df_avg_max['during_avg']) & (df_avg_max['post_avg']   > df_avg_max['pre_avg']), #post-op
    
    
    (df_avg_max['during_avg'] > df_avg_max['pre_avg']) & (df_avg_max['during_avg']> df_avg_max['post_avg']), #contest-only
    
    (df_avg_max['hist_avg'] > df_avg_max['pre_avg']),#hist
    (df_avg_max['pre_avg'] > df_avg_max['during_avg']) & (df_avg_max['pre_avg']  > df_avg_max['post_avg']),#pre
    
]
    

df_avg_max['impact_group_max'] = np.select(max_cond, ma_labels, default='m')                                                 
df_avg_max['impact_group_avg'] = np.select(avg_cond, ma_labels, default='a')

# %%
ig_u = df_avg_max.merge(glow_wikis, how='left', on='project').merge(c_w_editors, how='left', on='language_name').drop_duplicates().reset_index()

# %%
ig_u.columns
# Out:
# Index(['index', 'project', 'during_max', 'hist_max', 'post_max', 'pre_max',
#        'during_avg', 'hist_avg', 'post_avg', 'pre_avg', 'impact_group_max',
#        'impact_group_avg', 'language_name', 'database_code', 'article_total',
#        'total_editor_count', 'contest_link'],
#       dtype='object')

# %%
igu_cols = [
'project', 
 'language_name',
 'impact_group_max', 
 'impact_group_avg',
 'total_editor_count',
 'hist_max',
 'pre_max',
 'during_max',
 'post_max',
 'hist_avg',
 'pre_avg',
 'during_avg',
 'post_avg', 
 'database_code',
 'contest_link']
ig_u = ig_u[igu_cols]

# %%
ig_u.sort_values(by=['impact_group_avg', 'impact_group_max', 'total_editor_count'])

# %%
ig_u.to_csv("../../data/processed/ig_u.csv", index=False)

# %%
ig_u.groupby(['impact_group_max'])['total_editor_count'].mean().reset_index().sort_values(by='total_editor_count')
# Out:
#   impact_group_max  total_editor_count
# 1             hist           15.166667
# 3              pre           19.500000
# 2             post           20.666667
# 0        contained           32.000000
# 4        sustained           49.000000

# %%
ig_u.groupby(['impact_group_avg'])['total_editor_count'].mean().reset_index().sort_values(by='total_editor_count')
# Out:
#   impact_group_avg  total_editor_count
# 1              pre            8.000000
# 0             post           23.200000
# 2        sustained           23.666667

# %%
g = sns.FacetGrid(d, col="project", col_wrap=5) 
g.map(plt.scatter, "date","new_pages", alpha=.7)
plt.gcf().set_size_inches(15, 15)
plt.show()
g.add_legend();

# %%
#divide into groups given the above and chart below
g1 = ['hi.wikipedia.org', 'ta.wikipedia.org','bn.wikipedia.org', 'ur.wikipedia.org']
g2 = ['ml.wikipedia.org', 'mr.wikipedia.org', 'pa.wikipedia.org']
g3 = ['te.wikipedia.org', 'kn.wikipedia.org', 'sat.wikipedia.org']
g4 = ['pnb.wikipedia.org']
g5 = ['tcy.wikipedia.org', 'sa.wikipedia.org', 'as.wikipedia.org', 'gu.wikipedia.org', 'or.wikipedia.org']

g1df = d[d.project.isin(g1)]
g2df = d[d.project.isin(g2)]
g3df = d[d.project.isin(g3)]
g4df = d[d.project.isin(g4)]
g5df = d[d.project.isin(g5)]

#graph

f, axes =  plt.subplots(nrows=2, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)

sns.lineplot(data=g5df[g5df.date>z], x='date', y='new_pages', hue="project", ax=axes[0,0], legend='brief')
sns.lineplot(data=g4df[g4df.date>z], x='date', y='new_pages', hue="project", ax=axes[0,1], legend='brief')

#sns.lineplot(data=d[d.project=='pnb.wikipedia.org'], x='date', y='new_pages', hue="project", ax=axes[0,2], legend='brief')

sns.lineplot(data=g3df[g3df.date>z], x='date', y='new_pages', hue="project", ax=axes[1,0], legend='brief')
sns.lineplot(data=g2df[g2df.date>z], x='date', y='new_pages', hue="project", ax=axes[1,1], legend='brief')
sns.lineplot(data=g1df[g1df.date>z], x='date', y='new_pages', hue="project", ax=axes[1,2], legend='brief');

# %%
#divide into groups given the above and chart below
n1 = ['bn.wikipedia.org', 'ur.wikipedia.org']
n2 = ['ml.wikipedia.org', 'mr.wikipedia.org', ]
n3 = ['te.wikipedia.org', 'gu.wikipedia.org','as.wikipedia.org','pa.wikipedia.org', 'ta.wikipedia.org']
n4 = ['pnb.wikipedia.org','or.wikipedia.org','hi.wikipedia.org']
n5 = ['tcy.wikipedia.org', 'sa.wikipedia.org', 'kn.wikipedia.org', 'sat.wikipedia.org']

n1df = d[d.project.isin(n1)]
n2df = d[d.project.isin(n2)]
n3df = d[d.project.isin(n3)]
n4df = d[d.project.isin(n4)]
n5df = d[d.project.isin(n5)]

#graph

f, axes =  plt.subplots(nrows=2, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)

sns.lineplot(data=n5df[n5df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[0,0], legend='brief')


#sns.lineplot(data=d[d.project=='pnb.wikipedia.org'], x='date', y='new_pages', hue="project", ax=axes[0,2], legend='brief')

sns.lineplot(data=n3df[n3df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[0,1], legend='brief')
sns.lineplot(data=n2df[n2df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[0,2], legend='brief')

sns.lineplot(data=n4df[n4df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[1,1], legend='brief')
sns.lineplot(data=n1df[n1df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[1,2], legend='brief');

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('---')
sns.lineplot(x="date", y="new_pages", hue="project", 
            data=g1df)

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('---')
ax.set_xlim(z, new_articles_df['date'].max())
ax.set_ylim([0, 3500])
plt.tight_layout()
plt.show();

# %%
#https://meta.wikimedia.org/wiki/Growing_Local_Language_Content_on_Wikipedia_(Project_Tiger_2.0)/Writing_Contest/Edit-a-thons_and_requests
g0 =['te.wikipedia.org', 'ta.wikipedia.org','gu.wikipedia.org', 'pa.wikipedia.org']

g0df = d[d.project.isin(g0)]

sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('---')
sns.lineplot(x="date", y="pct_ch", hue="project", 
            data=g0df)

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('---')
ax.set_xlim(y, new_articles_df['date'].max())
#ax.set_ylim([0, 3000])
plt.tight_layout()
plt.show();

# %%
f, axes =  plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=g0df[g0df.date>=c], x='date', y='new_pages', hue="project", ax=axes[0], legend='brief')
sns.lineplot(data=g2df[g2df.date>=c], x='date', y='new_pages', hue="project", ax=axes[1], legend='brief')
sns.lineplot(data=g1df[g1df.date>=c], x='date', y='new_pages', hue="project", ax=axes[2], legend='brief');

# %%
f, axes =  plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=g0df[g0df.date>=y], x='date', y='new_pages', hue="project", ax=axes[0], legend='brief')
sns.lineplot(data=g2df[g2df.date>=y], x='date', y='new_pages', hue="project", ax=axes[1], legend='brief')
sns.lineplot(data=g1df[g1df.date>=y], x='date', y='new_pages', hue="project", ax=axes[2], legend='brief');

# %%
f, axes =  plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=g0df[g0df.date>=z], x='date', y='new_pages', hue="project", ax=axes[0], legend='brief')
sns.lineplot(data=g2df[g2df.date>=z], x='date', y='new_pages', hue="project", ax=axes[1], legend='brief')
sns.lineplot(data=g1df[g1df.date>=z], x='date', y='new_pages', hue="project", ax=axes[2], legend='brief');

# %%
c = datetime.date(2019,10,1)
f, axes =  plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=g0df[g0df.date>=c], x='date', y='pct_ch', ax=axes[0], legend='brief')
sns.lineplot(data=g2df[g2df.date>=c], x='date', y='pct_ch', ax=axes[1], legend='brief')
sns.lineplot(data=g1df[g1df.date>=c], x='date', y='pct_ch', ax=axes[2], legend='brief');

# %%
f, axes =  plt.subplots(nrows=1, ncols=2, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=n3df[n3df.date>=c], x='date', y='pct_ch', hue="project", ax=axes[0], legend='brief')
sns.lineplot(data=n2df[n2df.date>c], x='date', y='pct_ch', hue="project", ax=axes[1], legend='brief');

# %%
f, axes =  plt.subplots(nrows=1, ncols=2, figsize=(18, 6), sharex=True, sharey=True)
plt.xticks(rotation=45)
sns.lineplot(data=n3df[n3df.date>=y], x='date', y='pct_ch', hue="project", ax=axes[0], legend='brief')
sns.lineplot(data=n2df[n2df.date>y], x='date', y='pct_ch', hue="project", ax=axes[1], legend='brief');

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('---')
sns.lineplot(x="date", y="pct_ch", hue="project", 
            data=new_articles_df[new_articles_df.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('---')
ax.set_xlim(c, new_articles_df['date'].max())
ax.set_ylim([0, 20])
plt.tight_layout()
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)
#ax= sns.catplot(x="month", y="new_pages", hue="countries", kind="point", height=8.27, aspect=11.7/8.27, data=new_per_wp[new_per_wp.countries.isin(['India','Indonesia'])])

ax.set_title('India wikis pages added per month 2016-2020')
sns.lineplot(x="month", y="new_pages", hue="project", 
            data=new_per_wp_16_20[new_per_wp_16_20.countries.isin(['India'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('Indic wikis: number of pages added per month 2016-2020')

plt.tight_layout()
#plt.savefig('figs/p_India_avg_pages_added_per_month_2016_2019')
plt.savefig('../../results/figs/regional_counts/india/pages_added_per_month_GLOW_Indic_wikis_2016_2020.png')
plt.show();

# %% [raw]
# #CHART!
# #https://seaborn.pydata.org/generated/seaborn.catplot.html
#
#
# sns.set()
# ax = sns.catplot(
#     #height=8.27, aspect=11.7/8.27,
#     x="month",
#     y="new_pages",
#     hue='project',
#     col='countries',
#     data=new_per_wp[new_per_wp.countries.isin(['India'])],
#     col_wrap=3)
#
# fig.subplots_adjust(wspace=0, hspace=0)
#
# for ax in ax.axes:
#     for label in ax.get_xticklabels():
#         label.set_rotation(45)
#         label.set_ha('right')
#         label.set_visible(False)
#
# plt.setp(ax.axes.get_xticklabels()[::5], visible=True)
# #plt.savefig('figs/p_comparative_avg_pages_added_per_month_2016_2019');

# %% [markdown]
# ## Glow regions visualizations --- beyond Indic wikis

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('Glow regions pages added per month 2016-2019')
sns.lineplot(x="month", y="new_pages", hue="countries", 
            data=new_per_wp_16_20)

plt.xticks(rotation=45)
plt.title('GLOW regions: Number pages added per month 2016-2020')

plt.tight_layout()
#plt.savefig('figs/p_GLOW_avg_pages_added_per_month_2016_2019');

plt.savefig('../../results/figs/regional_counts/pages_added_per_month_GLOW_regions_2016_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('India/Indonesia avg pages added per month 2016-2019')
sns.lineplot(x="month", y="new_pages", hue="countries", 
            data=new_per_wp)

plt.xticks(rotation=45)
plt.title('GLOW avg pages added per month 2016-2019')

plt.tight_layout()
#plt.savefig('figs/p_GLOW_avg_pages_added_per_month_2016_2019')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)
#ax= sns.catplot(x="month", y="new_pages", hue="countries", kind="point", height=8.27, aspect=11.7/8.27, data=new_per_wp[new_per_wp.countries.isin(['India','Indonesia'])])

ax.set_title('Arabic wiki pages added per month 2016-2020')
sns.lineplot(x="month", y="new_pages", hue="project", 
            data=new_per_wp_16_20[new_per_wp_16_20.countries.isin(['MENA'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('Arabic wiki: number of pages added per month 2016-2020')

plt.tight_layout()
plt.savefig('../../results/figs/regional_counts/mena/pages_added_per_month_GLOW_arabic_2016_2020.png')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)

ax.set_title('wiki counts MENA GLOW')
sns.lineplot(x="month_year", y="count", hue="lang", 
            data=wiki_counts_arabic)

plt.xticks(rotation=45)
plt.title('GLOW Arabic Wiki Counts 2016-2020')

plt.tight_layout()
plt.savefig('../../results/figs/regional_counts/mena/wiki_counts_mena_GLOW_2016_2020.png')
plt.show();

# %%
ax = wiki_counts_arabic.plot()
new_per_wp_16_20[new_per_wp_16_20.countries.isin(['MENA'])].plot(ax=ax);

# %%
#CHART!
#https://seaborn.pydata.org/generated/seaborn.catplot.html


sns.set() 
ax = sns.catplot(
    #height=8.27, aspect=11.7/8.27, 
    x="month", 
    y="new_pages", 
    hue='project', 
    col='countries', 
    data=new_per_wp, 
    col_wrap=3)

fig.subplots_adjust(wspace=0, hspace=0)

for ax in ax.axes:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha('right')
        label.set_visible(False)
        
plt.setp(ax.axes.get_xticklabels()[::5], visible=True)
plt.savefig('figs/p_comparative_avg_pages_added_per_month_2016_2019')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)
#ax= sns.catplot(x="month", y="new_pages", hue="countries", kind="point", height=8.27, aspect=11.7/8.27, data=new_per_wp[new_per_wp.countries.isin(['India','Indonesia'])])

ax.set_title('India/Indonesia avg pages added per month 2016-2019')
sns.lineplot(x="month", y="new_pages", hue="countries", 
            data=new_per_wp[new_per_wp.countries.isin(['India','Indonesia'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('India/Indonesia avg pages added per month 2016-2019')

plt.tight_layout()
plt.savefig('figs/p_India_Indonesia_avg_pages_added_per_month_2016_2019')
plt.show();

# %%
sns.set() 
fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)
#ax= sns.catplot(x="month", y="new_pages", hue="countries", kind="point", height=8.27, aspect=11.7/8.27, data=new_per_wp[new_per_wp.countries.isin(['India','Indonesia'])])

ax.set_title('India/Indonesia avg pages added per month 2016-2019')
sns.lineplot(x="month", y="new_pages", hue="project", 
            data=new_per_wp[new_per_wp.countries.isin(['Indonesia'])])

plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels()[1::2], visible=False, weight='light')
plt.title('Indonesia avg pages added per month 2016-2019')

plt.tight_layout()
plt.savefig('figs/p_Indonesia_avg_pages_added_per_month_2016_2019')
plt.show();

# %%
npwp_pivot = pd.pivot_table(new_per_wp, index = 'project', values = 'new_pages', columns = 'year', aggfunc=[np.mean, len, min, max])

# %%
#change column names, see also:
#https://stackoverflow.com/questions/42060394/how-to-change-the-columns-name-from-a-tuple-to-string

my_colnames = []
for i, a in enumerate(npwp_pivot.columns.get_level_values(1)):
    my_colnames.append(str(a) + '_' + str(npwp_pivot.columns.get_level_values(0)[i]))
npwp_pivot.columns = my_colnames

# %% [raw]
# npwp_pivot.columns = npwp_pivot.columns.droplevel(0)
# npwp_pivot.columns.name = None
# npwp_pivot = npwp_pivot.reset_index()

# %%
#sort columns
npwp_pivot = npwp_pivot.reindex(sorted(npwp_pivot.columns), axis=1)

#shift project column to first place
cols = list(npwp_pivot.columns)
cols =[cols[-1]] + cols[:-1]
npwp_pivot = npwp_pivot[cols]

#reset index
npwp_pivot = npwp_pivot.reset_index()

# %%
#create df with 2019 data to merge in... USE CONTEST PERIOD AND/OR COMPARISON PERIOD 
current_articles_added_avg = npwp_pivot[['project', '2019_mean', '2019_min', '2019_max']]

#rename column names
current_articles_added_avg.rename(columns = 
                                 {
                                   'project' : 'wiki',
                                   '2019_mean':'avg_m_articles_added',
                                   '2019_min': 'min_articles_added',
                                   '2019_max': 'max_articles_added'  
                                 }
                                 );

# %%
#create new countries column
current_articles_added_avg['countries'] = current_articles_added_avg['project'].apply(add_country_column).str[0]
#rename the MENA entry in the countries column
current_articles_added_avg['countries'] = current_articles_added_avg['countries'].replace({'M':'MENA'})

#shift project column to first place
cols = list(current_articles_added_avg.columns)
cols =[cols[-1]] + cols[:-1]
current_articles_added_avg = current_articles_added_avg[cols]

#sort table
current_articles_added_avg.sort_values(['countries', '2019_mean'], ascending=[True, False]);
# Out:
# /home/iflorez/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/iflorez/venv/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#sort and reset index
current_articles_added_avg = current_articles_added_avg.sort_values(by=['2019_mean'], ascending=False)
current_articles_added_avg.reset_index(drop=True, inplace=True)

# %%
current_articles_added_avg

# %%
# Setting the positions and width for the bars
pos = list(range(len(current_articles_added_avg['2019_min']))) 
width = 0.25
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(12.1,8.9))

# Create a bar with min data,
# in position pos,
plt.bar(pos, 
        #using df,
        current_articles_added_avg['2019_min'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the first value in first_name
        label=current_articles_added_avg['project'][0]) 

# Create a bar with mean data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df,
        current_articles_added_avg['2019_mean'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=current_articles_added_avg['project'][1]) 

# Create a bar with max data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df,
        current_articles_added_avg['2019_max'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color= '#EE3224',    
        # with label the third value in first_name
        label=current_articles_added_avg['project'][2]) 




# Set the y axis label
ax.set_ylabel('pages_added')

# Set the chart's title
ax.set_title('avg pages added per month 2016-2019')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(current_articles_added_avg['project'])

plt.xticks(rotation=45, ha='right')

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(current_articles_added_avg['2019_min'] + current_articles_added_avg['2019_mean'] + current_articles_added_avg['2019_max'])] )

# Adding the legend and showing the plot
plt.legend(['2019_min', '2019_mean', '2019_max'], loc='upper right')
plt.grid()
plt.savefig('figs/p_avg_pages_added_per_month_2016_2019')
plt.show();

# %%
include_list = ['Argentina', 'India', 'Indonesia']
caaa_iia = current_articles_added_avg[current_articles_added_avg.countries.isin(include_list)].sort_values(by=['2019_mean'], ascending=False)
caaa_iia .reset_index(drop=True, inplace=True)

# %%
caaa_iia

# %%
# Setting the positions and width for the bars
pos = list(range(len(caaa_iia['2019_min']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(12.1,8.9))

# Create a bar with min data,
# in position pos,
plt.bar(pos, 
        #using df
        caaa_iia['2019_min'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the first value in first_name
        label=caaa_iia['project'][0]) 

# Create a bar with mean data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df
        caaa_iia['2019_mean'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=caaa_iia['project'][1]) 

# Create a bar with max data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df
        caaa_iia['2019_max'], 
        #current_articles_added_avg[current_articles_added_avg.countries.isin(['India'])])
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color= '#EE3224',    
        # with label the third value in first_name
        label=caaa_iia['project'][2]) 

# Set the y axis label
ax.set_ylabel('pages_added')

# Set the chart's title
ax.set_title('India/Indonesia/Argentina avg pages added per month 2016-2019')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(caaa_iia['project'])

plt.xticks(rotation=45, ha='right')

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(caaa_iia['2019_min'] + caaa_iia['2019_mean'] + caaa_iia['2019_max'])] )

# Adding the legend and showing the plot
plt.legend(['2019_min', '2019_mean', '2019_max'], loc='upper right')
plt.grid()
plt.savefig('figs/p_India_Indonesia_Argentina_avg_pages_added_per_month_2016_2019')
plt.show();
