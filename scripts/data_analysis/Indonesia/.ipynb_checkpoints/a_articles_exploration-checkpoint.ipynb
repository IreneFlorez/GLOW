# %% [markdown]
# # Quick Exploration

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np

#%load_ext sql_magic
# %matplotlib inline

# %% [raw]
# id_articles_pv = pd.read_csv("../../../data/raw/articles/2019/query_results/content_quality/per_wiki_full/Indonesia/id_writing_contest_monthly_challenge_articles_pv.csv", sep=',', encoding = 'utf-8')

# %%
indonesia = pd.read_csv("../../../data/raw/articles/2019/query_results/content_quality/per_wiki_full/Indonesia/articles_w_july_incountry_pageviews_recs.csv", sep=',')

# %%
indonesia = indonesia.reindex(sorted(indonesia.columns), axis=1)

# %% [raw]
# indonesia['page_len']  = indonesia['page_len'].fillna(0)
# indonesia['page_len']  = indonesia['page_len'].replace('False', 0)
# indonesia['page_len'] = pd.to_numeric(indonesia['page_len'])

# %%
g = indonesia.columns.to_series().groupby(indonesia.dtypes).groups
g
# Out:
# {dtype('bool'): Index(['g_suggestion'], dtype='object'),
#  dtype('int64'): Index(['QID', 'Unnamed: 0', 'page_id'], dtype='object'),
#  dtype('float64'): Index(['IP_editors', 'all_editors_of_all_edits', 'editors_1stM', 'editors_nm',
#         'edits_1M', 'ipl_count', 'is_double_redirect', 'iwsitelinks',
#         'july_view_count_internal', 'micro_editors', 'minor_edits_all_time',
#         'num_edits_all_time', 'oel_links', 'oplinks', 'p1_is_redirect',
#         'page_len', 'recs_given_order', 'relative_page_len', 'revertrate',
#         'rpage_id', 'rpage_len', 'talk_page_edits', 'watch_count'],
#        dtype='object'),
#  dtype('O'): Index(['article_type', 'at_create', 'at_edits', 'contest_article_type',
#         'database_code', 'filename', 'first_edited', 'iwsites', 'language_code',
#         'language_name', 'last_edited', 'page_title', 'project', 'recs_Topic',
#         'recs_article_suggestion', 'recs_local_encoded_title',
#         'recs_suggestion_type', 'rpage_title', 'translation_tool', 'url',
#         'url_article_info'],
#        dtype='object')}

# %%
# 'at_edits' bool
#'first_edited',
#'last_edited',

# %%
cols = ["rpage_title"]
indonesia[cols] = indonesia[cols].replace({'0':np.nan, 0:np.nan})

# %%
indonesia_total_submitted= 2135
indonesia_total_approved = 1794
indonesia_total_approved_clean_ids = len(indonesia) - len(indonesia[~indonesia['rpage_title'].isnull()])

india_total_submitted =13459 
india_total_approved = 9173
india_total_approved_clean_ids = 8863

p_id_ta = 100* indonesia_total_approved /indonesia_total_submitted
p_id_tas = 100* indonesia_total_approved_clean_ids /indonesia_total_submitted

p_in_ta = 100* india_total_approved /india_total_submitted
p_in_tas = 100* india_total_approved_clean_ids /india_total_submitted

print(p_id_ta, p_id_tas)
print('***')
print(p_in_ta, p_in_tas)
# Out:
# 84.02810304449649 80.70257611241217
# ***
# 68.15513782599004 65.85184634816851

# %%
len(indonesia)
# Out:
# 1793

# %%
len(indonesia[indonesia['article_type'].isnull()])
# Out:
# 0

# %%
indonesia['article_type'].unique()
# Out:
# array(['new', 'post', 'expanded', '0'], dtype=object)

# %%
article_types = indonesia['article_type'].value_counts().reset_index().rename(columns={'index':'type', 'article_type': 'count'})


article_type_new =  article_types[article_types['type']=='new'].values[0,1]+ article_types[article_types['type']=='post'].values[0,1]
article_type_expanded =  article_types[article_types['type']=='expanded'].values[0,1]

# %%
article_types
# Out:
#        type  count
# 0       new   1476
# 1      post    135
# 2         0    135
# 3  expanded     47

# %%
P = indonesia.groupby('g_suggestion')['article_type'].value_counts().to_frame()

# %%
P
# Out:
#                            article_type
# g_suggestion article_type
# False        new                   1035
#              post                   132
#              0                       73
#              expanded                16
# True         new                    441
#              0                       62
#              expanded                31
#              post                     3

# %%
441+62+31+3
# Out:
# 537

# %%
1413+63
# Out:
# 1476

# %%
#Percent of new articles that were google suggestions
100*618/(article_type_new)
# Out:
# 38.361266294227185

# %%
#Percent of new articles google suggestions selected from g list
100*618/8393
# Out:
# 7.363278922911951

# %%
#Percent of expanded articles that were google suggestions
100*31/(article_type_expanded)
# Out:
# 65.95744680851064

# %%
#Percent of expanded articles google suggestions selected from g list
100*31/8393
# Out:
# 0.36935541522697485

# %%
indonesia['translation_tool'].value_counts()
# Out:
# 0       1792
# True       1
# Name: translation_tool, dtype: int64

# %%
indonesia.groupby('translation_tool')['article_type'].value_counts()
# Out:
# translation_tool  article_type
# 0                 new             1475
#                   0                135
#                   post             135
#                   expanded          47
# True              new                1
# Name: article_type, dtype: int64

# %%
indonesia['filename'].unique()
# Out:
# array(['writing_contest.csv', 'monthly_challenge.csv',
#        'Indonesia_grant.csv', 'Jawa_grant.csv', 'Minangkabau_grant.csv',
#        'Sunda_grant.csv'], dtype=object)

# %%
indonesia.loc[indonesia.filename == 'writing_contest.csv', ['g_suggestion']] = True

# %%
indonesia['g_suggestion'].value_counts()
# Out:
# False    947
# True     846
# Name: g_suggestion, dtype: int64

# %%
indonesia.groupby('g_suggestion')['recs_suggestion_type'].value_counts()
# Out:
# g_suggestion  recs_suggestion_type
# True          Translating             536
#               Editing                   1
# Name: recs_suggestion_type, dtype: int64

# %%
indonesia.groupby('g_suggestion')['filename'].value_counts()
# Out:
# g_suggestion  filename
# False         Indonesia_grant.csv      287
#               monthly_challenge.csv    220
#               Minangkabau_grant.csv    173
#               Jawa_grant.csv           165
#               Sunda_grant.csv          102
# True          writing_contest.csv      607
#               Indonesia_grant.csv      181
#               monthly_challenge.csv     38
#               Jawa_grant.csv            16
#               Sunda_grant.csv            4
# Name: filename, dtype: int64

# %%
indonesia.groupby('article_type')['revertrate'].value_counts()
# Out:
# article_type  revertrate
# 0             0              135
# expanded      0               47
# new           0             1476
# post          0              135
# Name: revertrate, dtype: int64

# %%
indonesia['revertrate'].value_counts()
# Out:
# 0    1793
# Name: revertrate, dtype: int64

# %%
indonesia.groupby('g_suggestion')['article_type'].value_counts()
# Out:
# g_suggestion  article_type
# False         new             858
#               0                38
#               post             35
#               expanded         16
# True          new             618
#               post            100
#               0                97
#               expanded         31
# Name: article_type, dtype: int64

# %%
interim = pd.read_csv("../../data/processed/query_results/content_quality/5_interim_frame_updated_w_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
india = pd.read_csv("../../data/processed/query_results/content_quality/b5_final_frame_updated_pv_topics_g_suggs.csv", sep=',', encoding = 'utf-8')

# %%
india = india.reindex(sorted(india.columns), axis=1)

# %%
india['article_type'].unique()
# Out:
# array(['new'], dtype=object)

# %%
v = interim.groupby('article_type')['predicted_label_1'].apply(lambda x: x.mode().iat[0]).reset_index()
v
# Out:
#   article_type             predicted_label_1
# 0     expanded  Culture.Biography.Biography*
# 1          new  Culture.Biography.Biography*

# %%
labels = indonesia[indonesia['predicted_label_1']]

# %%
v_id = indonesia.groupby('article_type')['predicted_label_1'].apply(lambda x: x.mode().iat[0]).reset_index()
v_id
# Out:
#   article_type             predicted_label_1
# 0            0  Culture.Biography.Biography*
# 1     expanded                    STEM.STEM*
# 2          new  Culture.Biography.Biography*
# 3         post                    STEM.STEM*

# %%
test = indonesia.copy(deep=True)
test['article_type'] = test['article_type'].str.replace('post', 'new')

v_id2 = test.groupby('article_type')['predicted_label_1'].apply(lambda x: x.mode().iat[0]).reset_index()
v_id2
# Out:
#   article_type             predicted_label_1
# 0            0  Culture.Biography.Biography*
# 1     expanded                    STEM.STEM*
# 2          new  Culture.Biography.Biography*

# %%
#check for outliers in page_len
sns.stripplot(data = indonesia, y = 'page_len', jitter = True);
#sns.plt.ylim(0, 500)
#sns.plt.show()

# %%
#check for outliers in page_len
sns.stripplot(data = indonesia, y = 'page_len', jitter = True);
#sns.plt.ylim(0, 50000)
#sns.plt.show()

# %%
# Review 'page_len' distribution 
plt.figure();
age_hist = indonesia['page_len'].plot.hist(bins=10)
age_hist.set_xlabel("page_len")
age_hist.set_ylabel("Articles")
age_hist.set_title('Distribution of page_len');

# %%
## exploratory analysis

# %%
indonesia.describe()
# Out:
#         IP_editors           QID   Unnamed: 0  all_editors_of_all_edits  \
# count  1793.000000  1.793000e+03  1793.000000               1793.000000
# mean      0.065254  3.568323e+07   896.000000                  2.266592
# std       0.452773  4.281867e+07   517.738834                  1.544462
# min       0.000000  0.000000e+00     0.000000                  0.000000
# 25%       0.000000  5.887700e+05   448.000000                  1.000000
# 50%       0.000000  5.413090e+06   896.000000                  2.000000
# 75%       0.000000  9.662140e+07  1344.000000                  3.000000
# max      15.000000  9.737500e+07  1792.000000                 19.000000
#
#        editors_1stM   editors_nm     edits_1M    ipl_count  \
# count   1793.000000  1793.000000  1793.000000  1793.000000
# mean       1.083101     1.322922    21.992192     7.609035
# std        0.715196     0.820370    30.941692    23.457086
# min        0.000000     0.000000     0.000000     0.000000
# 25%        1.000000     1.000000     4.000000     1.000000
# 50%        1.000000     1.000000    11.000000     2.000000
# 75%        1.000000     2.000000    29.000000     5.000000
# max        4.000000     7.000000   348.000000   320.000000
#
#        is_double_redirect  iwsitelinks  ...  p1_is_redirect       page_id  \
# count              1793.0  1793.000000  ...     1793.000000  1.793000e+03
# mean                  0.0    14.920245  ...        0.039041  2.268168e+06
# std                   0.0    28.429302  ...        0.193746  1.244992e+06
# min                   0.0     0.000000  ...        0.000000  0.000000e+00
# 25%                   0.0     0.000000  ...        0.000000  3.356070e+05
# 50%                   0.0     8.000000  ...        0.000000  2.993813e+06
# 75%                   0.0    23.000000  ...        0.000000  3.040788e+06
# max                   0.0   966.000000  ...        1.000000  3.108543e+06
#
#             page_len  recs_given_order  relative_page_len  revertrate  \
# count    1793.000000        537.000000        1793.000000      1793.0
# mean     8360.755159         76.508380           0.232164         0.0
# std      8240.356726         64.851009           0.199124         0.0
# min         0.000000          1.000000           0.000000         0.0
# 25%      5015.000000         25.000000           0.106704         0.0
# 50%      8323.000000         57.000000           0.211548         0.0
# 75%     11041.000000        106.000000           0.355844         0.0
# max    195073.000000        249.000000           1.000000         0.0
#
#            rpage_id      rpage_len  talk_page_edits  watch_count
# count  1.793000e+03    1793.000000      1793.000000   1793.00000
# mean   1.126495e+05     588.991634         0.041829      1.02454
# std    5.738603e+05    4403.079114         0.657148      0.58388
# min    0.000000e+00       0.000000         0.000000      0.00000
# 25%    0.000000e+00       0.000000         0.000000      1.00000
# 50%    0.000000e+00       0.000000         0.000000      1.00000
# 75%    0.000000e+00       0.000000         0.000000      1.00000
# max    3.099210e+06  105410.000000        20.000000      5.00000
#
# [8 rows x 26 columns]

# %%
na_agg = indonesia[[ #for aggregating
'wikicode',
'iwsitelinks',
'article_type',
'page_len',
'relative_page_len',
'total_edits',
'editors',
'views_1M',
'views_1M_all',
'editors_1stM',
'edits_1M',
'minor_edits',
'major_editors',
'IP_editors',
'micro_editors',
'revertrate',
'first_edited',
'last_edited',
'talk_page_edits',
'watch_count',
'o_internal_links',
'o_external_links',
'incoming_links']]

#select only numeric columns for hist plotting
numerics = ['int', 'float64']
na_numeric = na_agg.select_dtypes(include=numerics)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-80a9d8bc9a03> in <module>
#      22 'o_internal_links',
#      23 'o_external_links',
# ---> 24 'incoming_links']]
#      25
#      26 #select only numeric columns for hist plotting
#
# ~/venv/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/venv/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/venv/lib/python3.5/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/venv/lib/python3.5/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['views_1M_all', 'wikicode', 'incoming_links', 'o_external_links', 'minor_edits', 'editors', 'major_editors', 'o_internal_links', 'views_1M', 'total_edits'] not in index"

# %%
indonesia.groupby(['database_code']).agg(['nunique'])
# Out:
#               IP_editors     QID Unnamed: 0 all_editors_of_all_edits  \
#                  nunique nunique    nunique                  nunique
# database_code
# idwiki                 6    1329       1333                       11
# jvwiki                 2     181        181                        4
# minwiki                3     172        173                        5
# suwiki                 3     106        106                        4
#
#               article_type at_create at_edits contest_article_type  \
#                    nunique   nunique  nunique              nunique
# database_code
# idwiki                   4         2        2                    6
# jvwiki                   1         1        1                    2
# minwiki                  3         1        1                    2
# suwiki                   1         1        1                    2
#
#               editors_1stM editors_nm  ... relative_page_len revertrate  \
#                    nunique    nunique  ...           nunique    nunique
# database_code                          ...
# idwiki                   5          7  ...              1089          1
# jvwiki                   4          4  ...               175          1
# minwiki                  3          4  ...               160          1
# suwiki                   3          4  ...               102          1
#
#               rpage_id rpage_len rpage_title talk_page_edits translation_tool  \
#                nunique   nunique     nunique         nunique          nunique
# database_code
# idwiki              67        66          67               8                2
# jvwiki               2         2           2               1                1
# minwiki              3         3           3               2                1
# suwiki               2         2           2               1                1
#
#                   url url_article_info watch_count
#               nunique          nunique     nunique
# database_code
# idwiki           1333             1328           6
# jvwiki            181              181           2
# minwiki           173              173           3
# suwiki            106              106           3
#
# [4 rows x 47 columns]

# %%
indonesia.groupby(['database_code']).agg(['median', 'max'])
# Out:
#               IP_editors            QID           Unnamed: 0        \
#                   median   max   median       max     median   max
# database_code
# idwiki               0.0  15.0  6075368  97374998      666.0  1790
# jvwiki               0.0   1.0  2322964  97257305     1457.0  1792
# minwiki              0.0   2.0  7645447  97372542     1280.0  1791
# suwiki               0.0   2.0  1278456  97241818     1602.5  1655
#
#               all_editors_of_all_edits       editors_1stM       ...  \
#                                 median   max       median  max  ...
# database_code                                                   ...
# idwiki                             2.0  19.0          1.0  4.0  ...
# jvwiki                             1.0   4.0          1.0  4.0  ...
# minwiki                            1.0   4.0          1.0  2.0  ...
# suwiki                             1.0   8.0          1.0  4.0  ...
#
#               revertrate     rpage_id            rpage_len            \
#                   median max   median        max    median       max
# database_code
# idwiki                 0   0      0.0  3099210.0       0.0  105410.0
# jvwiki                 0   0      0.0   164906.0       0.0   10729.0
# minwiki                0   0      0.0   327858.0       0.0   12670.0
# suwiki                 0   0      0.0    99598.0       0.0   10872.0
#
#               talk_page_edits       watch_count
#                        median   max      median  max
# database_code
# idwiki                    0.0  20.0         1.0  5.0
# jvwiki                    0.0   0.0         1.0  2.0
# minwiki                   0.0   3.0         1.0  2.0
# suwiki                    0.0   0.0         1.0  2.0
#
# [4 rows x 54 columns]

# %%
indonesia.hist(figsize=(15,15));
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/venv/lib/python3.5/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     353     try:
# --> 354         dt = signed_to_unsigned[dt.type]
#     355     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-a6957f859d93> in <module>
# ----> 1 indonesia.hist(figsize=(15,15));
#
# ~/venv/lib/python3.5/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     197         layout=layout,
#     198         bins=bins,
# --> 199         **kwds
#     200     )
#     201
#
# ~/venv/lib/python3.5/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     410     for i, col in enumerate(com.try_sort(data.columns)):
#     411         ax = _axes[i]
# --> 412         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#     413         ax.set_title(col)
#     414         ax.grid(grid)
#
# ~/venv/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/venv/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/venv/lib/python3.5/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     823
#     824         # Pre-compute histogram scaling factor
# --> 825         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     826
#     827         # We iterate over blocks here for two reasons: the first is that for
#
# ~/venv/lib/python3.5/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     354         dt = signed_to_unsigned[dt.type]
#     355     except KeyError:
# --> 356         return np.subtract(a, b, dtype=dt)
#     357     else:
#     358         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
indonesia.corr()
# Out:
#                           IP_editors       QID  Unnamed: 0  \
# IP_editors                  1.000000  0.012116   -0.040983
# QID                         0.012116  1.000000   -0.055997
# Unnamed: 0                 -0.040983 -0.055997    1.000000
# all_editors_of_all_edits    0.408425  0.021147   -0.552955
# editors_1stM                0.103875  0.106405   -0.268252
# editors_nm                  0.114507  0.057530   -0.368266
# edits_1M                    0.054408 -0.172399    0.127890
# g_suggestion               -0.017783 -0.203327   -0.267687
# ipl_count                   0.080481 -0.014513   -0.120798
# is_double_redirect               NaN       NaN         NaN
# iwsitelinks                 0.020694 -0.345307    0.071329
# july_view_count_internal    0.329893  0.082619   -0.173742
# micro_editors               0.115634 -0.007880   -0.527494
# minor_edits_all_time        0.107517 -0.006991   -0.276345
# num_edits_all_time          0.107315 -0.077679   -0.108324
# oel_links                   0.015474 -0.108224   -0.077042
# oplinks                     0.046130 -0.036565   -0.287721
# p1_is_redirect             -0.029057  0.089206    0.185386
# page_id                     0.018482  0.062827   -0.613062
# page_len                    0.044743 -0.055348   -0.124107
# recs_given_order           -0.127790  0.057975   -0.049168
# relative_page_len           0.046764 -0.094260    0.197243
# revertrate                       NaN       NaN         NaN
# rpage_id                   -0.028307  0.095769    0.175976
# rpage_len                  -0.019289  0.044954    0.120675
# talk_page_edits             0.018954  0.010479   -0.050942
# watch_count                 0.040378  0.060392   -0.226242
#
#                           all_editors_of_all_edits  editors_1stM  editors_nm  \
# IP_editors                                0.408425      0.103875    0.114507
# QID                                       0.021147      0.106405    0.057530
# Unnamed: 0                               -0.552955     -0.268252   -0.368266
# all_editors_of_all_edits                  1.000000      0.480581    0.748130
# editors_1stM                              0.480581      1.000000    0.522996
# editors_nm                                0.748130      0.522996    1.000000
# edits_1M                                  0.026609      0.236741    0.118813
# g_suggestion                              0.251416     -0.070789    0.095094
# ipl_count                                 0.159683      0.094076    0.090777
# is_double_redirect                             NaN           NaN         NaN
# iwsitelinks                              -0.013712     -0.063759    0.002229
# july_view_count_internal                  0.281646      0.103665    0.147583
# micro_editors                             0.799145      0.397381    0.460407
# minor_edits_all_time                      0.417709      0.245731    0.260836
# num_edits_all_time                        0.279511      0.249449    0.268620
# oel_links                                 0.165344      0.112852    0.160721
# oplinks                                   0.301373      0.205781    0.197911
# p1_is_redirect                           -0.161614     -0.180488   -0.110961
# page_id                                   0.406189      0.025084    0.129356
# page_len                                  0.231275      0.216805    0.206233
# recs_given_order                         -0.051796     -0.072631   -0.069606
# relative_page_len                        -0.026054      0.203369    0.077399
# revertrate                                     NaN           NaN         NaN
# rpage_id                                 -0.159098     -0.181276   -0.113652
# rpage_len                                -0.107423     -0.143282   -0.069548
# talk_page_edits                           0.030243      0.010410    0.041178
# watch_count                               0.328758      0.291779    0.388870
#
#                           edits_1M  g_suggestion  ipl_count  \
# IP_editors                0.054408     -0.017783   0.080481
# QID                      -0.172399     -0.203327  -0.014513
# Unnamed: 0                0.127890     -0.267687  -0.120798
# all_editors_of_all_edits  0.026609      0.251416   0.159683
# editors_1stM              0.236741     -0.070789   0.094076
# editors_nm                0.118813      0.095094   0.090777
# edits_1M                  1.000000     -0.196313  -0.014629
# g_suggestion             -0.196313      1.000000  -0.015352
# ipl_count                -0.014629     -0.015352   1.000000
# is_double_redirect             NaN           NaN        NaN
# iwsitelinks               0.098966      0.052182   0.022232
# july_view_count_internal -0.033504     -0.038890   0.041158
# micro_editors             0.025273      0.291208   0.131612
# minor_edits_all_time      0.165183      0.172776   0.083968
# num_edits_all_time        0.656885     -0.066256   0.069121
# oel_links                 0.236034     -0.075697   0.120204
# oplinks                   0.159595     -0.059997   0.328390
# p1_is_redirect           -0.139299     -0.086685   0.006430
# page_id                  -0.396946      0.471914   0.143962
# page_len                  0.341469     -0.117536   0.110056
# recs_given_order         -0.007796           NaN   0.016801
# relative_page_len         0.445314     -0.373843  -0.013856
# revertrate                     NaN           NaN        NaN
# rpage_id                 -0.136059     -0.080920   0.008420
# rpage_len                -0.093291     -0.037396  -0.002393
# talk_page_edits           0.112017     -0.014264   0.080813
# watch_count               0.167981     -0.102897   0.024251
#
#                           is_double_redirect  ...  p1_is_redirect   page_id  \
# IP_editors                               NaN  ...       -0.029057  0.018482
# QID                                      NaN  ...        0.089206  0.062827
# Unnamed: 0                               NaN  ...        0.185386 -0.613062
# all_editors_of_all_edits                 NaN  ...       -0.161614  0.406189
# editors_1stM                             NaN  ...       -0.180488  0.025084
# editors_nm                               NaN  ...       -0.110961  0.129356
# edits_1M                                 NaN  ...       -0.139299 -0.396946
# g_suggestion                             NaN  ...       -0.086685  0.471914
# ipl_count                                NaN  ...        0.006430  0.143962
# is_double_redirect                       NaN  ...             NaN       NaN
# iwsitelinks                              NaN  ...       -0.071670 -0.124788
# july_view_count_internal                 NaN  ...       -0.056800  0.169822
# micro_editors                            NaN  ...       -0.250179  0.383630
# minor_edits_all_time                     NaN  ...       -0.133074  0.188480
# num_edits_all_time                       NaN  ...       -0.158309 -0.102224
# oel_links                                NaN  ...       -0.136754 -0.080096
# oplinks                                  NaN  ...       -0.142905  0.195312
# p1_is_redirect                           NaN  ...        1.000000  0.104363
# page_id                                  NaN  ...        0.104363  1.000000
# page_len                                 NaN  ...       -0.203726 -0.114950
# recs_given_order                         NaN  ...       -0.036206  0.114703
# relative_page_len                        NaN  ...       -0.234291 -0.602098
# revertrate                               NaN  ...             NaN       NaN
# rpage_id                                 NaN  ...        0.974177  0.125364
# rpage_len                                NaN  ...        0.663846  0.073760
# talk_page_edits                          NaN  ...       -0.004068  0.034055
# watch_count                              NaN  ...        0.198710  0.035599
#
#                           page_len  recs_given_order  relative_page_len  \
# IP_editors                0.044743         -0.127790           0.046764
# QID                      -0.055348          0.057975          -0.094260
# Unnamed: 0               -0.124107         -0.049168           0.197243
# all_editors_of_all_edits  0.231275         -0.051796          -0.026054
# editors_1stM              0.216805         -0.072631           0.203369
# editors_nm                0.206233         -0.069606           0.077399
# edits_1M                  0.341469         -0.007796           0.445314
# g_suggestion             -0.117536               NaN          -0.373843
# ipl_count                 0.110056          0.016801          -0.013856
# is_double_redirect             NaN               NaN                NaN
# iwsitelinks               0.044970         -0.190480           0.104699
# july_view_count_internal  0.125121         -0.132317           0.000772
# micro_editors             0.239574          0.012040           0.009043
# minor_edits_all_time      0.374423          0.034376           0.094492
# num_edits_all_time        0.669392          0.046276           0.386729
# oel_links                 0.843647          0.036739           0.496054
# oplinks                   0.536585          0.051044           0.233442
# p1_is_redirect           -0.203726         -0.036206          -0.234291
# page_id                  -0.114950          0.114703          -0.602098
# page_len                  1.000000          0.031174           0.657458
# recs_given_order          0.031174          1.000000          -0.047970
# relative_page_len         0.657458         -0.047970           1.000000
# revertrate                     NaN               NaN                NaN
# rpage_id                 -0.198469         -0.036045          -0.228284
# rpage_len                -0.135257         -0.019536          -0.155553
# talk_page_edits           0.281217          0.060291           0.089886
# watch_count               0.246481         -0.021847           0.146949
#
#                           revertrate  rpage_id  rpage_len  talk_page_edits  \
# IP_editors                       NaN -0.028307  -0.019289         0.018954
# QID                              NaN  0.095769   0.044954         0.010479
# Unnamed: 0                       NaN  0.175976   0.120675        -0.050942
# all_editors_of_all_edits         NaN -0.159098  -0.107423         0.030243
# editors_1stM                     NaN -0.181276  -0.143282         0.010410
# editors_nm                       NaN -0.113652  -0.069548         0.041178
# edits_1M                         NaN -0.136059  -0.093291         0.112017
# g_suggestion                     NaN -0.080920  -0.037396        -0.014264
# ipl_count                        NaN  0.008420  -0.002393         0.080813
# is_double_redirect               NaN       NaN        NaN              NaN
# iwsitelinks                      NaN -0.072549  -0.046877        -0.002181
# july_view_count_internal         NaN -0.055331  -0.037704         0.020082
# micro_editors                    NaN -0.245947  -0.166263         0.035402
# minor_edits_all_time             NaN -0.130152  -0.088383         0.136425
# num_edits_all_time               NaN -0.155946  -0.105465         0.435283
# oel_links                        NaN -0.133223  -0.090784         0.278320
# oplinks                          NaN -0.139215  -0.094867         0.135282
# p1_is_redirect                   NaN  0.974177   0.663846        -0.004068
# page_id                          NaN  0.125364   0.073760         0.034055
# page_len                         NaN -0.198469  -0.135257         0.281217
# recs_given_order                 NaN -0.036045  -0.019536         0.060291
# relative_page_len                NaN -0.228284  -0.155553         0.089886
# revertrate                       NaN       NaN        NaN              NaN
# rpage_id                         NaN  1.000000   0.655969        -0.003518
# rpage_len                        NaN  0.655969   1.000000         0.010776
# talk_page_edits                  NaN -0.003518   0.010776         1.000000
# watch_count                      NaN  0.201339   0.147462         0.033683
#
#                           watch_count
# IP_editors                   0.040378
# QID                          0.060392
# Unnamed: 0                  -0.226242
# all_editors_of_all_edits     0.328758
# editors_1stM                 0.291779
# editors_nm                   0.388870
# edits_1M                     0.167981
# g_suggestion                -0.102897
# ipl_count                    0.024251
# is_double_redirect                NaN
# iwsitelinks                 -0.006807
# july_view_count_internal     0.135531
# micro_editors                0.222056
# minor_edits_all_time         0.155008
# num_edits_all_time           0.238018
# oel_links                    0.183702
# oplinks                      0.189105
# p1_is_redirect               0.198710
# page_id                      0.035599
# page_len                     0.246481
# recs_given_order            -0.021847
# relative_page_len            0.146949
# revertrate                        NaN
# rpage_id                     0.201339
# rpage_len                    0.147462
# talk_page_edits              0.033683
# watch_count                  1.000000
#
# [27 rows x 27 columns]

# %%
corr = indonesia.corr()
corr = (corr)
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="coolwarm", center=0);

# %%
plt.figure(figsize = (20,8))
sns.heatmap(indonesia.corr(), annot=True, cmap='coolwarm');

# %%
#new articles - full frame
plt.figure(figsize = (21,19))
sns.heatmap(indonesia.corr(), annot=True, cmap='coolwarm');

# %% [markdown]
# ## Isolated/Underdeveloped articles

# %%
#o_internal_links	o_external_links
zero_oel = indonesia[indonesia['oplinks']==0]
zero_oil = indonesia[indonesia['oel_links']==0]
zero_in_links =  indonesia[indonesia['ipl_count']==0]
not_redirect= indonesia[indonesia['rpage_title'].isnull()]

# %%
len(indonesia[indonesia['oplinks']==0])
# Out:
# 179

# %%
len(indonesia[indonesia['oel_links']==0])
# Out:
# 223

# %%
z = len(indonesia[indonesia['ipl_count']==0])
z
# Out:
# 266

# %%
z/len(indonesia)
# Out:
# 0.1483547127718907

# %%
zero_out_links_mask = (indonesia['oplinks']== 0) & (indonesia['oel_links'] == 0 ) 
zero_out_links = indonesia.loc[zero_out_links_mask]
zero_out_links = zero_out_links[zero_out_links['rpage_title'].isnull()]

#externallinks contains links to elsewhere, outside of all wikis
#https://www.mediawiki.org/wiki/Manual:Externallinks_table (external links, from the page)

# %%
indonesia_links = indonesia[['page_title','oplinks','oel_links','ipl_count', 'url_article_info', 'url']]

# %%
(~indonesia_links.all(1)).sum()
# Out:
# 376

# %%
zero_out_links_mask2 = (indonesia_links['oplinks']== 0) & (indonesia_links['oel_links'] == 0 ) 
zero_out_links2 = indonesia_links.loc[zero_out_links_mask2]
#zero_out_links2 = zero_out_links2[zero_out_links2['rpage_title'].isnull()]

# %%
len(zero_out_links)
# Out:
# 0

# %%
len(zero_out_links2)
# Out:
# 135

# %%
zero_in_or_out_links_indonesia = 2
zero_in_or_out_links_india = 768

# %%
100* zero_in_or_out_links_indonesia / indonesia_total_approved
# Out:
# 0.11148272017837235

# %%
100* 89 / indonesia_total_approved
# Out:
# 4.96098104793757

# %%
100* zero_in_or_out_links_india / india_total_approved
# Out:
# 8.37239725280715

# %%
zero_out_links2.to_csv("test.csv")

# %%
zero_out_links.database_code.unique()
# Out:
# array(['idwiki', 'minwiki'], dtype=object)

# %%
zero_out_links.describe()
# Out:
#        IP_editors           QID   Unnamed: 0  all_editors_of_all_edits  \
# count       135.0  1.350000e+02   135.000000                     135.0
# mean          0.0  3.001485e+06  1722.696296                       0.0
# std           0.0  1.654873e+07    39.483848                       0.0
# min           0.0  0.000000e+00  1655.000000                       0.0
# 25%           0.0  0.000000e+00  1688.500000                       0.0
# 50%           0.0  0.000000e+00  1723.000000                       0.0
# 75%           0.0  0.000000e+00  1756.500000                       0.0
# max           0.0  9.737407e+07  1790.000000                       0.0
#
#        editors_1stM  editors_nm  edits_1M  given_order  ipl_count  \
# count         135.0       135.0     135.0     9.000000      135.0
# mean            0.0         0.0       0.0    50.111111        0.0
# std             0.0         0.0       0.0    55.019189        0.0
# min             0.0         0.0       0.0     2.000000        0.0
# 25%             0.0         0.0       0.0     6.000000        0.0
# 50%             0.0         0.0       0.0    33.000000        0.0
# 75%             0.0         0.0       0.0    56.000000        0.0
# max             0.0         0.0       0.0   151.000000        0.0
#
#        iwsitelinks  ...  micro_editors  minor_edits_all_time  \
# count   135.000000  ...          135.0                 135.0
# mean      5.237037  ...            0.0                   0.0
# std      15.064641  ...            0.0                   0.0
# min       0.000000  ...            0.0                   0.0
# 25%       0.000000  ...            0.0                   0.0
# 50%       0.000000  ...            0.0                   0.0
# 75%       0.000000  ...            0.0                   0.0
# max      78.000000  ...            0.0                   0.0
#
#        num_edits_all_time  oel_links  oplinks       page_id  page_len  \
# count               135.0      135.0    135.0  1.350000e+02     135.0
# mean                  0.0        0.0      0.0  2.353545e+06       0.0
# std                   0.0        0.0      0.0  1.094410e+06       0.0
# min                   0.0        0.0      0.0  0.000000e+00       0.0
# 25%                   0.0        0.0      0.0  2.263370e+06       0.0
# 50%                   0.0        0.0      0.0  2.968658e+06       0.0
# 75%                   0.0        0.0      0.0  2.998942e+06       0.0
# max                   0.0        0.0      0.0  3.097720e+06       0.0
#
#        revertrate  talk_page_edits  watch_count
# count       135.0            135.0        135.0
# mean          0.0              0.0          0.0
# std           0.0              0.0          0.0
# min           0.0              0.0          0.0
# 25%           0.0              0.0          0.0
# 50%           0.0              0.0          0.0
# 75%           0.0              0.0          0.0
# max           0.0              0.0          0.0
#
# [8 rows x 21 columns]

# %%
zero_oel.describe()
# Out:
#        IP_editors           QID   Unnamed: 0  all_editors_of_all_edits  \
# count       179.0  1.790000e+02   179.000000                179.000000
# mean          0.0  3.457753e+06  1476.044693                  0.547486
# std           0.0  1.667396e+07   495.062359                  1.050271
# min           0.0  0.000000e+00    14.000000                  0.000000
# 25%           0.0  0.000000e+00  1656.500000                  0.000000
# 50%           0.0  0.000000e+00  1702.000000                  0.000000
# 75%           0.0  0.000000e+00  1746.500000                  0.000000
# max           0.0  9.737407e+07  1792.000000                  5.000000
#
#        editors_1stM  editors_nm    edits_1M  given_order   ipl_count  \
# count    179.000000  179.000000  179.000000     9.000000  179.000000
# mean       0.094972    0.290503    0.698324    50.111111    1.245810
# std        0.392238    0.565357    3.003471    55.019189    5.612578
# min        0.000000    0.000000    0.000000     2.000000    0.000000
# 25%        0.000000    0.000000    0.000000     6.000000    0.000000
# 50%        0.000000    0.000000    0.000000    33.000000    0.000000
# 75%        0.000000    0.000000    0.000000    56.000000    0.000000
# max        3.000000    3.000000   20.000000   151.000000   66.000000
#
#        iwsitelinks  ...  micro_editors  minor_edits_all_time  \
# count   179.000000  ...     179.000000            179.000000
# mean      5.296089  ...       0.318436              0.480447
# std      14.132461  ...       0.682235              1.419530
# min       0.000000  ...       0.000000              0.000000
# 25%       0.000000  ...       0.000000              0.000000
# 50%       0.000000  ...       0.000000              0.000000
# 75%       0.000000  ...       0.000000              0.000000
# max      78.000000  ...       3.000000             10.000000
#
#        num_edits_all_time   oel_links  oplinks       page_id      page_len  \
# count          179.000000  179.000000    179.0  1.790000e+02    179.000000
# mean             1.424581    0.826816      0.0  2.410253e+06    656.927374
# std              4.070814    1.886724      0.0  1.081775e+06   1739.839722
# min              0.000000    0.000000      0.0  0.000000e+00      0.000000
# 25%              0.000000    0.000000      0.0  2.582301e+06      0.000000
# 50%              0.000000    0.000000      0.0  2.975685e+06      0.000000
# 75%              0.000000    0.000000      0.0  3.002564e+06      0.000000
# max             33.000000   13.000000      0.0  3.097720e+06  10865.000000
#
#        revertrate  talk_page_edits  watch_count
# count       179.0            179.0   179.000000
# mean          0.0              0.0     0.262570
# std           0.0              0.0     0.511987
# min           0.0              0.0     0.000000
# 25%           0.0              0.0     0.000000
# 50%           0.0              0.0     0.000000
# 75%           0.0              0.0     0.000000
# max           0.0              0.0     3.000000
#
# [8 rows x 21 columns]

# %%
zero_oil.describe()
# Out:
#        IP_editors           QID   Unnamed: 0  all_editors_of_all_edits  \
# count  223.000000  2.230000e+02   223.000000                223.000000
# mean     0.004484  2.262725e+06  1346.520179                  0.596413
# std      0.066965  1.441281e+07   506.657532                  1.073172
# min      0.000000  0.000000e+00   109.000000                  0.000000
# 25%      0.000000  0.000000e+00   844.500000                  0.000000
# 50%      0.000000  0.000000e+00  1678.000000                  0.000000
# 75%      0.000000  0.000000e+00  1734.500000                  1.000000
# max      1.000000  9.737407e+07  1790.000000                  9.000000
#
#        editors_1stM  editors_nm    edits_1M  given_order   ipl_count  \
# count    223.000000  223.000000  223.000000     9.000000  223.000000
# mean       0.273543    0.408072    1.152466    50.111111    2.762332
# std        0.570735    0.629119    5.522606    55.019189   20.398552
# min        0.000000    0.000000    0.000000     2.000000    0.000000
# 25%        0.000000    0.000000    0.000000     6.000000    0.000000
# 50%        0.000000    0.000000    0.000000    33.000000    0.000000
# 75%        0.000000    1.000000    0.000000    56.000000    1.000000
# max        3.000000    4.000000   60.000000   151.000000  214.000000
#
#        iwsitelinks  ...  micro_editors  minor_edits_all_time  \
# count   223.000000  ...     223.000000            223.000000
# mean      3.336323  ...       0.197309              0.376682
# std      12.093438  ...       0.714453              1.498285
# min       0.000000  ...       0.000000              0.000000
# 25%       0.000000  ...       0.000000              0.000000
# 50%       0.000000  ...       0.000000              0.000000
# 75%       0.000000  ...       0.000000              0.000000
# max      78.000000  ...       5.000000             10.000000
#
#        num_edits_all_time  oel_links     oplinks       page_id      page_len  \
# count          223.000000      223.0  223.000000  2.230000e+02    223.000000
# mean             1.197309        0.0    1.609865  2.573204e+06    611.457399
# std              3.253078        0.0    5.433073  9.854704e+05   2329.740531
# min              0.000000        0.0    0.000000  0.000000e+00      0.000000
# 25%              0.000000        0.0    0.000000  2.953911e+06      0.000000
# 50%              0.000000        0.0    0.000000  2.995161e+06      0.000000
# 75%              1.000000        0.0    1.000000  3.065617e+06     35.500000
# max             26.000000        0.0   45.000000  3.108543e+06  20534.000000
#
#        revertrate  talk_page_edits  watch_count
# count       223.0       223.000000   223.000000
# mean          0.0         0.013453     0.627803
# std           0.0         0.115463     0.915600
# min           0.0         0.000000     0.000000
# 25%           0.0         0.000000     0.000000
# 50%           0.0         0.000000     0.000000
# 75%           0.0         0.000000     1.000000
# max           0.0         1.000000     4.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ### external links <a class="anchor" id="extlinks"></a>
# [Back to Table of Contents](#toc)

# %%
# check to see if any of the targets are duplicated in the article
oel_r.duplicated()

# %% [markdown]
# #### Categorize opls & oextlinks

# %%
# use bins to seperate number of pagelinks into categories
#seperate number of links into bins defined for oel_bins 
opls["binned_links"] = pd.cut(opls["oplinks"], oel_bins, right=False)

#sort
opls["binned_links"].value_counts(sort = False)

# %%
# use bins to seperate number of pagelinks into categories
#seperate number of links into bins defined for oext_bins 
oextlinks["binned_links"] = pd.cut(oextlinks["oelinks"], oext_bins, right=False)

#sort
oextlinks["binned_links"].value_counts(sort = False)
