# %%
# from SPARQLWrapper import SPARQLWrapper, JSON
from ratelimiter import RateLimiter
from collections import OrderedDict
import pandas as pd
# %load_ext sql_magic

import os
import glob
from urllib.parse import unquote

import wmfdata as wmf
from wmfdata import charting, mariadb, hive
from wmfdata.utils import pct_str, pd_display_all

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
# %store -r query_vars

# %% [raw]
# # TO DO FIX SPARQL LOOP CALL. At present, this code successfully gets and collects data for the first wiki in the list... then it gets stuck after line 32 and doesn't make it to line 34 for any of the following wikis in the list.
#
# ac_dict = {}
# wikicodeslist = (query_vars["india_wiki_codes"])
#
# for wikicode in wikicodeslist.lower().split(","):
#     ac_dict = {}
#
#     @RateLimiter(max_calls=10, period=1)
#     def do_something():
#         pass
#
#     rate_limiter = RateLimiter(max_calls=10, period=1)
#
#     for i in range(100):
#         with rate_limiter:
#             do_something()
#
#     try:
#
#         endpoint = "https://query.wikidata.org/sparql"
#         sparql = SPARQLWrapper(endpoint)
#         sparql.setReturnFormat(JSON)
#         sparql.setQuery("""
#         SELECT ?item ?sitelink ?itemLabel
#         WHERE {
#           ?sitelink schema:isPartOf <https://%s.wikipedia.org/>;
#              schema:about ?item;
#              wikibase:badge wd:Q17437796 . # Sitelink is badged as a Featured Article
#             SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" } .
#         } ORDER BY ?itemLabel
#         """% wikicode)
#
#         results = sparql.query().convert()
#         ac_dict.update(results)
#         t_ac = []
#         t_ac.append(ac_dict.copy())
#     except Exception:
#         pass

# %%
#In the absence of a functional SPARQL LOOP CALL, run SPARQL Query manually for each wiki: https://w.wiki/Gh$

#download results into csv files, one for each wiki
#note, some wikis don't have featured articles

# %%
os.chdir("./data/raw/relative_length")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined = pd.concat([pd.read_csv(f) for f in all_filenames ], sort=True)
#export to csv
combined.to_csv( "_combined.csv", index=False, encoding='utf-8-sig')
# Out:
# /home/iflorez/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#os.chdir("./data/raw/relative_length")
combined_r = pd.read_csv("_combined.csv")
combined_r2 = combined_r.copy()

# %%
#extract wikicode
combined_r2['wikicode'] = combined_r2['sitelink'].str.extract('([a-z]+(?=\.))', expand=True)

#add 'wiki'
combined_r2['wikicode'] = combined_r2['wikicode']+'wiki'

#extract url title
combined_r2['encoded_title'] = combined_r2['sitelink'].str.extract('([^\/]+$)', expand=True)

#encoded URL to decoded title
combined_r2['page_title'] = combined_r2['encoded_title'].apply(lambda x: unquote(x))
# Out:
# array(['hi', 'or', 'ml', 'mr', 'ur', 'pnb', 'ta', 'bn', 'as', 'sa', 'gu',
#        'kn', 'pa', 'te'], dtype=object)

# %%
#create tuple object containing page_title values given wikicode value in wikicode column
grouped_titles = combined_r2.groupby('wikicode')['page_title'].apply(tuple)

# %%
fpr_query = """
SELECT 
       p1.page_id  AS page_id,
       p1.page_title AS page_title,
       p1.page_is_redirect AS p1_is_redirect,
       p1.page_len AS page_len,
       p2.page_id AS rpage_id,
       p2.page_title AS rpage_title,
       p2.page_len rpage_len,
       p2.page_is_redirect AS is_double_redirect
FROM page AS p1 
LEFT JOIN redirect AS rd 
    ON p1.page_id=rd.rd_from 
LEFT JOIN page AS p2 
    ON (rd_namespace = p2.page_namespace)
        AND rd_title = p2.page_title  
WHERE p1.page_namespace = 0
      AND p1.page_title IN {titles}
"""

# %%
fpr_query_single_article = """
SELECT 
       p1.page_id  AS page_id,
       p1.page_title AS page_title,
       p1.page_is_redirect AS p1_is_redirect,
       p1.page_len AS page_len,
       p2.page_id AS rpage_id,
       p2.page_title AS rpage_title,
       p2.page_len rpage_len,
       p2.page_is_redirect AS is_double_redirect
FROM page AS p1 
LEFT JOIN redirect AS rd 
    ON p1.page_id=rd.rd_from 
LEFT JOIN page AS p2 
    ON (rd_namespace = p2.page_namespace)
        AND rd_title = p2.page_title  
WHERE p1.page_namespace = 0
      AND p1.page_title = '{titles}'
"""

# %%
articles_len_wiki_query = """
SELECT 
       p1.page_id  AS page_id,
       p1.page_title AS page_title,
       p1.page_is_redirect AS p1_is_redirect,
       p1.page_len AS page_len,
       p2.page_id AS rpage_id,
       p2.page_title AS rpage_title,
       p2.page_len rpage_len,
       p2.page_is_redirect AS is_double_redirect
FROM page AS p1 
LEFT JOIN redirect AS rd 
    ON p1.page_id=rd.rd_from 
LEFT JOIN page AS p2 
    ON (rd_namespace = p2.page_namespace)
        AND rd_title = p2.page_title  
WHERE p1.page_namespace = 0
"""

# %%
#run the queries
bntitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['bnwiki']), 'bnwiki')
hititles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['hiwiki']), 'hiwiki')
mltitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['mlwiki']), 'mlwiki')

tatitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['tawiki']), 'tawiki')
tetitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['tewiki']), 'tewiki')
astitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['aswiki']), 'aswiki') 
satitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['sawiki']), 'sawiki')
kntitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['knwiki']), 'knwiki')
gutitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['guwiki']), 'guwiki')
bntitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['bnwiki']), 'bnwiki')
mrtitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['mrwiki']), 'mrwiki')
urtitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['urwiki']), 'urwiki')
ortitles = wmf.mariadb.run(fpr_query.format(titles=grouped_titles['orwiki']), 'orwiki')


pnbtitles = wmf.mariadb.run(fpr_query_single_article.format(titles=grouped_titles['pnbwiki'][0]), 'pnbwiki')
patitles = wmf.mariadb.run(fpr_query_single_article.format(titles=grouped_titles['pawiki'][0]), 'pawiki')
#sattitles = doesn't have any featured articles
#tcytitles = doesn't have any featured articles

# %%
featuredtitles = bntitles.append([
                hititles,   
                mltitles,  
                tatitles,   
                tetitles,   
                astitles,   
                satitles,   
                kntitles,
                gutitles,
                bntitles,
                mrtitles,
                urtitles,
                ortitles,
                pnbtitles, patitles])

# %%
# |
#check to see if any of the page_ids are redirects or double redirects
((featuredtitles['p1_is_redirect']==1) & (featuredtitles['is_double_redirect']==1)).any()
# Out:
# False

# %%
# |
#check to see if any of the page_ids are redirects or double redirects
((featuredtitles['p1_is_redirect']==1) | (featuredtitles['is_double_redirect']==1)).any()
# Out:
# True

# %%
# act on the results ...featured_pages_redirects_r

#create a df 
all_surviving_articles = featuredtitles[['page_id','page_title', 'page_len']] 

#seperate the redirected items into their own df
redirects = featuredtitles.loc[featuredtitles['p1_is_redirect']==1]
#pull only p1.page_id, p1.page_title, p1.page_len 
redirect_df = redirects[['page_id','page_title','page_len']] 

#remove the redirect items from the all_surviving_articles df & create global articles df
articles =  all_surviving_articles[~all_surviving_articles.isin(redirect_df)].dropna(how='all')

# %%
#check for duplicates
article_dupe_count = articles.groupby(['page_id','page_title', 'page_len']).size().reset_index()
article_dupe_count

# %%
#drop duplicates
articles_clean = articles.drop_duplicates(subset=['page_id', 'page_title'], keep='first')

# %%
#check for nulls
articles_clean[articles_clean.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [page_id, page_title, page_len]
# Index: []

# %%
#combine combined_r2 and articles_clean3 on page_title
df = pd.merge(combined_r2, articles_clean, on='page_title', how='outer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 0 to 509
# Data columns (total 8 columns):
# item           510 non-null object
# itemLabel      510 non-null object
# sitelink       510 non-null object
# wikicode       510 non-null object
# encoded_url    510 non-null object
# page_title     510 non-null object
# page_id        493 non-null object
# page_len       493 non-null object
# dtypes: object(8)
# memory usage: 35.9+ KB

# %%
#check for nulls
df[df.isnull().any(axis=1)].count()
# Out:
# item           17
# itemLabel      17
# sitelink       17
# wikicode       17
# encoded_url    17
# page_title     17
# page_id         0
# page_len        0
# dtype: int64

# %%
#create a df of just the null rows
df_nulls = df[df.isnull().any(axis=1)]

#remove the null items from the df 
df_clean =  df[~df.isin(df_nulls)].dropna(how='all')

# %%
df_nulls.reset_index(drop=True);

# %%
#prepare for #manual review and data entry for those nulls which obtained NAN results in mariadb query
#make sure I'm getting what I think I'm getting (see next cell)
df_nulls.iat[12,1]
# Out:
# 'Barak'

# %%
#manual review and data entry for those which obtained NAN results in mariadb query
#fyi: no info for Pankaj Jaiswal[0], Barak[12] nor Rajkumar [14]

df_nulls.iat[1,6] = 322066  
df_nulls.iat[1,7] = 146818

df_nulls.iat[2,6] =  23678
df_nulls.iat[2,7] = 161157

df_nulls.iat[3,6] =  17150 #benjamin
df_nulls.iat[3,7] =  64824

df_nulls.iat[4,6] =  33052 #db
df_nulls.iat[4,7] = 273275

df_nulls.iat[5,6] =  1999
df_nulls.iat[5,7] =  14801

df_nulls.iat[6,6] =  79715
df_nulls.iat[6,7] = 139976

df_nulls.iat[7,6] =  33198 #Nelson Mandela
df_nulls.iat[7,7] = 163061

df_nulls.iat[8,6] =  7192 #Sheikh Abubakr Ahmad
df_nulls.iat[8,7] = 48266

df_nulls.iat[9,6] =  4551 #..Pradesh
df_nulls.iat[9,7] = 131014

df_nulls.iat[10,6] =  465532 #blue whale
df_nulls.iat[10,7] = 87

df_nulls.iat[11,6] =  177470 #anne frank
df_nulls.iat[11,7] = 236236

df_nulls.iat[13,6] =  7470
df_nulls.iat[13,7] = 24438

df_nulls.iat[14,6] =  1240 #Rajkumar
#df_nulls.iat[14,7] = # previously listed as 1 07 07 4 39 4 39

df_nulls.iat[15,6] =  75456 #Angkor Wat
df_nulls.iat[15,7] = 21881 #previously listed as 21.881

df_nulls.iat[16,6] =  69976
df_nulls.iat[16,7] = 65660 #previously listed as 65.660

# %% [raw]
# df_nulls.sample(3)

# %%
#create a df of just the null rows
df_no_info = df_nulls[df_nulls.isnull().any(axis=1)]

#remove the null items from the df 
df_formerly_nulls =  df_nulls[~df_nulls.isin(df_no_info)].dropna(how='all')

df_no_info.reset_index(drop=True);

# %%
#concat the formerly nulls back into the df
df_relative_length = pd.concat([df_clean, df_formerly_nulls], ignore_index=True)

# %%
#convert page_len to int
df_relative_length['page_len'] = df_relative_length['page_len'].astype(str).astype(int);

# %%
df_relative_length.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 8 columns):
# item           507 non-null object
# itemLabel      507 non-null object
# sitelink       507 non-null object
# wikicode       507 non-null object
# encoded_url    507 non-null object
# page_title     507 non-null object
# page_id        507 non-null object
# page_len       507 non-null int64
# dtypes: int64(1), object(7)
# memory usage: 31.8+ KB

# %%
#validate results by pulling a sample and checking page info
#https://{}.wikipedia.org/w/index.php?title={}&action=info
df_relative_length.sample(8)
# Out:
#                                         item            itemLabel  \
# 386    http://www.wikidata.org/entity/Q12271         architecture
# 160      http://www.wikidata.org/entity/Q111                 Mars
# 194      http://www.wikidata.org/entity/Q525                  Sun
# 310   http://www.wikidata.org/entity/Q284750             Al-Nasir
# 427    http://www.wikidata.org/entity/Q47478    Swami Vivekananda
# 388    http://www.wikidata.org/entity/Q13909       Angelina Jolie
# 143  http://www.wikidata.org/entity/Q2051849        K. J. Yesudas
# 59    http://www.wikidata.org/entity/Q430574  Krishna Janmashtami
#
#                                               sitelink wikicode  \
# 386  https://ta.wikipedia.org/wiki/%E0%AE%95%E0%AE%...   tawiki
# 160  https://ml.wikipedia.org/wiki/%E0%B4%9A%E0%B5%...   mlwiki
# 194  https://ml.wikipedia.org/wiki/%E0%B4%B8%E0%B5%...   mlwiki
# 310  https://ur.wikipedia.org/wiki/%D8%A7%D9%84%D9%...   urwiki
# 427  https://sa.wikipedia.org/wiki/%E0%A4%B8%E0%A5%...   sawiki
# 388  https://bn.wikipedia.org/wiki/%E0%A6%85%E0%A7%...   bnwiki
# 143  https://ml.wikipedia.org/wiki/%E0%B4%95%E0%B5%...   mlwiki
# 59   https://or.wikipedia.org/wiki/%E0%AC%95%E0%AD%...   orwiki
#
#                                            encoded_url          page_title  \
# 386  %E0%AE%95%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BF%...         கட்டிடக்கலை
# 160      %E0%B4%9A%E0%B5%8A%E0%B4%B5%E0%B5%8D%E0%B4%B5               ചൊവ്വ
# 194  %E0%B4%B8%E0%B5%82%E0%B4%B0%E0%B5%8D%E0%B4%AF%...              സൂര്യൻ
# 310  %D8%A7%D9%84%D9%86%D8%A7%D8%B5%D8%B1_%D9%84%D8...    الناصر_لدین_اللہ
# 427  %E0%A4%B8%E0%A5%8D%E0%A4%B5%E0%A4%BE%E0%A4%AE%...  स्वामी_विवेकानन्दः
# 388  %E0%A6%85%E0%A7%8D%E0%A6%AF%E0%A6%BE%E0%A6%9E%...   অ্যাঞ্জেলিনা_জোলি
# 143  %E0%B4%95%E0%B5%86.%E0%B4%9C%E0%B5%86._%E0%B4%...     കെ.ജെ._യേശുദാസ്
# 59   %E0%AC%95%E0%AD%83%E0%AC%B7%E0%AD%8D%E0%AC%A3_...    କୃଷ୍ଣ_ଜନ୍ମାଷ୍ଟମୀ
#
#     page_id  page_len
# 386      12     59029
# 160    4953    238474
# 194    3703    200413
# 310  613398    115619
# 427    1537     83872
# 388   92186    276311
# 143    2385     24049
# 59    19278     28287

# %%
#save df to csv
path = './data/processed/relative_length/'
df_relative_length.to_csv(path+'India_relative_lengths.csv', encoding='utf-8', index=False)

# %%
#count of clean-non-null entries of featured articles in each wiki
df_relative_length.groupby(df_relative_length['wikicode'])['page_len'].count()
# Out:
# wikicode
# aswiki     12
# bnwiki      7
# guwiki     10
# hiwiki     37
# knwiki     13
# mlwiki    172
# mrwiki     61
# orwiki     46
# pawiki      1
# sawiki     32
# tawiki     13
# tewiki     33
# urwiki     70
# Name: page_len, dtype: int64

# %%
median_values = df_relative_length.groupby(df_relative_length['wikicode'])['page_len'].median()

# %%
# %store median_values
# Out:
# Stored 'median_values' (Series)

# %%
ax = median_values.plot (kind='bar', figsize=(10,6), color="indigo", fontsize=11);
ax.set_alpha(0.8)
ax.set_title("Median Values", fontsize=22)
ax.set_ylabel("page_len", fontsize=15);
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'1_median_values.png');

# %%
#about error bars: https://en.wikipedia.org/wiki/Error_bar
sns.set(style='whitegrid')
plt.figure(figsize=(13,7))
g = sns.barplot(x='wikicode', y='page_len', data=df_relative_length)
g.set_yscale("log")
plt.title('Logscale Pagelen Bar Plot: as,bn,gu,hi,kn,ml,mr,or,pa,sa,ta,te,ur')
path = './results/figs/relative_length/'
plt.savefig(path+'2_logscale_pagelens_by_wiki');

# %%
# Sort the dataframe by wikicode and plot in distplot
# see more about y axis kde value: https://stackoverflow.com/questions/51666784/what-is-y-axis-in-seaborn-distplot
wikicode_bn = df_relative_length.loc[df_relative_length['wikicode'] == 'bnwiki'] #normal distribution
wikicode_ml = df_relative_length.loc[df_relative_length['wikicode'] == 'mlwiki'] 
sns.distplot(wikicode_bn[['page_len']], hist=False, rug=True, label ='bnwiki')
sns.distplot(wikicode_ml[['page_len']], hist=False, rug=True, label ='mlwiki')
plt.ylabel('Density')
plt.xlabel('Page Length')
plt.title('Page Length & KDE: bn, ml')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'3_Pagelen_KDE_bn_ml.png');

# %%
wikicode_hi = df_relative_length.loc[df_relative_length['wikicode'] == 'hiwiki']
wikicode_kn = df_relative_length.loc[df_relative_length['wikicode'] == 'knwiki'] 
wikicode_gu = df_relative_length.loc[df_relative_length['wikicode'] == 'guwiki']
wikicode_te = df_relative_length.loc[df_relative_length['wikicode'] == 'tewiki']

sns.distplot(wikicode_hi[['page_len']], hist=False, rug=True, label ='hiwiki')
sns.distplot(wikicode_kn[['page_len']], hist=False, rug=True, label ='knwiki')
sns.distplot(wikicode_gu[['page_len']], hist=False, rug=True, label ='guwiki')
sns.distplot(wikicode_te[['page_len']], hist=False, rug=True, label ='tewiki')
plt.ylabel('Density')
plt.xlabel('Page Length')
plt.title('Page Length & KDE: hi, kn, gu, te')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'4_Pagelen_KDE_hi_kn_gu_te');

# %%
wikicode_ur = df_relative_length.loc[df_relative_length['wikicode'] == 'urwiki']
wikicode_sa = df_relative_length.loc[df_relative_length['wikicode'] == 'sawiki']
sns.distplot(wikicode_ur[['page_len']], rug=True, label ='urwiki')
sns.distplot(wikicode_sa[['page_len']], hist=False, rug=True, label ='sawiki')
plt.ylabel('Density')
plt.xlabel('Page Length')
plt.title('Page Length & KDE: sa, ur')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'5_Pagelen_KDE_sa_ur');

# %%
wikicode_or = df_relative_length.loc[df_relative_length['wikicode'] == 'orwiki']
sns.distplot(wikicode_or[['page_len']], rug=True, label ='orwiki')
plt.ylabel('Density')
plt.xlabel('Page Length')
plt.title('Page Length & KDE: or')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'6_Pagelen_KDE_or');

# %%
plt.figure(figsize=(17,8))
wikicode_as = df_relative_length.loc[df_relative_length['wikicode'] == 'aswiki'] #12 featured articles
wikicode_mr = df_relative_length.loc[df_relative_length['wikicode'] == 'mrwiki']
wikicode_ta = df_relative_length.loc[df_relative_length['wikicode'] == 'tawiki'] #13 featured articles
sns.distplot(wikicode_as[['page_len']], rug=True, label = 'aswiki')
sns.distplot(wikicode_mr[['page_len']], rug=True, label = 'mrwiki')
sns.distplot(wikicode_ta[['page_len']], rug=True, label = 'tawiki')
plt.ylabel('Density')
plt.xlabel('Page Length')
plt.title('Page Length & KDE: as, mr, ta')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'7_Pagelen_KDE_as_mr_ta');

# %%
review_wikis = df_relative_length[df_relative_length['wikicode'].isin(['aswiki', 'mrwiki', 'tawiki'  ]) ]

# %%
review_wiki_list = review_wikis.wikicode.unique()
plt.figure(figsize=(13,7))
plt.hist([review_wikis.loc[review_wikis.wikicode ==x, 'page_len']for x in review_wiki_list], label=review_wiki_list);
plt.ylabel('Count')
plt.xlabel('Page Length')
plt.title('Page Length & Count: mr, ta, as')
plt.legend()
plt.show()
path = './results/figs/relative_length/'
plt.savefig(path+'8_Pagelen_count_mr_ta_as');

# %%
#about error bars: https://en.wikipedia.org/wiki/Error_bar
sns.set(style='whitegrid')
plt.figure(figsize=(13,7))
g = sns.barplot(x='wikicode', y='page_len', data=review_wikis)
g.set_yscale("log")
plt.title('Logscale Pagelen Bar Plot: mr, ta, as')
path = './results/figs/relative_length/'
plt.savefig(path+'9_logscale_barplot_mr_ta_as');

# %% [markdown]
# ### Address pawiki which only had one featured article

# %%
#wikicode_pa has only one featured article
df_relative_length.loc[df_relative_length['wikicode'] == 'pawiki']
# Out:
#                                      item       itemLabel  \
# 461  http://www.wikidata.org/entity/Q1035  Charles Darwin
#
#                                               sitelink wikicode  \
# 461  https://pa.wikipedia.org/wiki/%E0%A8%9A%E0%A8%...   pawiki
#
#                                            encoded_url    page_title  page_id  \
# 461  %E0%A8%9A%E0%A8%BE%E0%A8%B0%E0%A8%B2%E0%A8%B8_...  ਚਾਰਲਸ_ਡਾਰਵਿਨ    17395
#
#      page_len
# 461     29195

# %%
median_value_pa = df_relative_length[df_relative_length['wikicode']== 'pawiki'].page_len

# %% [markdown]
# ### Address tcywiki and satwiki which had zero featured articles

# %%
tcy_articles_r = wmf.mariadb.run(articles_len_wiki_query, 'tcywiki')
sat_articles_r = wmf.mariadb.run(articles_len_wiki_query, 'satwiki')

# %% [markdown]
# #### start by cleaning tcy_articles_r data

# %%
# |
#check to see if any of the page_ids are redirects or double redirects
((tcy_articles_r['p1_is_redirect']==1) & (tcy_articles_r['is_double_redirect']==1)).any()
# Out:
# False

# %%
# |
#check to see if any of the page_ids are redirects or double redirects
((tcy_articles_r['p1_is_redirect']==1) | (tcy_articles_r['is_double_redirect']==1)).any()
# Out:
# True

# %%
# act on the results ...featured_pages_redirects_r

#create a df 
all_surviving_articles_tcy = tcy_articles_r[['page_id','page_title', 'page_len']] 

#seperate the redirected items into their own df
redirects_tcy = tcy_articles_r.loc[tcy_articles_r['p1_is_redirect']==1]
#pull only p1.page_id, p1.page_title, p1.page_len 
redirect_df_tcy = redirects_tcy[['page_id','page_title','page_len']] 

#remove the redirect items from the all_surviving_articles df & create global articles df
articles_tcy =  all_surviving_articles_tcy[~all_surviving_articles_tcy.isin(redirect_df_tcy)].dropna(how='all')

# %% [markdown]
# #### now clean sat_articles_r data

# %%
# Now with sat_articles_r
#check to see if any of the page_ids are redirects or double redirects
((sat_articles_r['p1_is_redirect']==1) & (sat_articles_r['is_double_redirect']==1)).any()
# Out:
# True

# %%
# |
#check to see if any of the page_ids are redirects or double redirects
((sat_articles_r['p1_is_redirect']==1) | (sat_articles_r['is_double_redirect']==1)).any()
# Out:
# True

# %%
# act on the results ...featured_pages_redirects_r

#create a df 
all_surviving_articles_sat = sat_articles_r[['page_id','page_title', 'page_len']] 

#seperate the redirected items into their own df
redirects_sat = sat_articles_r.loc[sat_articles_r['p1_is_redirect']==1]
#pull only p1.page_id, p1.page_title, p1.page_len 
redirect_df_sat = redirects_sat[['page_id','page_title','page_len']] 

#remove the redirect items from the all_surviving_articles df & create global articles df
articles_sat =  all_surviving_articles_sat[~all_surviving_articles_sat.isin(redirect_df_sat)].dropna(how='all')

# %%
articles_tcy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1531 entries, 5 to 1712
# Data columns (total 3 columns):
# page_id       1531 non-null float64
# page_title    1531 non-null object
# page_len      1531 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 47.8+ KB

# %%
articles_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2929 entries, 3 to 3204
# Data columns (total 3 columns):
# page_id       2929 non-null float64
# page_title    2929 non-null object
# page_len      2929 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 91.5+ KB

# %%
median_values_sat = articles_sat['page_len'].median()
median_values_sat
# Out:
# 6438.0

# %%
articles_sat['page_len'].hist(bins=30, figsize=(16,18))
plt.ylabel('Count')
plt.xlabel('Page Length')
plt.title('Page Length Distribution: sat')
path = './results/figs/relative_length/'
plt.savefig(path+'10_pagelen_dis_sat');

# %%
median_values_tcy = articles_tcy['page_len'].median()
median_values_tcy
# Out:
# 3133.0

# %%
articles_tcy['page_len'].hist(bins=20, figsize=(16,18))
plt.ylabel('Count')
plt.xlabel('Page Length')
plt.title('Page Length Distribution: tcy')
path = './results/figs/relative_length/'
plt.savefig(path+'11_pagelen_dis_tcy');

# %% [markdown]
# ## create an index of median values

# %%
#first convert tcy and sat median values into a df
tcy_sat = pd.DataFrame({'wikicode': {0:'satwiki', 1: 'tcywiki'},
                        'page_len': {0:6438, 1:3133}
                       })

# %%
median_values = median_values.to_frame().reset_index()

# %%
median_value_pa = median_value_pa.to_frame().reset_index().rename(columns={'index':'wikicode'})

# %%
median_value_pa['wikicode']= median_value_pa['wikicode'].map({461:'pawiki'})

# %%
IN_median_vi = pd.concat([median_values,median_value_pa, tcy_sat])
# Out:
# /home/iflorez/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
IN_median_vi.sort_values(['page_len']).reset_index(drop=True);

# %%
IN_median_vi.rename(columns={'page_len': 'mpl_index'}, inplace=True)

# %%
# %store IN_median_vi
# Out:
# Stored 'IN_median_vi' (DataFrame)
